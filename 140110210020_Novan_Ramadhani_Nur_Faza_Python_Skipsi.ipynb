# %% [markdown]
# # Omega 3

# %%
# Membentuk Himpunnan kodon-kodon dari himpunan basa DNA
def Pembentuk_Kodon():
    # himpunan basa DNA
    omega = ['C', 'T', 'A', 'G']
    # himpunan kodon-kodon
    kodons = []

    # Membentuk kodon-kodon dari himpunan basa DNA
    for kodon_1 in omega:
        for kodon_2 in omega:
            for kodon_3 in omega:
                kodons.append(kodon_1 + kodon_2 + kodon_3)
    # Menampilkan kodon-kodon
    print(kodons)
    return kodons

# Memanggil fungsi Pembentuk_Kodon
kodons = Pembentuk_Kodon()
# Out:
# ['CCC', 'CCT', 'CCA', 'CCG', 'CTC', 'CTT', 'CTA', 'CTG', 'CAC', 'CAT', 'CAA', 'CAG', 'CGC', 'CGT', 'CGA', 'CGG', 'TCC', 'TCT', 'TCA', 'TCG', 'TTC', 'TTT', 'TTA', 'TTG', 'TAC', 'TAT', 'TAA', 'TAG', 'TGC', 'TGT', 'TGA', 'TGG', 'ACC', 'ACT', 'ACA', 'ACG', 'ATC', 'ATT', 'ATA', 'ATG', 'AAC', 'AAT', 'AAA', 'AAG', 'AGC', 'AGT', 'AGA', 'AGG', 'GCC', 'GCT', 'GCA', 'GCG', 'GTC', 'GTT', 'GTA', 'GTG', 'GAC', 'GAT', 'GAA', 'GAG', 'GGC', 'GGT', 'GGA', 'GGG']

# %% [markdown]
# # Proposisi 4.2

# %%
# Mencari elemen-elemen yang ekuivalen siklik
def Mencari_Elemen_Ekuivalen_siklik(kodons):
    # Mencari permutasi dari kodon
    def permutasi_kodons(kodons):

        # Permutasi a_1 = (1 2 3)
        keys_1 = [2, 3, 1]
        # Permutasi a_2 = (1 3 2)
        keys_2 = [3, 1, 2]

        keys_11 = [key - 1 for key in keys_1]
        keys_22 = [key - 1 for key in keys_2]

        # Periksa apakah panjang keys sama dengan panjang kodons
        if len(keys_11) != len(kodons) and len(keys_22) != len(kodons):
            raise ValueError('Panjang keys tidak sama dengan panjang kodons')

        # Mengembalikan permutasi terhadap kodons_i
        kodons_1 = [kodons[key] for key in keys_11]
        kodons_2 = [kodons[key] for key in keys_22]
        return ''.join(kodons_1) if isinstance(kodons, str) else kodons_1, ''.join(kodons_2) if isinstance(kodons, str) else kodons_2

    # membentuk himpunan dari elemen-elemen yang ekuivalen siklik
    def elemen_ekuivalen_siklik(kodons):

        # Membentuk dictionary untuk menyimpan urutan kodon
        urutan_kodon = {}

        # Menentukan kodon x_i
        for i in range(len(kodons)):

            # Melakukan permutasi terhadap kodon x_i
            kodons_11, kodons_22 = permutasi_kodons(kodons[i])

            # Menentukan kodon x_j
            for j in range(len(kodons)):

                # Menentukan kodon x_k
                for k in range(len(kodons)):

                    # Memeriksa apakah kodon x_i, kodon x_j, dan kodon x_k ekuivalen siklik
                    if kodons[j] == kodons_11 and kodons[k] == kodons_22:

                        # Memeriksa apakah kodon x_i sama dengan kodon x_j dan kodon x_k
                        if kodons[i] == kodons_11 and kodons[i] == kodons_22:
                            urutan_kodon[kodons[i]] = [kodons[i]]
                        else:
                            urutan_kodon[kodons[i]] = [kodons[i],kodons[j], kodons[k]]

                        # Menampilkan elemen ekuivalen siklik pada kodon x_i
                        print(f'Elemen Ekuivalen Siklik pada Kodon {kodons[i]}: {kodons[i], kodons_11, kodons_22}\n')
                    else:
                        continue

        # Mengembalikan list dari urutan kodon
        return list(urutan_kodon.values())

    # Mendefinisikan urutan kodon
    urutan_kodon = elemen_ekuivalen_siklik(kodons)
    # Mengembalikan urutan kodon
    return urutan_kodon

# Memanggil fungsi Mencari_Elemen_Ekuivalen_siklik
elemen_ekuivalen_siklik = Mencari_Elemen_Ekuivalen_siklik(kodons)
# Out:
# Elemen Ekuivalen Siklik pada Kodon CCC: ('CCC', 'CCC', 'CCC')
#
# Elemen Ekuivalen Siklik pada Kodon CCT: ('CCT', 'CTC', 'TCC')
#
# Elemen Ekuivalen Siklik pada Kodon CCA: ('CCA', 'CAC', 'ACC')
#
# Elemen Ekuivalen Siklik pada Kodon CCG: ('CCG', 'CGC', 'GCC')
#
# Elemen Ekuivalen Siklik pada Kodon CTC: ('CTC', 'TCC', 'CCT')
#
# Elemen Ekuivalen Siklik pada Kodon CTT: ('CTT', 'TTC', 'TCT')
#
# Elemen Ekuivalen Siklik pada Kodon CTA: ('CTA', 'TAC', 'ACT')
#
# Elemen Ekuivalen Siklik pada Kodon CTG: ('CTG', 'TGC', 'GCT')
#
# Elemen Ekuivalen Siklik pada Kodon CAC: ('CAC', 'ACC', 'CCA')
#
# Elemen Ekuivalen Siklik pada Kodon CAT: ('CAT', 'ATC', 'TCA')
#
# Elemen Ekuivalen Siklik pada Kodon CAA: ('CAA', 'AAC', 'ACA')
#
# Elemen Ekuivalen Siklik pada Kodon CAG: ('CAG', 'AGC', 'GCA')
#
# Elemen Ekuivalen Siklik pada Kodon CGC: ('CGC', 'GCC', 'CCG')
#
# Elemen Ekuivalen Siklik pada Kodon CGT: ('CGT', 'GTC', 'TCG')
#
# Elemen Ekuivalen Siklik pada Kodon CGA: ('CGA', 'GAC', 'ACG')
#
# Elemen Ekuivalen Siklik pada Kodon CGG: ('CGG', 'GGC', 'GCG')
#
# Elemen Ekuivalen Siklik pada Kodon TCC: ('TCC', 'CCT', 'CTC')
#
# Elemen Ekuivalen Siklik pada Kodon TCT: ('TCT', 'CTT', 'TTC')
#
# Elemen Ekuivalen Siklik pada Kodon TCA: ('TCA', 'CAT', 'ATC')
#
# Elemen Ekuivalen Siklik pada Kodon TCG: ('TCG', 'CGT', 'GTC')
#
# Elemen Ekuivalen Siklik pada Kodon TTC: ('TTC', 'TCT', 'CTT')
#
# Elemen Ekuivalen Siklik pada Kodon TTT: ('TTT', 'TTT', 'TTT')
#
# Elemen Ekuivalen Siklik pada Kodon TTA: ('TTA', 'TAT', 'ATT')
#
# Elemen Ekuivalen Siklik pada Kodon TTG: ('TTG', 'TGT', 'GTT')
#
# Elemen Ekuivalen Siklik pada Kodon TAC: ('TAC', 'ACT', 'CTA')
#
# Elemen Ekuivalen Siklik pada Kodon TAT: ('TAT', 'ATT', 'TTA')
#
# Elemen Ekuivalen Siklik pada Kodon TAA: ('TAA', 'AAT', 'ATA')
#
# Elemen Ekuivalen Siklik pada Kodon TAG: ('TAG', 'AGT', 'GTA')
#
# Elemen Ekuivalen Siklik pada Kodon TGC: ('TGC', 'GCT', 'CTG')
#
# Elemen Ekuivalen Siklik pada Kodon TGT: ('TGT', 'GTT', 'TTG')
#
# Elemen Ekuivalen Siklik pada Kodon TGA: ('TGA', 'GAT', 'ATG')
#
# Elemen Ekuivalen Siklik pada Kodon TGG: ('TGG', 'GGT', 'GTG')
#
# Elemen Ekuivalen Siklik pada Kodon ACC: ('ACC', 'CCA', 'CAC')
#
# Elemen Ekuivalen Siklik pada Kodon ACT: ('ACT', 'CTA', 'TAC')
#
# Elemen Ekuivalen Siklik pada Kodon ACA: ('ACA', 'CAA', 'AAC')
#
# Elemen Ekuivalen Siklik pada Kodon ACG: ('ACG', 'CGA', 'GAC')
#
# Elemen Ekuivalen Siklik pada Kodon ATC: ('ATC', 'TCA', 'CAT')
#
# Elemen Ekuivalen Siklik pada Kodon ATT: ('ATT', 'TTA', 'TAT')
#
# Elemen Ekuivalen Siklik pada Kodon ATA: ('ATA', 'TAA', 'AAT')
#
# Elemen Ekuivalen Siklik pada Kodon ATG: ('ATG', 'TGA', 'GAT')
#
# Elemen Ekuivalen Siklik pada Kodon AAC: ('AAC', 'ACA', 'CAA')
#
# Elemen Ekuivalen Siklik pada Kodon AAT: ('AAT', 'ATA', 'TAA')
#
# Elemen Ekuivalen Siklik pada Kodon AAA: ('AAA', 'AAA', 'AAA')
#
# Elemen Ekuivalen Siklik pada Kodon AAG: ('AAG', 'AGA', 'GAA')
#
# Elemen Ekuivalen Siklik pada Kodon AGC: ('AGC', 'GCA', 'CAG')
#
# Elemen Ekuivalen Siklik pada Kodon AGT: ('AGT', 'GTA', 'TAG')
#
# Elemen Ekuivalen Siklik pada Kodon AGA: ('AGA', 'GAA', 'AAG')
#
# Elemen Ekuivalen Siklik pada Kodon AGG: ('AGG', 'GGA', 'GAG')
#
# Elemen Ekuivalen Siklik pada Kodon GCC: ('GCC', 'CCG', 'CGC')
#
# Elemen Ekuivalen Siklik pada Kodon GCT: ('GCT', 'CTG', 'TGC')
#
# Elemen Ekuivalen Siklik pada Kodon GCA: ('GCA', 'CAG', 'AGC')
#
# Elemen Ekuivalen Siklik pada Kodon GCG: ('GCG', 'CGG', 'GGC')
#
# Elemen Ekuivalen Siklik pada Kodon GTC: ('GTC', 'TCG', 'CGT')
#
# Elemen Ekuivalen Siklik pada Kodon GTT: ('GTT', 'TTG', 'TGT')
#
# Elemen Ekuivalen Siklik pada Kodon GTA: ('GTA', 'TAG', 'AGT')
#
# Elemen Ekuivalen Siklik pada Kodon GTG: ('GTG', 'TGG', 'GGT')
#
# Elemen Ekuivalen Siklik pada Kodon GAC: ('GAC', 'ACG', 'CGA')
#
# Elemen Ekuivalen Siklik pada Kodon GAT: ('GAT', 'ATG', 'TGA')
#
# Elemen Ekuivalen Siklik pada Kodon GAA: ('GAA', 'AAG', 'AGA')
#
# Elemen Ekuivalen Siklik pada Kodon GAG: ('GAG', 'AGG', 'GGA')
#
# Elemen Ekuivalen Siklik pada Kodon GGC: ('GGC', 'GCG', 'CGG')
#
# Elemen Ekuivalen Siklik pada Kodon GGT: ('GGT', 'GTG', 'TGG')
#
# Elemen Ekuivalen Siklik pada Kodon GGA: ('GGA', 'GAG', 'AGG')
#
# Elemen Ekuivalen Siklik pada Kodon GGG: ('GGG', 'GGG', 'GGG')

# %% [markdown]
# # Proposisi 4.3

# %%
# Membentuk fungsi untuk mencari kelas-kelas ekuivalen siklik
def KelasEkuivalenSiklik(urutan_kodon):

    # Mensortir dan mengelompokkan kelas-kelas ekuivalen siklik
    def KelompokKelasEkuivalenSiklik(strs):

        # Membuat dictionary untuk menyimpan kelas-kelas ekuivalen siklik
        Kelas = {}
        for word in strs:

            # Mengurutkan karakter pada kelas-kelas ekuivalen siklik
            key = "".join(sorted(word))

            # Memeriksa apakah key ada dalam Kelas-kelas ekuivalen siklik
            if key in Kelas or len(key) < 9:
                continue
            else:
                Kelas[key] = word

        # Kembalikan daftar kelas-kelas ekuivalen siklik
        return list(Kelas.values())


    hasil = KelompokKelasEkuivalenSiklik(urutan_kodon)
    nama_file = 'Kelas Ekuivalen Siklik.txt'
    print("Kelas-kelas ekuivalen:")
    for i, kelompok in enumerate(hasil):
        print(f"{i+1}. Kelas ekuivalen [{kelompok[0]}]: {kelompok}")
    return hasil

Kelas_Ekuivalen = KelasEkuivalenSiklik(elemen_ekuivalen_siklik)
# Out:
# Kelas-kelas ekuivalen:
# 1. Kelas ekuivalen [CCT]: ['CCT', 'CTC', 'TCC']
# 2. Kelas ekuivalen [CCA]: ['CCA', 'CAC', 'ACC']
# 3. Kelas ekuivalen [CCG]: ['CCG', 'CGC', 'GCC']
# 4. Kelas ekuivalen [CTT]: ['CTT', 'TTC', 'TCT']
# 5. Kelas ekuivalen [CTA]: ['CTA', 'TAC', 'ACT']
# 6. Kelas ekuivalen [CTG]: ['CTG', 'TGC', 'GCT']
# 7. Kelas ekuivalen [CAT]: ['CAT', 'ATC', 'TCA']
# 8. Kelas ekuivalen [CAA]: ['CAA', 'AAC', 'ACA']
# 9. Kelas ekuivalen [CAG]: ['CAG', 'AGC', 'GCA']
# 10. Kelas ekuivalen [CGT]: ['CGT', 'GTC', 'TCG']
# 11. Kelas ekuivalen [CGA]: ['CGA', 'GAC', 'ACG']
# 12. Kelas ekuivalen [CGG]: ['CGG', 'GGC', 'GCG']
# 13. Kelas ekuivalen [TTA]: ['TTA', 'TAT', 'ATT']
# 14. Kelas ekuivalen [TTG]: ['TTG', 'TGT', 'GTT']
# 15. Kelas ekuivalen [TAA]: ['TAA', 'AAT', 'ATA']
# 16. Kelas ekuivalen [TAG]: ['TAG', 'AGT', 'GTA']
# 17. Kelas ekuivalen [TGA]: ['TGA', 'GAT', 'ATG']
# 18. Kelas ekuivalen [TGG]: ['TGG', 'GGT', 'GTG']
# 19. Kelas ekuivalen [AAG]: ['AAG', 'AGA', 'GAA']
# 20. Kelas ekuivalen [AGG]: ['AGG', 'GGA', 'GAG']

# %% [markdown]
# # Proposisi 4.4

# %% [markdown]
# ## Untuk |X| = 1

# %%
# mencari himpuanan bersifat kode sirukular trinukleotida
def Sirkular_Trinukleotida(Kelas_Ekuivalen):

    # Menentukan himpunan X
    X = []
    # Menentukan nomor urutan
    k = 1

    # Mencari permutasi dari kodon
    def permutasi_kodons(kodons):

        # Permutasi a_1 = (1 2 3)
        keys_1 = [2, 3, 1]
        # Permutasi a_2 = (1 3 2)
        keys_2 = [3, 1, 2]

        keys_11 = [key - 1 for key in keys_1]
        keys_22 = [key - 1 for key in keys_2]

        # Periksa apakah panjang keys sama dengan panjang kodons
        if len(keys_11) != len(kodons) and len(keys_22) != len(kodons):
            raise ValueError('Panjang keys tidak sama dengan panjang kodons')

        # Mengembalikan permutasi terhadap kodons_i
        kodons_1 = [kodons[key] for key in keys_11]
        kodons_2 = [kodons[key] for key in keys_22]
        return ''.join(kodons_1) if isinstance(kodons, str) else kodons_1, ''.join(kodons_2) if isinstance(kodons, str) else kodons_2

    # melakukan perulangan untuk mencari himpunan sirkular trinukleotida
    for kodon in Kelas_Ekuivalen:
        kodons_1, kodons_2 = permutasi_kodons(kodon)

        # Memeriksa apakah x1 dan x2 tidak ada dalam X
        if kodon not in X and kodon != kodons_1 and kodon != kodons_2:
            X.append([kodon])
            print(f'{k}. Himpunan Sirkular Trinukleotida: [{kodon}]')
            print(f'Kata Sikel yang terbentuk: {kodon, kodons_1, kodons_2}\n')
            k += 1
        else:
            continue
    return X


sirkular_trinukleotida = Sirkular_Trinukleotida(kodons)
# Out:
# 1. Himpunan Sirkular Trinukleotida: [CCT]
# Kata Sikel yang terbentuk: ('CCT', 'CTC', 'TCC')
#
# 2. Himpunan Sirkular Trinukleotida: [CCA]
# Kata Sikel yang terbentuk: ('CCA', 'CAC', 'ACC')
#
# 3. Himpunan Sirkular Trinukleotida: [CCG]
# Kata Sikel yang terbentuk: ('CCG', 'CGC', 'GCC')
#
# 4. Himpunan Sirkular Trinukleotida: [CTC]
# Kata Sikel yang terbentuk: ('CTC', 'TCC', 'CCT')
#
# 5. Himpunan Sirkular Trinukleotida: [CTT]
# Kata Sikel yang terbentuk: ('CTT', 'TTC', 'TCT')
#
# 6. Himpunan Sirkular Trinukleotida: [CTA]
# Kata Sikel yang terbentuk: ('CTA', 'TAC', 'ACT')
#
# 7. Himpunan Sirkular Trinukleotida: [CTG]
# Kata Sikel yang terbentuk: ('CTG', 'TGC', 'GCT')
#
# 8. Himpunan Sirkular Trinukleotida: [CAC]
# Kata Sikel yang terbentuk: ('CAC', 'ACC', 'CCA')
#
# 9. Himpunan Sirkular Trinukleotida: [CAT]
# Kata Sikel yang terbentuk: ('CAT', 'ATC', 'TCA')
#
# 10. Himpunan Sirkular Trinukleotida: [CAA]
# Kata Sikel yang terbentuk: ('CAA', 'AAC', 'ACA')
#
# 11. Himpunan Sirkular Trinukleotida: [CAG]
# Kata Sikel yang terbentuk: ('CAG', 'AGC', 'GCA')
#
# 12. Himpunan Sirkular Trinukleotida: [CGC]
# Kata Sikel yang terbentuk: ('CGC', 'GCC', 'CCG')
#
# 13. Himpunan Sirkular Trinukleotida: [CGT]
# Kata Sikel yang terbentuk: ('CGT', 'GTC', 'TCG')
#
# 14. Himpunan Sirkular Trinukleotida: [CGA]
# Kata Sikel yang terbentuk: ('CGA', 'GAC', 'ACG')
#
# 15. Himpunan Sirkular Trinukleotida: [CGG]
# Kata Sikel yang terbentuk: ('CGG', 'GGC', 'GCG')
#
# 16. Himpunan Sirkular Trinukleotida: [TCC]
# Kata Sikel yang terbentuk: ('TCC', 'CCT', 'CTC')
#
# 17. Himpunan Sirkular Trinukleotida: [TCT]
# Kata Sikel yang terbentuk: ('TCT', 'CTT', 'TTC')
#
# 18. Himpunan Sirkular Trinukleotida: [TCA]
# Kata Sikel yang terbentuk: ('TCA', 'CAT', 'ATC')
#
# 19. Himpunan Sirkular Trinukleotida: [TCG]
# Kata Sikel yang terbentuk: ('TCG', 'CGT', 'GTC')
#
# 20. Himpunan Sirkular Trinukleotida: [TTC]
# Kata Sikel yang terbentuk: ('TTC', 'TCT', 'CTT')
#
# 21. Himpunan Sirkular Trinukleotida: [TTA]
# Kata Sikel yang terbentuk: ('TTA', 'TAT', 'ATT')
#
# 22. Himpunan Sirkular Trinukleotida: [TTG]
# Kata Sikel yang terbentuk: ('TTG', 'TGT', 'GTT')
#
# 23. Himpunan Sirkular Trinukleotida: [TAC]
# Kata Sikel yang terbentuk: ('TAC', 'ACT', 'CTA')
#
# 24. Himpunan Sirkular Trinukleotida: [TAT]
# Kata Sikel yang terbentuk: ('TAT', 'ATT', 'TTA')
#
# 25. Himpunan Sirkular Trinukleotida: [TAA]
# Kata Sikel yang terbentuk: ('TAA', 'AAT', 'ATA')
#
# 26. Himpunan Sirkular Trinukleotida: [TAG]
# Kata Sikel yang terbentuk: ('TAG', 'AGT', 'GTA')
#
# 27. Himpunan Sirkular Trinukleotida: [TGC]
# Kata Sikel yang terbentuk: ('TGC', 'GCT', 'CTG')
#
# 28. Himpunan Sirkular Trinukleotida: [TGT]
# Kata Sikel yang terbentuk: ('TGT', 'GTT', 'TTG')
#
# 29. Himpunan Sirkular Trinukleotida: [TGA]
# Kata Sikel yang terbentuk: ('TGA', 'GAT', 'ATG')
#
# 30. Himpunan Sirkular Trinukleotida: [TGG]
# Kata Sikel yang terbentuk: ('TGG', 'GGT', 'GTG')
#
# 31. Himpunan Sirkular Trinukleotida: [ACC]
# Kata Sikel yang terbentuk: ('ACC', 'CCA', 'CAC')
#
# 32. Himpunan Sirkular Trinukleotida: [ACT]
# Kata Sikel yang terbentuk: ('ACT', 'CTA', 'TAC')
#
# 33. Himpunan Sirkular Trinukleotida: [ACA]
# Kata Sikel yang terbentuk: ('ACA', 'CAA', 'AAC')
#
# 34. Himpunan Sirkular Trinukleotida: [ACG]
# Kata Sikel yang terbentuk: ('ACG', 'CGA', 'GAC')
#
# 35. Himpunan Sirkular Trinukleotida: [ATC]
# Kata Sikel yang terbentuk: ('ATC', 'TCA', 'CAT')
#
# 36. Himpunan Sirkular Trinukleotida: [ATT]
# Kata Sikel yang terbentuk: ('ATT', 'TTA', 'TAT')
#
# 37. Himpunan Sirkular Trinukleotida: [ATA]
# Kata Sikel yang terbentuk: ('ATA', 'TAA', 'AAT')
#
# 38. Himpunan Sirkular Trinukleotida: [ATG]
# Kata Sikel yang terbentuk: ('ATG', 'TGA', 'GAT')
#
# 39. Himpunan Sirkular Trinukleotida: [AAC]
# Kata Sikel yang terbentuk: ('AAC', 'ACA', 'CAA')
#
# 40. Himpunan Sirkular Trinukleotida: [AAT]
# Kata Sikel yang terbentuk: ('AAT', 'ATA', 'TAA')
#
# 41. Himpunan Sirkular Trinukleotida: [AAG]
# Kata Sikel yang terbentuk: ('AAG', 'AGA', 'GAA')
#
# 42. Himpunan Sirkular Trinukleotida: [AGC]
# Kata Sikel yang terbentuk: ('AGC', 'GCA', 'CAG')
#
# 43. Himpunan Sirkular Trinukleotida: [AGT]
# Kata Sikel yang terbentuk: ('AGT', 'GTA', 'TAG')
#
# 44. Himpunan Sirkular Trinukleotida: [AGA]
# Kata Sikel yang terbentuk: ('AGA', 'GAA', 'AAG')
#
# 45. Himpunan Sirkular Trinukleotida: [AGG]
# Kata Sikel yang terbentuk: ('AGG', 'GGA', 'GAG')
#
# 46. Himpunan Sirkular Trinukleotida: [GCC]
# Kata Sikel yang terbentuk: ('GCC', 'CCG', 'CGC')
#
# 47. Himpunan Sirkular Trinukleotida: [GCT]
# Kata Sikel yang terbentuk: ('GCT', 'CTG', 'TGC')
#
# 48. Himpunan Sirkular Trinukleotida: [GCA]
# Kata Sikel yang terbentuk: ('GCA', 'CAG', 'AGC')
#
# 49. Himpunan Sirkular Trinukleotida: [GCG]
# Kata Sikel yang terbentuk: ('GCG', 'CGG', 'GGC')
#
# 50. Himpunan Sirkular Trinukleotida: [GTC]
# Kata Sikel yang terbentuk: ('GTC', 'TCG', 'CGT')
#
# 51. Himpunan Sirkular Trinukleotida: [GTT]
# Kata Sikel yang terbentuk: ('GTT', 'TTG', 'TGT')
#
# 52. Himpunan Sirkular Trinukleotida: [GTA]
# Kata Sikel yang terbentuk: ('GTA', 'TAG', 'AGT')
#
# 53. Himpunan Sirkular Trinukleotida: [GTG]
# Kata Sikel yang terbentuk: ('GTG', 'TGG', 'GGT')
#
# 54. Himpunan Sirkular Trinukleotida: [GAC]
# Kata Sikel yang terbentuk: ('GAC', 'ACG', 'CGA')
#
# 55. Himpunan Sirkular Trinukleotida: [GAT]
# Kata Sikel yang terbentuk: ('GAT', 'ATG', 'TGA')
#
# 56. Himpunan Sirkular Trinukleotida: [GAA]
# Kata Sikel yang terbentuk: ('GAA', 'AAG', 'AGA')
#
# 57. Himpunan Sirkular Trinukleotida: [GAG]
# Kata Sikel yang terbentuk: ('GAG', 'AGG', 'GGA')
#
# 58. Himpunan Sirkular Trinukleotida: [GGC]
# Kata Sikel yang terbentuk: ('GGC', 'GCG', 'CGG')
#
# 59. Himpunan Sirkular Trinukleotida: [GGT]
# Kata Sikel yang terbentuk: ('GGT', 'GTG', 'TGG')
#
# 60. Himpunan Sirkular Trinukleotida: [GGA]
# Kata Sikel yang terbentuk: ('GGA', 'GAG', 'AGG')

# %% [markdown]
# ## Untuk |X| = 2

# %%
# mencari himpuanan bersifat kode sirukular trinukleotida
def Sirkular_Trinukleotida(Kelas_Ekuivalen):

    # Menentukan himpunan X
    X = []
    # Menentukan nomor urutan
    k = 1

    # Mencari permutasi dari kodon
    def permutasi_kodons(kodons):

        # Permutasi a_1 = (1 2 3)
        keys_1 = [2, 3, 4, 5, 6, 1]
        # Permutasi a_2 = (1 3 2)
        keys_2 = [3, 4, 5 ,6 ,1, 2]

        keys_11 = [key - 1 for key in keys_1]
        keys_22 = [key - 1 for key in keys_2]

        # Periksa apakah panjang keys sama dengan panjang kodons
        if len(keys_11) != len(kodons) and len(keys_22) != len(kodons):
            raise ValueError('Panjang keys tidak sama dengan panjang kodons')

        # Mengembalikan permutasi terhadap kodons_i
        kodons_1 = [kodons[key] for key in keys_11]
        kodons_2 = [kodons[key] for key in keys_22]
        return ''.join(kodons_1) if isinstance(kodons, str) else kodons_1, ''.join(kodons_2) if isinstance(kodons, str) else kodons_2

    # melakukan perulangan untuk mencari himpunan sirkular trinukleotida
    for i in range(len(Kelas_Ekuivalen)):
        for j in range(len(Kelas_Ekuivalen)):
            if i == j:
                continue
            else:
                # Menentukan kodon x_i dari Kelas Ekuivalen
                for kodon_1 in (Kelas_Ekuivalen[i]):
                    # Menentukan kodon x_j dari Kelas Ekuivalen
                    for kodon_2 in (Kelas_Ekuivalen[j]):
                        # mengurutkan kodon x_i dan kodon x_j
                        x1 = [kodon_1, kodon_2]
                        x2 = [kodon_2, kodon_1]

                        # Memeriksa apakah alfabet sama dengan kodons_1 dan kodons_2
                        alfabet = kodon_1 + kodon_2
                        kodons_1, kodons_2 = permutasi_kodons(alfabet)

                        # Memeriksa apakah x1 dan x2 tidak ada dalam X
                        if x1 not in X and x2 not in X and alfabet != kodons_1 and alfabet != kodons_2:
                            X.append([kodon_1, kodon_2])
                            print(f'{k}. Himpunan Sirkular Trinukleotida: [{kodon_1, kodon_2}]')
                            print(f'Kata Sikel yang terbentuk: {alfabet, kodons_1, kodons_2}\n')
                            k += 1
                        else:
                            continue
    return X


sirkular_trinukleotida = Sirkular_Trinukleotida(Kelas_Ekuivalen)
# Out:
# Streaming output truncated to the last 5000 lines.
# Kata Sikel yang terbentuk: ('CCTGCT', 'CTGCTC', 'TGCTCC')
#
# 39. Himpunan Sirkular Trinukleotida: [('CTC', 'CTG')]
# Kata Sikel yang terbentuk: ('CTCCTG', 'TCCTGC', 'CCTGCT')
#
# 40. Himpunan Sirkular Trinukleotida: [('CTC', 'TGC')]
# Kata Sikel yang terbentuk: ('CTCTGC', 'TCTGCC', 'CTGCCT')
#
# 41. Himpunan Sirkular Trinukleotida: [('CTC', 'GCT')]
# Kata Sikel yang terbentuk: ('CTCGCT', 'TCGCTC', 'CGCTCT')
#
# 42. Himpunan Sirkular Trinukleotida: [('TCC', 'CTG')]
# Kata Sikel yang terbentuk: ('TCCCTG', 'CCCTGT', 'CCTGTC')
#
# 43. Himpunan Sirkular Trinukleotida: [('TCC', 'TGC')]
# Kata Sikel yang terbentuk: ('TCCTGC', 'CCTGCT', 'CTGCTC')
#
# 44. Himpunan Sirkular Trinukleotida: [('TCC', 'GCT')]
# Kata Sikel yang terbentuk: ('TCCGCT', 'CCGCTT', 'CGCTTC')
#
# 45. Himpunan Sirkular Trinukleotida: [('CCT', 'CAT')]
# Kata Sikel yang terbentuk: ('CCTCAT', 'CTCATC', 'TCATCC')
#
# 46. Himpunan Sirkular Trinukleotida: [('CCT', 'ATC')]
# Kata Sikel yang terbentuk: ('CCTATC', 'CTATCC', 'TATCCC')
#
# 47. Himpunan Sirkular Trinukleotida: [('CCT', 'TCA')]
# Kata Sikel yang terbentuk: ('CCTTCA', 'CTTCAC', 'TTCACC')
#
# 48. Himpunan Sirkular Trinukleotida: [('CTC', 'CAT')]
# Kata Sikel yang terbentuk: ('CTCCAT', 'TCCATC', 'CCATCT')
#
# 49. Himpunan Sirkular Trinukleotida: [('CTC', 'ATC')]
# Kata Sikel yang terbentuk: ('CTCATC', 'TCATCC', 'CATCCT')
#
# 50. Himpunan Sirkular Trinukleotida: [('CTC', 'TCA')]
# Kata Sikel yang terbentuk: ('CTCTCA', 'TCTCAC', 'CTCACT')
#
# 51. Himpunan Sirkular Trinukleotida: [('TCC', 'CAT')]
# Kata Sikel yang terbentuk: ('TCCCAT', 'CCCATT', 'CCATTC')
#
# 52. Himpunan Sirkular Trinukleotida: [('TCC', 'ATC')]
# Kata Sikel yang terbentuk: ('TCCATC', 'CCATCT', 'CATCTC')
#
# 53. Himpunan Sirkular Trinukleotida: [('TCC', 'TCA')]
# Kata Sikel yang terbentuk: ('TCCTCA', 'CCTCAT', 'CTCATC')
#
# 54. Himpunan Sirkular Trinukleotida: [('CCT', 'CAA')]
# Kata Sikel yang terbentuk: ('CCTCAA', 'CTCAAC', 'TCAACC')
#
# 55. Himpunan Sirkular Trinukleotida: [('CCT', 'AAC')]
# Kata Sikel yang terbentuk: ('CCTAAC', 'CTAACC', 'TAACCC')
#
# 56. Himpunan Sirkular Trinukleotida: [('CCT', 'ACA')]
# Kata Sikel yang terbentuk: ('CCTACA', 'CTACAC', 'TACACC')
#
# 57. Himpunan Sirkular Trinukleotida: [('CTC', 'CAA')]
# Kata Sikel yang terbentuk: ('CTCCAA', 'TCCAAC', 'CCAACT')
#
# 58. Himpunan Sirkular Trinukleotida: [('CTC', 'AAC')]
# Kata Sikel yang terbentuk: ('CTCAAC', 'TCAACC', 'CAACCT')
#
# 59. Himpunan Sirkular Trinukleotida: [('CTC', 'ACA')]
# Kata Sikel yang terbentuk: ('CTCACA', 'TCACAC', 'CACACT')
#
# 60. Himpunan Sirkular Trinukleotida: [('TCC', 'CAA')]
# Kata Sikel yang terbentuk: ('TCCCAA', 'CCCAAT', 'CCAATC')
#
# 61. Himpunan Sirkular Trinukleotida: [('TCC', 'AAC')]
# Kata Sikel yang terbentuk: ('TCCAAC', 'CCAACT', 'CAACTC')
#
# 62. Himpunan Sirkular Trinukleotida: [('TCC', 'ACA')]
# Kata Sikel yang terbentuk: ('TCCACA', 'CCACAT', 'CACATC')
#
# 63. Himpunan Sirkular Trinukleotida: [('CCT', 'CAG')]
# Kata Sikel yang terbentuk: ('CCTCAG', 'CTCAGC', 'TCAGCC')
#
# 64. Himpunan Sirkular Trinukleotida: [('CCT', 'AGC')]
# Kata Sikel yang terbentuk: ('CCTAGC', 'CTAGCC', 'TAGCCC')
#
# 65. Himpunan Sirkular Trinukleotida: [('CCT', 'GCA')]
# Kata Sikel yang terbentuk: ('CCTGCA', 'CTGCAC', 'TGCACC')
#
# 66. Himpunan Sirkular Trinukleotida: [('CTC', 'CAG')]
# Kata Sikel yang terbentuk: ('CTCCAG', 'TCCAGC', 'CCAGCT')
#
# 67. Himpunan Sirkular Trinukleotida: [('CTC', 'AGC')]
# Kata Sikel yang terbentuk: ('CTCAGC', 'TCAGCC', 'CAGCCT')
#
# 68. Himpunan Sirkular Trinukleotida: [('CTC', 'GCA')]
# Kata Sikel yang terbentuk: ('CTCGCA', 'TCGCAC', 'CGCACT')
#
# 69. Himpunan Sirkular Trinukleotida: [('TCC', 'CAG')]
# Kata Sikel yang terbentuk: ('TCCCAG', 'CCCAGT', 'CCAGTC')
#
# 70. Himpunan Sirkular Trinukleotida: [('TCC', 'AGC')]
# Kata Sikel yang terbentuk: ('TCCAGC', 'CCAGCT', 'CAGCTC')
#
# 71. Himpunan Sirkular Trinukleotida: [('TCC', 'GCA')]
# Kata Sikel yang terbentuk: ('TCCGCA', 'CCGCAT', 'CGCATC')
#
# 72. Himpunan Sirkular Trinukleotida: [('CCT', 'CGT')]
# Kata Sikel yang terbentuk: ('CCTCGT', 'CTCGTC', 'TCGTCC')
#
# 73. Himpunan Sirkular Trinukleotida: [('CCT', 'GTC')]
# Kata Sikel yang terbentuk: ('CCTGTC', 'CTGTCC', 'TGTCCC')
#
# 74. Himpunan Sirkular Trinukleotida: [('CCT', 'TCG')]
# Kata Sikel yang terbentuk: ('CCTTCG', 'CTTCGC', 'TTCGCC')
#
# 75. Himpunan Sirkular Trinukleotida: [('CTC', 'CGT')]
# Kata Sikel yang terbentuk: ('CTCCGT', 'TCCGTC', 'CCGTCT')
#
# 76. Himpunan Sirkular Trinukleotida: [('CTC', 'GTC')]
# Kata Sikel yang terbentuk: ('CTCGTC', 'TCGTCC', 'CGTCCT')
#
# 77. Himpunan Sirkular Trinukleotida: [('CTC', 'TCG')]
# Kata Sikel yang terbentuk: ('CTCTCG', 'TCTCGC', 'CTCGCT')
#
# 78. Himpunan Sirkular Trinukleotida: [('TCC', 'CGT')]
# Kata Sikel yang terbentuk: ('TCCCGT', 'CCCGTT', 'CCGTTC')
#
# 79. Himpunan Sirkular Trinukleotida: [('TCC', 'GTC')]
# Kata Sikel yang terbentuk: ('TCCGTC', 'CCGTCT', 'CGTCTC')
#
# 80. Himpunan Sirkular Trinukleotida: [('TCC', 'TCG')]
# Kata Sikel yang terbentuk: ('TCCTCG', 'CCTCGT', 'CTCGTC')
#
# 81. Himpunan Sirkular Trinukleotida: [('CCT', 'CGA')]
# Kata Sikel yang terbentuk: ('CCTCGA', 'CTCGAC', 'TCGACC')
#
# 82. Himpunan Sirkular Trinukleotida: [('CCT', 'GAC')]
# Kata Sikel yang terbentuk: ('CCTGAC', 'CTGACC', 'TGACCC')
#
# 83. Himpunan Sirkular Trinukleotida: [('CCT', 'ACG')]
# Kata Sikel yang terbentuk: ('CCTACG', 'CTACGC', 'TACGCC')
#
# 84. Himpunan Sirkular Trinukleotida: [('CTC', 'CGA')]
# Kata Sikel yang terbentuk: ('CTCCGA', 'TCCGAC', 'CCGACT')
#
# 85. Himpunan Sirkular Trinukleotida: [('CTC', 'GAC')]
# Kata Sikel yang terbentuk: ('CTCGAC', 'TCGACC', 'CGACCT')
#
# 86. Himpunan Sirkular Trinukleotida: [('CTC', 'ACG')]
# Kata Sikel yang terbentuk: ('CTCACG', 'TCACGC', 'CACGCT')
#
# 87. Himpunan Sirkular Trinukleotida: [('TCC', 'CGA')]
# Kata Sikel yang terbentuk: ('TCCCGA', 'CCCGAT', 'CCGATC')
#
# 88. Himpunan Sirkular Trinukleotida: [('TCC', 'GAC')]
# Kata Sikel yang terbentuk: ('TCCGAC', 'CCGACT', 'CGACTC')
#
# 89. Himpunan Sirkular Trinukleotida: [('TCC', 'ACG')]
# Kata Sikel yang terbentuk: ('TCCACG', 'CCACGT', 'CACGTC')
#
# 90. Himpunan Sirkular Trinukleotida: [('CCT', 'CGG')]
# Kata Sikel yang terbentuk: ('CCTCGG', 'CTCGGC', 'TCGGCC')
#
# 91. Himpunan Sirkular Trinukleotida: [('CCT', 'GGC')]
# Kata Sikel yang terbentuk: ('CCTGGC', 'CTGGCC', 'TGGCCC')
#
# 92. Himpunan Sirkular Trinukleotida: [('CCT', 'GCG')]
# Kata Sikel yang terbentuk: ('CCTGCG', 'CTGCGC', 'TGCGCC')
#
# 93. Himpunan Sirkular Trinukleotida: [('CTC', 'CGG')]
# Kata Sikel yang terbentuk: ('CTCCGG', 'TCCGGC', 'CCGGCT')
#
# 94. Himpunan Sirkular Trinukleotida: [('CTC', 'GGC')]
# Kata Sikel yang terbentuk: ('CTCGGC', 'TCGGCC', 'CGGCCT')
#
# 95. Himpunan Sirkular Trinukleotida: [('CTC', 'GCG')]
# Kata Sikel yang terbentuk: ('CTCGCG', 'TCGCGC', 'CGCGCT')
#
# 96. Himpunan Sirkular Trinukleotida: [('TCC', 'CGG')]
# Kata Sikel yang terbentuk: ('TCCCGG', 'CCCGGT', 'CCGGTC')
#
# 97. Himpunan Sirkular Trinukleotida: [('TCC', 'GGC')]
# Kata Sikel yang terbentuk: ('TCCGGC', 'CCGGCT', 'CGGCTC')
#
# 98. Himpunan Sirkular Trinukleotida: [('TCC', 'GCG')]
# Kata Sikel yang terbentuk: ('TCCGCG', 'CCGCGT', 'CGCGTC')
#
# 99. Himpunan Sirkular Trinukleotida: [('CCT', 'TTA')]
# Kata Sikel yang terbentuk: ('CCTTTA', 'CTTTAC', 'TTTACC')
#
# 100. Himpunan Sirkular Trinukleotida: [('CCT', 'TAT')]
# Kata Sikel yang terbentuk: ('CCTTAT', 'CTTATC', 'TTATCC')
#
# 101. Himpunan Sirkular Trinukleotida: [('CCT', 'ATT')]
# Kata Sikel yang terbentuk: ('CCTATT', 'CTATTC', 'TATTCC')
#
# 102. Himpunan Sirkular Trinukleotida: [('CTC', 'TTA')]
# Kata Sikel yang terbentuk: ('CTCTTA', 'TCTTAC', 'CTTACT')
#
# 103. Himpunan Sirkular Trinukleotida: [('CTC', 'TAT')]
# Kata Sikel yang terbentuk: ('CTCTAT', 'TCTATC', 'CTATCT')
#
# 104. Himpunan Sirkular Trinukleotida: [('CTC', 'ATT')]
# Kata Sikel yang terbentuk: ('CTCATT', 'TCATTC', 'CATTCT')
#
# 105. Himpunan Sirkular Trinukleotida: [('TCC', 'TTA')]
# Kata Sikel yang terbentuk: ('TCCTTA', 'CCTTAT', 'CTTATC')
#
# 106. Himpunan Sirkular Trinukleotida: [('TCC', 'TAT')]
# Kata Sikel yang terbentuk: ('TCCTAT', 'CCTATT', 'CTATTC')
#
# 107. Himpunan Sirkular Trinukleotida: [('TCC', 'ATT')]
# Kata Sikel yang terbentuk: ('TCCATT', 'CCATTT', 'CATTTC')
#
# 108. Himpunan Sirkular Trinukleotida: [('CCT', 'TTG')]
# Kata Sikel yang terbentuk: ('CCTTTG', 'CTTTGC', 'TTTGCC')
#
# 109. Himpunan Sirkular Trinukleotida: [('CCT', 'TGT')]
# Kata Sikel yang terbentuk: ('CCTTGT', 'CTTGTC', 'TTGTCC')
#
# 110. Himpunan Sirkular Trinukleotida: [('CCT', 'GTT')]
# Kata Sikel yang terbentuk: ('CCTGTT', 'CTGTTC', 'TGTTCC')
#
# 111. Himpunan Sirkular Trinukleotida: [('CTC', 'TTG')]
# Kata Sikel yang terbentuk: ('CTCTTG', 'TCTTGC', 'CTTGCT')
#
# 112. Himpunan Sirkular Trinukleotida: [('CTC', 'TGT')]
# Kata Sikel yang terbentuk: ('CTCTGT', 'TCTGTC', 'CTGTCT')
#
# 113. Himpunan Sirkular Trinukleotida: [('CTC', 'GTT')]
# Kata Sikel yang terbentuk: ('CTCGTT', 'TCGTTC', 'CGTTCT')
#
# 114. Himpunan Sirkular Trinukleotida: [('TCC', 'TTG')]
# Kata Sikel yang terbentuk: ('TCCTTG', 'CCTTGT', 'CTTGTC')
#
# 115. Himpunan Sirkular Trinukleotida: [('TCC', 'TGT')]
# Kata Sikel yang terbentuk: ('TCCTGT', 'CCTGTT', 'CTGTTC')
#
# 116. Himpunan Sirkular Trinukleotida: [('TCC', 'GTT')]
# Kata Sikel yang terbentuk: ('TCCGTT', 'CCGTTT', 'CGTTTC')
#
# 117. Himpunan Sirkular Trinukleotida: [('CCT', 'TAA')]
# Kata Sikel yang terbentuk: ('CCTTAA', 'CTTAAC', 'TTAACC')
#
# 118. Himpunan Sirkular Trinukleotida: [('CCT', 'AAT')]
# Kata Sikel yang terbentuk: ('CCTAAT', 'CTAATC', 'TAATCC')
#
# 119. Himpunan Sirkular Trinukleotida: [('CCT', 'ATA')]
# Kata Sikel yang terbentuk: ('CCTATA', 'CTATAC', 'TATACC')
#
# 120. Himpunan Sirkular Trinukleotida: [('CTC', 'TAA')]
# Kata Sikel yang terbentuk: ('CTCTAA', 'TCTAAC', 'CTAACT')
#
# 121. Himpunan Sirkular Trinukleotida: [('CTC', 'AAT')]
# Kata Sikel yang terbentuk: ('CTCAAT', 'TCAATC', 'CAATCT')
#
# 122. Himpunan Sirkular Trinukleotida: [('CTC', 'ATA')]
# Kata Sikel yang terbentuk: ('CTCATA', 'TCATAC', 'CATACT')
#
# 123. Himpunan Sirkular Trinukleotida: [('TCC', 'TAA')]
# Kata Sikel yang terbentuk: ('TCCTAA', 'CCTAAT', 'CTAATC')
#
# 124. Himpunan Sirkular Trinukleotida: [('TCC', 'AAT')]
# Kata Sikel yang terbentuk: ('TCCAAT', 'CCAATT', 'CAATTC')
#
# 125. Himpunan Sirkular Trinukleotida: [('TCC', 'ATA')]
# Kata Sikel yang terbentuk: ('TCCATA', 'CCATAT', 'CATATC')
#
# 126. Himpunan Sirkular Trinukleotida: [('CCT', 'TAG')]
# Kata Sikel yang terbentuk: ('CCTTAG', 'CTTAGC', 'TTAGCC')
#
# 127. Himpunan Sirkular Trinukleotida: [('CCT', 'AGT')]
# Kata Sikel yang terbentuk: ('CCTAGT', 'CTAGTC', 'TAGTCC')
#
# 128. Himpunan Sirkular Trinukleotida: [('CCT', 'GTA')]
# Kata Sikel yang terbentuk: ('CCTGTA', 'CTGTAC', 'TGTACC')
#
# 129. Himpunan Sirkular Trinukleotida: [('CTC', 'TAG')]
# Kata Sikel yang terbentuk: ('CTCTAG', 'TCTAGC', 'CTAGCT')
#
# 130. Himpunan Sirkular Trinukleotida: [('CTC', 'AGT')]
# Kata Sikel yang terbentuk: ('CTCAGT', 'TCAGTC', 'CAGTCT')
#
# 131. Himpunan Sirkular Trinukleotida: [('CTC', 'GTA')]
# Kata Sikel yang terbentuk: ('CTCGTA', 'TCGTAC', 'CGTACT')
#
# 132. Himpunan Sirkular Trinukleotida: [('TCC', 'TAG')]
# Kata Sikel yang terbentuk: ('TCCTAG', 'CCTAGT', 'CTAGTC')
#
# 133. Himpunan Sirkular Trinukleotida: [('TCC', 'AGT')]
# Kata Sikel yang terbentuk: ('TCCAGT', 'CCAGTT', 'CAGTTC')
#
# 134. Himpunan Sirkular Trinukleotida: [('TCC', 'GTA')]
# Kata Sikel yang terbentuk: ('TCCGTA', 'CCGTAT', 'CGTATC')
#
# 135. Himpunan Sirkular Trinukleotida: [('CCT', 'TGA')]
# Kata Sikel yang terbentuk: ('CCTTGA', 'CTTGAC', 'TTGACC')
#
# 136. Himpunan Sirkular Trinukleotida: [('CCT', 'GAT')]
# Kata Sikel yang terbentuk: ('CCTGAT', 'CTGATC', 'TGATCC')
#
# 137. Himpunan Sirkular Trinukleotida: [('CCT', 'ATG')]
# Kata Sikel yang terbentuk: ('CCTATG', 'CTATGC', 'TATGCC')
#
# 138. Himpunan Sirkular Trinukleotida: [('CTC', 'TGA')]
# Kata Sikel yang terbentuk: ('CTCTGA', 'TCTGAC', 'CTGACT')
#
# 139. Himpunan Sirkular Trinukleotida: [('CTC', 'GAT')]
# Kata Sikel yang terbentuk: ('CTCGAT', 'TCGATC', 'CGATCT')
#
# 140. Himpunan Sirkular Trinukleotida: [('CTC', 'ATG')]
# Kata Sikel yang terbentuk: ('CTCATG', 'TCATGC', 'CATGCT')
#
# 141. Himpunan Sirkular Trinukleotida: [('TCC', 'TGA')]
# Kata Sikel yang terbentuk: ('TCCTGA', 'CCTGAT', 'CTGATC')
#
# 142. Himpunan Sirkular Trinukleotida: [('TCC', 'GAT')]
# Kata Sikel yang terbentuk: ('TCCGAT', 'CCGATT', 'CGATTC')
#
# 143. Himpunan Sirkular Trinukleotida: [('TCC', 'ATG')]
# Kata Sikel yang terbentuk: ('TCCATG', 'CCATGT', 'CATGTC')
#
# 144. Himpunan Sirkular Trinukleotida: [('CCT', 'TGG')]
# Kata Sikel yang terbentuk: ('CCTTGG', 'CTTGGC', 'TTGGCC')
#
# 145. Himpunan Sirkular Trinukleotida: [('CCT', 'GGT')]
# Kata Sikel yang terbentuk: ('CCTGGT', 'CTGGTC', 'TGGTCC')
#
# 146. Himpunan Sirkular Trinukleotida: [('CCT', 'GTG')]
# Kata Sikel yang terbentuk: ('CCTGTG', 'CTGTGC', 'TGTGCC')
#
# 147. Himpunan Sirkular Trinukleotida: [('CTC', 'TGG')]
# Kata Sikel yang terbentuk: ('CTCTGG', 'TCTGGC', 'CTGGCT')
#
# 148. Himpunan Sirkular Trinukleotida: [('CTC', 'GGT')]
# Kata Sikel yang terbentuk: ('CTCGGT', 'TCGGTC', 'CGGTCT')
#
# 149. Himpunan Sirkular Trinukleotida: [('CTC', 'GTG')]
# Kata Sikel yang terbentuk: ('CTCGTG', 'TCGTGC', 'CGTGCT')
#
# 150. Himpunan Sirkular Trinukleotida: [('TCC', 'TGG')]
# Kata Sikel yang terbentuk: ('TCCTGG', 'CCTGGT', 'CTGGTC')
#
# 151. Himpunan Sirkular Trinukleotida: [('TCC', 'GGT')]
# Kata Sikel yang terbentuk: ('TCCGGT', 'CCGGTT', 'CGGTTC')
#
# 152. Himpunan Sirkular Trinukleotida: [('TCC', 'GTG')]
# Kata Sikel yang terbentuk: ('TCCGTG', 'CCGTGT', 'CGTGTC')
#
# 153. Himpunan Sirkular Trinukleotida: [('CCT', 'AAG')]
# Kata Sikel yang terbentuk: ('CCTAAG', 'CTAAGC', 'TAAGCC')
#
# 154. Himpunan Sirkular Trinukleotida: [('CCT', 'AGA')]
# Kata Sikel yang terbentuk: ('CCTAGA', 'CTAGAC', 'TAGACC')
#
# 155. Himpunan Sirkular Trinukleotida: [('CCT', 'GAA')]
# Kata Sikel yang terbentuk: ('CCTGAA', 'CTGAAC', 'TGAACC')
#
# 156. Himpunan Sirkular Trinukleotida: [('CTC', 'AAG')]
# Kata Sikel yang terbentuk: ('CTCAAG', 'TCAAGC', 'CAAGCT')
#
# 157. Himpunan Sirkular Trinukleotida: [('CTC', 'AGA')]
# Kata Sikel yang terbentuk: ('CTCAGA', 'TCAGAC', 'CAGACT')
#
# 158. Himpunan Sirkular Trinukleotida: [('CTC', 'GAA')]
# Kata Sikel yang terbentuk: ('CTCGAA', 'TCGAAC', 'CGAACT')
#
# 159. Himpunan Sirkular Trinukleotida: [('TCC', 'AAG')]
# Kata Sikel yang terbentuk: ('TCCAAG', 'CCAAGT', 'CAAGTC')
#
# 160. Himpunan Sirkular Trinukleotida: [('TCC', 'AGA')]
# Kata Sikel yang terbentuk: ('TCCAGA', 'CCAGAT', 'CAGATC')
#
# 161. Himpunan Sirkular Trinukleotida: [('TCC', 'GAA')]
# Kata Sikel yang terbentuk: ('TCCGAA', 'CCGAAT', 'CGAATC')
#
# 162. Himpunan Sirkular Trinukleotida: [('CCT', 'AGG')]
# Kata Sikel yang terbentuk: ('CCTAGG', 'CTAGGC', 'TAGGCC')
#
# 163. Himpunan Sirkular Trinukleotida: [('CCT', 'GGA')]
# Kata Sikel yang terbentuk: ('CCTGGA', 'CTGGAC', 'TGGACC')
#
# 164. Himpunan Sirkular Trinukleotida: [('CCT', 'GAG')]
# Kata Sikel yang terbentuk: ('CCTGAG', 'CTGAGC', 'TGAGCC')
#
# 165. Himpunan Sirkular Trinukleotida: [('CTC', 'AGG')]
# Kata Sikel yang terbentuk: ('CTCAGG', 'TCAGGC', 'CAGGCT')
#
# 166. Himpunan Sirkular Trinukleotida: [('CTC', 'GGA')]
# Kata Sikel yang terbentuk: ('CTCGGA', 'TCGGAC', 'CGGACT')
#
# 167. Himpunan Sirkular Trinukleotida: [('CTC', 'GAG')]
# Kata Sikel yang terbentuk: ('CTCGAG', 'TCGAGC', 'CGAGCT')
#
# 168. Himpunan Sirkular Trinukleotida: [('TCC', 'AGG')]
# Kata Sikel yang terbentuk: ('TCCAGG', 'CCAGGT', 'CAGGTC')
#
# 169. Himpunan Sirkular Trinukleotida: [('TCC', 'GGA')]
# Kata Sikel yang terbentuk: ('TCCGGA', 'CCGGAT', 'CGGATC')
#
# 170. Himpunan Sirkular Trinukleotida: [('TCC', 'GAG')]
# Kata Sikel yang terbentuk: ('TCCGAG', 'CCGAGT', 'CGAGTC')
#
# 171. Himpunan Sirkular Trinukleotida: [('CCA', 'CCG')]
# Kata Sikel yang terbentuk: ('CCACCG', 'CACCGC', 'ACCGCC')
#
# 172. Himpunan Sirkular Trinukleotida: [('CCA', 'CGC')]
# Kata Sikel yang terbentuk: ('CCACGC', 'CACGCC', 'ACGCCC')
#
# 173. Himpunan Sirkular Trinukleotida: [('CCA', 'GCC')]
# Kata Sikel yang terbentuk: ('CCAGCC', 'CAGCCC', 'AGCCCC')
#
# 174. Himpunan Sirkular Trinukleotida: [('CAC', 'CCG')]
# Kata Sikel yang terbentuk: ('CACCCG', 'ACCCGC', 'CCCGCA')
#
# 175. Himpunan Sirkular Trinukleotida: [('CAC', 'CGC')]
# Kata Sikel yang terbentuk: ('CACCGC', 'ACCGCC', 'CCGCCA')
#
# 176. Himpunan Sirkular Trinukleotida: [('CAC', 'GCC')]
# Kata Sikel yang terbentuk: ('CACGCC', 'ACGCCC', 'CGCCCA')
#
# 177. Himpunan Sirkular Trinukleotida: [('ACC', 'CCG')]
# Kata Sikel yang terbentuk: ('ACCCCG', 'CCCCGA', 'CCCGAC')
#
# 178. Himpunan Sirkular Trinukleotida: [('ACC', 'CGC')]
# Kata Sikel yang terbentuk: ('ACCCGC', 'CCCGCA', 'CCGCAC')
#
# 179. Himpunan Sirkular Trinukleotida: [('ACC', 'GCC')]
# Kata Sikel yang terbentuk: ('ACCGCC', 'CCGCCA', 'CGCCAC')
#
# 180. Himpunan Sirkular Trinukleotida: [('CCA', 'CTT')]
# Kata Sikel yang terbentuk: ('CCACTT', 'CACTTC', 'ACTTCC')
#
# 181. Himpunan Sirkular Trinukleotida: [('CCA', 'TTC')]
# Kata Sikel yang terbentuk: ('CCATTC', 'CATTCC', 'ATTCCC')
#
# 182. Himpunan Sirkular Trinukleotida: [('CCA', 'TCT')]
# Kata Sikel yang terbentuk: ('CCATCT', 'CATCTC', 'ATCTCC')
#
# 183. Himpunan Sirkular Trinukleotida: [('CAC', 'CTT')]
# Kata Sikel yang terbentuk: ('CACCTT', 'ACCTTC', 'CCTTCA')
#
# 184. Himpunan Sirkular Trinukleotida: [('CAC', 'TTC')]
# Kata Sikel yang terbentuk: ('CACTTC', 'ACTTCC', 'CTTCCA')
#
# 185. Himpunan Sirkular Trinukleotida: [('CAC', 'TCT')]
# Kata Sikel yang terbentuk: ('CACTCT', 'ACTCTC', 'CTCTCA')
#
# 186. Himpunan Sirkular Trinukleotida: [('ACC', 'CTT')]
# Kata Sikel yang terbentuk: ('ACCCTT', 'CCCTTA', 'CCTTAC')
#
# 187. Himpunan Sirkular Trinukleotida: [('ACC', 'TTC')]
# Kata Sikel yang terbentuk: ('ACCTTC', 'CCTTCA', 'CTTCAC')
#
# 188. Himpunan Sirkular Trinukleotida: [('ACC', 'TCT')]
# Kata Sikel yang terbentuk: ('ACCTCT', 'CCTCTA', 'CTCTAC')
#
# 189. Himpunan Sirkular Trinukleotida: [('CCA', 'CTA')]
# Kata Sikel yang terbentuk: ('CCACTA', 'CACTAC', 'ACTACC')
#
# 190. Himpunan Sirkular Trinukleotida: [('CCA', 'TAC')]
# Kata Sikel yang terbentuk: ('CCATAC', 'CATACC', 'ATACCC')
#
# 191. Himpunan Sirkular Trinukleotida: [('CCA', 'ACT')]
# Kata Sikel yang terbentuk: ('CCAACT', 'CAACTC', 'AACTCC')
#
# 192. Himpunan Sirkular Trinukleotida: [('CAC', 'CTA')]
# Kata Sikel yang terbentuk: ('CACCTA', 'ACCTAC', 'CCTACA')
#
# 193. Himpunan Sirkular Trinukleotida: [('CAC', 'TAC')]
# Kata Sikel yang terbentuk: ('CACTAC', 'ACTACC', 'CTACCA')
#
# 194. Himpunan Sirkular Trinukleotida: [('CAC', 'ACT')]
# Kata Sikel yang terbentuk: ('CACACT', 'ACACTC', 'CACTCA')
#
# 195. Himpunan Sirkular Trinukleotida: [('ACC', 'CTA')]
# Kata Sikel yang terbentuk: ('ACCCTA', 'CCCTAA', 'CCTAAC')
#
# 196. Himpunan Sirkular Trinukleotida: [('ACC', 'TAC')]
# Kata Sikel yang terbentuk: ('ACCTAC', 'CCTACA', 'CTACAC')
#
# 197. Himpunan Sirkular Trinukleotida: [('ACC', 'ACT')]
# Kata Sikel yang terbentuk: ('ACCACT', 'CCACTA', 'CACTAC')
#
# 198. Himpunan Sirkular Trinukleotida: [('CCA', 'CTG')]
# Kata Sikel yang terbentuk: ('CCACTG', 'CACTGC', 'ACTGCC')
#
# 199. Himpunan Sirkular Trinukleotida: [('CCA', 'TGC')]
# Kata Sikel yang terbentuk: ('CCATGC', 'CATGCC', 'ATGCCC')
#
# 200. Himpunan Sirkular Trinukleotida: [('CCA', 'GCT')]
# Kata Sikel yang terbentuk: ('CCAGCT', 'CAGCTC', 'AGCTCC')
#
# 201. Himpunan Sirkular Trinukleotida: [('CAC', 'CTG')]
# Kata Sikel yang terbentuk: ('CACCTG', 'ACCTGC', 'CCTGCA')
#
# 202. Himpunan Sirkular Trinukleotida: [('CAC', 'TGC')]
# Kata Sikel yang terbentuk: ('CACTGC', 'ACTGCC', 'CTGCCA')
#
# 203. Himpunan Sirkular Trinukleotida: [('CAC', 'GCT')]
# Kata Sikel yang terbentuk: ('CACGCT', 'ACGCTC', 'CGCTCA')
#
# 204. Himpunan Sirkular Trinukleotida: [('ACC', 'CTG')]
# Kata Sikel yang terbentuk: ('ACCCTG', 'CCCTGA', 'CCTGAC')
#
# 205. Himpunan Sirkular Trinukleotida: [('ACC', 'TGC')]
# Kata Sikel yang terbentuk: ('ACCTGC', 'CCTGCA', 'CTGCAC')
#
# 206. Himpunan Sirkular Trinukleotida: [('ACC', 'GCT')]
# Kata Sikel yang terbentuk: ('ACCGCT', 'CCGCTA', 'CGCTAC')
#
# 207. Himpunan Sirkular Trinukleotida: [('CCA', 'CAT')]
# Kata Sikel yang terbentuk: ('CCACAT', 'CACATC', 'ACATCC')
#
# 208. Himpunan Sirkular Trinukleotida: [('CCA', 'ATC')]
# Kata Sikel yang terbentuk: ('CCAATC', 'CAATCC', 'AATCCC')
#
# 209. Himpunan Sirkular Trinukleotida: [('CCA', 'TCA')]
# Kata Sikel yang terbentuk: ('CCATCA', 'CATCAC', 'ATCACC')
#
# 210. Himpunan Sirkular Trinukleotida: [('CAC', 'CAT')]
# Kata Sikel yang terbentuk: ('CACCAT', 'ACCATC', 'CCATCA')
#
# 211. Himpunan Sirkular Trinukleotida: [('CAC', 'ATC')]
# Kata Sikel yang terbentuk: ('CACATC', 'ACATCC', 'CATCCA')
#
# 212. Himpunan Sirkular Trinukleotida: [('CAC', 'TCA')]
# Kata Sikel yang terbentuk: ('CACTCA', 'ACTCAC', 'CTCACA')
#
# 213. Himpunan Sirkular Trinukleotida: [('ACC', 'CAT')]
# Kata Sikel yang terbentuk: ('ACCCAT', 'CCCATA', 'CCATAC')
#
# 214. Himpunan Sirkular Trinukleotida: [('ACC', 'ATC')]
# Kata Sikel yang terbentuk: ('ACCATC', 'CCATCA', 'CATCAC')
#
# 215. Himpunan Sirkular Trinukleotida: [('ACC', 'TCA')]
# Kata Sikel yang terbentuk: ('ACCTCA', 'CCTCAA', 'CTCAAC')
#
# 216. Himpunan Sirkular Trinukleotida: [('CCA', 'CAA')]
# Kata Sikel yang terbentuk: ('CCACAA', 'CACAAC', 'ACAACC')
#
# 217. Himpunan Sirkular Trinukleotida: [('CCA', 'AAC')]
# Kata Sikel yang terbentuk: ('CCAAAC', 'CAAACC', 'AAACCC')
#
# 218. Himpunan Sirkular Trinukleotida: [('CCA', 'ACA')]
# Kata Sikel yang terbentuk: ('CCAACA', 'CAACAC', 'AACACC')
#
# 219. Himpunan Sirkular Trinukleotida: [('CAC', 'CAA')]
# Kata Sikel yang terbentuk: ('CACCAA', 'ACCAAC', 'CCAACA')
#
# 220. Himpunan Sirkular Trinukleotida: [('CAC', 'AAC')]
# Kata Sikel yang terbentuk: ('CACAAC', 'ACAACC', 'CAACCA')
#
# 221. Himpunan Sirkular Trinukleotida: [('ACC', 'CAA')]
# Kata Sikel yang terbentuk: ('ACCCAA', 'CCCAAA', 'CCAAAC')
#
# 222. Himpunan Sirkular Trinukleotida: [('ACC', 'AAC')]
# Kata Sikel yang terbentuk: ('ACCAAC', 'CCAACA', 'CAACAC')
#
# 223. Himpunan Sirkular Trinukleotida: [('ACC', 'ACA')]
# Kata Sikel yang terbentuk: ('ACCACA', 'CCACAA', 'CACAAC')
#
# 224. Himpunan Sirkular Trinukleotida: [('CCA', 'CAG')]
# Kata Sikel yang terbentuk: ('CCACAG', 'CACAGC', 'ACAGCC')
#
# 225. Himpunan Sirkular Trinukleotida: [('CCA', 'AGC')]
# Kata Sikel yang terbentuk: ('CCAAGC', 'CAAGCC', 'AAGCCC')
#
# 226. Himpunan Sirkular Trinukleotida: [('CCA', 'GCA')]
# Kata Sikel yang terbentuk: ('CCAGCA', 'CAGCAC', 'AGCACC')
#
# 227. Himpunan Sirkular Trinukleotida: [('CAC', 'CAG')]
# Kata Sikel yang terbentuk: ('CACCAG', 'ACCAGC', 'CCAGCA')
#
# 228. Himpunan Sirkular Trinukleotida: [('CAC', 'AGC')]
# Kata Sikel yang terbentuk: ('CACAGC', 'ACAGCC', 'CAGCCA')
#
# 229. Himpunan Sirkular Trinukleotida: [('CAC', 'GCA')]
# Kata Sikel yang terbentuk: ('CACGCA', 'ACGCAC', 'CGCACA')
#
# 230. Himpunan Sirkular Trinukleotida: [('ACC', 'CAG')]
# Kata Sikel yang terbentuk: ('ACCCAG', 'CCCAGA', 'CCAGAC')
#
# 231. Himpunan Sirkular Trinukleotida: [('ACC', 'AGC')]
# Kata Sikel yang terbentuk: ('ACCAGC', 'CCAGCA', 'CAGCAC')
#
# 232. Himpunan Sirkular Trinukleotida: [('ACC', 'GCA')]
# Kata Sikel yang terbentuk: ('ACCGCA', 'CCGCAA', 'CGCAAC')
#
# 233. Himpunan Sirkular Trinukleotida: [('CCA', 'CGT')]
# Kata Sikel yang terbentuk: ('CCACGT', 'CACGTC', 'ACGTCC')
#
# 234. Himpunan Sirkular Trinukleotida: [('CCA', 'GTC')]
# Kata Sikel yang terbentuk: ('CCAGTC', 'CAGTCC', 'AGTCCC')
#
# 235. Himpunan Sirkular Trinukleotida: [('CCA', 'TCG')]
# Kata Sikel yang terbentuk: ('CCATCG', 'CATCGC', 'ATCGCC')
#
# 236. Himpunan Sirkular Trinukleotida: [('CAC', 'CGT')]
# Kata Sikel yang terbentuk: ('CACCGT', 'ACCGTC', 'CCGTCA')
#
# 237. Himpunan Sirkular Trinukleotida: [('CAC', 'GTC')]
# Kata Sikel yang terbentuk: ('CACGTC', 'ACGTCC', 'CGTCCA')
#
# 238. Himpunan Sirkular Trinukleotida: [('CAC', 'TCG')]
# Kata Sikel yang terbentuk: ('CACTCG', 'ACTCGC', 'CTCGCA')
#
# 239. Himpunan Sirkular Trinukleotida: [('ACC', 'CGT')]
# Kata Sikel yang terbentuk: ('ACCCGT', 'CCCGTA', 'CCGTAC')
#
# 240. Himpunan Sirkular Trinukleotida: [('ACC', 'GTC')]
# Kata Sikel yang terbentuk: ('ACCGTC', 'CCGTCA', 'CGTCAC')
#
# 241. Himpunan Sirkular Trinukleotida: [('ACC', 'TCG')]
# Kata Sikel yang terbentuk: ('ACCTCG', 'CCTCGA', 'CTCGAC')
#
# 242. Himpunan Sirkular Trinukleotida: [('CCA', 'CGA')]
# Kata Sikel yang terbentuk: ('CCACGA', 'CACGAC', 'ACGACC')
#
# 243. Himpunan Sirkular Trinukleotida: [('CCA', 'GAC')]
# Kata Sikel yang terbentuk: ('CCAGAC', 'CAGACC', 'AGACCC')
#
# 244. Himpunan Sirkular Trinukleotida: [('CCA', 'ACG')]
# Kata Sikel yang terbentuk: ('CCAACG', 'CAACGC', 'AACGCC')
#
# 245. Himpunan Sirkular Trinukleotida: [('CAC', 'CGA')]
# Kata Sikel yang terbentuk: ('CACCGA', 'ACCGAC', 'CCGACA')
#
# 246. Himpunan Sirkular Trinukleotida: [('CAC', 'GAC')]
# Kata Sikel yang terbentuk: ('CACGAC', 'ACGACC', 'CGACCA')
#
# 247. Himpunan Sirkular Trinukleotida: [('CAC', 'ACG')]
# Kata Sikel yang terbentuk: ('CACACG', 'ACACGC', 'CACGCA')
#
# 248. Himpunan Sirkular Trinukleotida: [('ACC', 'CGA')]
# Kata Sikel yang terbentuk: ('ACCCGA', 'CCCGAA', 'CCGAAC')
#
# 249. Himpunan Sirkular Trinukleotida: [('ACC', 'GAC')]
# Kata Sikel yang terbentuk: ('ACCGAC', 'CCGACA', 'CGACAC')
#
# 250. Himpunan Sirkular Trinukleotida: [('ACC', 'ACG')]
# Kata Sikel yang terbentuk: ('ACCACG', 'CCACGA', 'CACGAC')
#
# 251. Himpunan Sirkular Trinukleotida: [('CCA', 'CGG')]
# Kata Sikel yang terbentuk: ('CCACGG', 'CACGGC', 'ACGGCC')
#
# 252. Himpunan Sirkular Trinukleotida: [('CCA', 'GGC')]
# Kata Sikel yang terbentuk: ('CCAGGC', 'CAGGCC', 'AGGCCC')
#
# 253. Himpunan Sirkular Trinukleotida: [('CCA', 'GCG')]
# Kata Sikel yang terbentuk: ('CCAGCG', 'CAGCGC', 'AGCGCC')
#
# 254. Himpunan Sirkular Trinukleotida: [('CAC', 'CGG')]
# Kata Sikel yang terbentuk: ('CACCGG', 'ACCGGC', 'CCGGCA')
#
# 255. Himpunan Sirkular Trinukleotida: [('CAC', 'GGC')]
# Kata Sikel yang terbentuk: ('CACGGC', 'ACGGCC', 'CGGCCA')
#
# 256. Himpunan Sirkular Trinukleotida: [('CAC', 'GCG')]
# Kata Sikel yang terbentuk: ('CACGCG', 'ACGCGC', 'CGCGCA')
#
# 257. Himpunan Sirkular Trinukleotida: [('ACC', 'CGG')]
# Kata Sikel yang terbentuk: ('ACCCGG', 'CCCGGA', 'CCGGAC')
#
# 258. Himpunan Sirkular Trinukleotida: [('ACC', 'GGC')]
# Kata Sikel yang terbentuk: ('ACCGGC', 'CCGGCA', 'CGGCAC')
#
# 259. Himpunan Sirkular Trinukleotida: [('ACC', 'GCG')]
# Kata Sikel yang terbentuk: ('ACCGCG', 'CCGCGA', 'CGCGAC')
#
# 260. Himpunan Sirkular Trinukleotida: [('CCA', 'TTA')]
# Kata Sikel yang terbentuk: ('CCATTA', 'CATTAC', 'ATTACC')
#
# 261. Himpunan Sirkular Trinukleotida: [('CCA', 'TAT')]
# Kata Sikel yang terbentuk: ('CCATAT', 'CATATC', 'ATATCC')
#
# 262. Himpunan Sirkular Trinukleotida: [('CCA', 'ATT')]
# Kata Sikel yang terbentuk: ('CCAATT', 'CAATTC', 'AATTCC')
#
# 263. Himpunan Sirkular Trinukleotida: [('CAC', 'TTA')]
# Kata Sikel yang terbentuk: ('CACTTA', 'ACTTAC', 'CTTACA')
#
# 264. Himpunan Sirkular Trinukleotida: [('CAC', 'TAT')]
# Kata Sikel yang terbentuk: ('CACTAT', 'ACTATC', 'CTATCA')
#
# 265. Himpunan Sirkular Trinukleotida: [('CAC', 'ATT')]
# Kata Sikel yang terbentuk: ('CACATT', 'ACATTC', 'CATTCA')
#
# 266. Himpunan Sirkular Trinukleotida: [('ACC', 'TTA')]
# Kata Sikel yang terbentuk: ('ACCTTA', 'CCTTAA', 'CTTAAC')
#
# 267. Himpunan Sirkular Trinukleotida: [('ACC', 'TAT')]
# Kata Sikel yang terbentuk: ('ACCTAT', 'CCTATA', 'CTATAC')
#
# 268. Himpunan Sirkular Trinukleotida: [('ACC', 'ATT')]
# Kata Sikel yang terbentuk: ('ACCATT', 'CCATTA', 'CATTAC')
#
# 269. Himpunan Sirkular Trinukleotida: [('CCA', 'TTG')]
# Kata Sikel yang terbentuk: ('CCATTG', 'CATTGC', 'ATTGCC')
#
# 270. Himpunan Sirkular Trinukleotida: [('CCA', 'TGT')]
# Kata Sikel yang terbentuk: ('CCATGT', 'CATGTC', 'ATGTCC')
#
# 271. Himpunan Sirkular Trinukleotida: [('CCA', 'GTT')]
# Kata Sikel yang terbentuk: ('CCAGTT', 'CAGTTC', 'AGTTCC')
#
# 272. Himpunan Sirkular Trinukleotida: [('CAC', 'TTG')]
# Kata Sikel yang terbentuk: ('CACTTG', 'ACTTGC', 'CTTGCA')
#
# 273. Himpunan Sirkular Trinukleotida: [('CAC', 'TGT')]
# Kata Sikel yang terbentuk: ('CACTGT', 'ACTGTC', 'CTGTCA')
#
# 274. Himpunan Sirkular Trinukleotida: [('CAC', 'GTT')]
# Kata Sikel yang terbentuk: ('CACGTT', 'ACGTTC', 'CGTTCA')
#
# 275. Himpunan Sirkular Trinukleotida: [('ACC', 'TTG')]
# Kata Sikel yang terbentuk: ('ACCTTG', 'CCTTGA', 'CTTGAC')
#
# 276. Himpunan Sirkular Trinukleotida: [('ACC', 'TGT')]
# Kata Sikel yang terbentuk: ('ACCTGT', 'CCTGTA', 'CTGTAC')
#
# 277. Himpunan Sirkular Trinukleotida: [('ACC', 'GTT')]
# Kata Sikel yang terbentuk: ('ACCGTT', 'CCGTTA', 'CGTTAC')
#
# 278. Himpunan Sirkular Trinukleotida: [('CCA', 'TAA')]
# Kata Sikel yang terbentuk: ('CCATAA', 'CATAAC', 'ATAACC')
#
# 279. Himpunan Sirkular Trinukleotida: [('CCA', 'AAT')]
# Kata Sikel yang terbentuk: ('CCAAAT', 'CAAATC', 'AAATCC')
#
# 280. Himpunan Sirkular Trinukleotida: [('CCA', 'ATA')]
# Kata Sikel yang terbentuk: ('CCAATA', 'CAATAC', 'AATACC')
#
# 281. Himpunan Sirkular Trinukleotida: [('CAC', 'TAA')]
# Kata Sikel yang terbentuk: ('CACTAA', 'ACTAAC', 'CTAACA')
#
# 282. Himpunan Sirkular Trinukleotida: [('CAC', 'AAT')]
# Kata Sikel yang terbentuk: ('CACAAT', 'ACAATC', 'CAATCA')
#
# 283. Himpunan Sirkular Trinukleotida: [('CAC', 'ATA')]
# Kata Sikel yang terbentuk: ('CACATA', 'ACATAC', 'CATACA')
#
# 284. Himpunan Sirkular Trinukleotida: [('ACC', 'TAA')]
# Kata Sikel yang terbentuk: ('ACCTAA', 'CCTAAA', 'CTAAAC')
#
# 285. Himpunan Sirkular Trinukleotida: [('ACC', 'AAT')]
# Kata Sikel yang terbentuk: ('ACCAAT', 'CCAATA', 'CAATAC')
#
# 286. Himpunan Sirkular Trinukleotida: [('ACC', 'ATA')]
# Kata Sikel yang terbentuk: ('ACCATA', 'CCATAA', 'CATAAC')
#
# 287. Himpunan Sirkular Trinukleotida: [('CCA', 'TAG')]
# Kata Sikel yang terbentuk: ('CCATAG', 'CATAGC', 'ATAGCC')
#
# 288. Himpunan Sirkular Trinukleotida: [('CCA', 'AGT')]
# Kata Sikel yang terbentuk: ('CCAAGT', 'CAAGTC', 'AAGTCC')
#
# 289. Himpunan Sirkular Trinukleotida: [('CCA', 'GTA')]
# Kata Sikel yang terbentuk: ('CCAGTA', 'CAGTAC', 'AGTACC')
#
# 290. Himpunan Sirkular Trinukleotida: [('CAC', 'TAG')]
# Kata Sikel yang terbentuk: ('CACTAG', 'ACTAGC', 'CTAGCA')
#
# 291. Himpunan Sirkular Trinukleotida: [('CAC', 'AGT')]
# Kata Sikel yang terbentuk: ('CACAGT', 'ACAGTC', 'CAGTCA')
#
# 292. Himpunan Sirkular Trinukleotida: [('CAC', 'GTA')]
# Kata Sikel yang terbentuk: ('CACGTA', 'ACGTAC', 'CGTACA')
#
# 293. Himpunan Sirkular Trinukleotida: [('ACC', 'TAG')]
# Kata Sikel yang terbentuk: ('ACCTAG', 'CCTAGA', 'CTAGAC')
#
# 294. Himpunan Sirkular Trinukleotida: [('ACC', 'AGT')]
# Kata Sikel yang terbentuk: ('ACCAGT', 'CCAGTA', 'CAGTAC')
#
# 295. Himpunan Sirkular Trinukleotida: [('ACC', 'GTA')]
# Kata Sikel yang terbentuk: ('ACCGTA', 'CCGTAA', 'CGTAAC')
#
# 296. Himpunan Sirkular Trinukleotida: [('CCA', 'TGA')]
# Kata Sikel yang terbentuk: ('CCATGA', 'CATGAC', 'ATGACC')
#
# 297. Himpunan Sirkular Trinukleotida: [('CCA', 'GAT')]
# Kata Sikel yang terbentuk: ('CCAGAT', 'CAGATC', 'AGATCC')
#
# 298. Himpunan Sirkular Trinukleotida: [('CCA', 'ATG')]
# Kata Sikel yang terbentuk: ('CCAATG', 'CAATGC', 'AATGCC')
#
# 299. Himpunan Sirkular Trinukleotida: [('CAC', 'TGA')]
# Kata Sikel yang terbentuk: ('CACTGA', 'ACTGAC', 'CTGACA')
#
# 300. Himpunan Sirkular Trinukleotida: [('CAC', 'GAT')]
# Kata Sikel yang terbentuk: ('CACGAT', 'ACGATC', 'CGATCA')
#
# 301. Himpunan Sirkular Trinukleotida: [('CAC', 'ATG')]
# Kata Sikel yang terbentuk: ('CACATG', 'ACATGC', 'CATGCA')
#
# 302. Himpunan Sirkular Trinukleotida: [('ACC', 'TGA')]
# Kata Sikel yang terbentuk: ('ACCTGA', 'CCTGAA', 'CTGAAC')
#
# 303. Himpunan Sirkular Trinukleotida: [('ACC', 'GAT')]
# Kata Sikel yang terbentuk: ('ACCGAT', 'CCGATA', 'CGATAC')
#
# 304. Himpunan Sirkular Trinukleotida: [('ACC', 'ATG')]
# Kata Sikel yang terbentuk: ('ACCATG', 'CCATGA', 'CATGAC')
#
# 305. Himpunan Sirkular Trinukleotida: [('CCA', 'TGG')]
# Kata Sikel yang terbentuk: ('CCATGG', 'CATGGC', 'ATGGCC')
#
# 306. Himpunan Sirkular Trinukleotida: [('CCA', 'GGT')]
# Kata Sikel yang terbentuk: ('CCAGGT', 'CAGGTC', 'AGGTCC')
#
# 307. Himpunan Sirkular Trinukleotida: [('CCA', 'GTG')]
# Kata Sikel yang terbentuk: ('CCAGTG', 'CAGTGC', 'AGTGCC')
#
# 308. Himpunan Sirkular Trinukleotida: [('CAC', 'TGG')]
# Kata Sikel yang terbentuk: ('CACTGG', 'ACTGGC', 'CTGGCA')
#
# 309. Himpunan Sirkular Trinukleotida: [('CAC', 'GGT')]
# Kata Sikel yang terbentuk: ('CACGGT', 'ACGGTC', 'CGGTCA')
#
# 310. Himpunan Sirkular Trinukleotida: [('CAC', 'GTG')]
# Kata Sikel yang terbentuk: ('CACGTG', 'ACGTGC', 'CGTGCA')
#
# 311. Himpunan Sirkular Trinukleotida: [('ACC', 'TGG')]
# Kata Sikel yang terbentuk: ('ACCTGG', 'CCTGGA', 'CTGGAC')
#
# 312. Himpunan Sirkular Trinukleotida: [('ACC', 'GGT')]
# Kata Sikel yang terbentuk: ('ACCGGT', 'CCGGTA', 'CGGTAC')
#
# 313. Himpunan Sirkular Trinukleotida: [('ACC', 'GTG')]
# Kata Sikel yang terbentuk: ('ACCGTG', 'CCGTGA', 'CGTGAC')
#
# 314. Himpunan Sirkular Trinukleotida: [('CCA', 'AAG')]
# Kata Sikel yang terbentuk: ('CCAAAG', 'CAAAGC', 'AAAGCC')
#
# 315. Himpunan Sirkular Trinukleotida: [('CCA', 'AGA')]
# Kata Sikel yang terbentuk: ('CCAAGA', 'CAAGAC', 'AAGACC')
#
# 316. Himpunan Sirkular Trinukleotida: [('CCA', 'GAA')]
# Kata Sikel yang terbentuk: ('CCAGAA', 'CAGAAC', 'AGAACC')
#
# 317. Himpunan Sirkular Trinukleotida: [('CAC', 'AAG')]
# Kata Sikel yang terbentuk: ('CACAAG', 'ACAAGC', 'CAAGCA')
#
# 318. Himpunan Sirkular Trinukleotida: [('CAC', 'AGA')]
# Kata Sikel yang terbentuk: ('CACAGA', 'ACAGAC', 'CAGACA')
#
# 319. Himpunan Sirkular Trinukleotida: [('CAC', 'GAA')]
# Kata Sikel yang terbentuk: ('CACGAA', 'ACGAAC', 'CGAACA')
#
# 320. Himpunan Sirkular Trinukleotida: [('ACC', 'AAG')]
# Kata Sikel yang terbentuk: ('ACCAAG', 'CCAAGA', 'CAAGAC')
#
# 321. Himpunan Sirkular Trinukleotida: [('ACC', 'AGA')]
# Kata Sikel yang terbentuk: ('ACCAGA', 'CCAGAA', 'CAGAAC')
#
# 322. Himpunan Sirkular Trinukleotida: [('ACC', 'GAA')]
# Kata Sikel yang terbentuk: ('ACCGAA', 'CCGAAA', 'CGAAAC')
#
# 323. Himpunan Sirkular Trinukleotida: [('CCA', 'AGG')]
# Kata Sikel yang terbentuk: ('CCAAGG', 'CAAGGC', 'AAGGCC')
#
# 324. Himpunan Sirkular Trinukleotida: [('CCA', 'GGA')]
# Kata Sikel yang terbentuk: ('CCAGGA', 'CAGGAC', 'AGGACC')
#
# 325. Himpunan Sirkular Trinukleotida: [('CCA', 'GAG')]
# Kata Sikel yang terbentuk: ('CCAGAG', 'CAGAGC', 'AGAGCC')
#
# 326. Himpunan Sirkular Trinukleotida: [('CAC', 'AGG')]
# Kata Sikel yang terbentuk: ('CACAGG', 'ACAGGC', 'CAGGCA')
#
# 327. Himpunan Sirkular Trinukleotida: [('CAC', 'GGA')]
# Kata Sikel yang terbentuk: ('CACGGA', 'ACGGAC', 'CGGACA')
#
# 328. Himpunan Sirkular Trinukleotida: [('CAC', 'GAG')]
# Kata Sikel yang terbentuk: ('CACGAG', 'ACGAGC', 'CGAGCA')
#
# 329. Himpunan Sirkular Trinukleotida: [('ACC', 'AGG')]
# Kata Sikel yang terbentuk: ('ACCAGG', 'CCAGGA', 'CAGGAC')
#
# 330. Himpunan Sirkular Trinukleotida: [('ACC', 'GGA')]
# Kata Sikel yang terbentuk: ('ACCGGA', 'CCGGAA', 'CGGAAC')
#
# 331. Himpunan Sirkular Trinukleotida: [('ACC', 'GAG')]
# Kata Sikel yang terbentuk: ('ACCGAG', 'CCGAGA', 'CGAGAC')
#
# 332. Himpunan Sirkular Trinukleotida: [('CCG', 'CTT')]
# Kata Sikel yang terbentuk: ('CCGCTT', 'CGCTTC', 'GCTTCC')
#
# 333. Himpunan Sirkular Trinukleotida: [('CCG', 'TTC')]
# Kata Sikel yang terbentuk: ('CCGTTC', 'CGTTCC', 'GTTCCC')
#
# 334. Himpunan Sirkular Trinukleotida: [('CCG', 'TCT')]
# Kata Sikel yang terbentuk: ('CCGTCT', 'CGTCTC', 'GTCTCC')
#
# 335. Himpunan Sirkular Trinukleotida: [('CGC', 'CTT')]
# Kata Sikel yang terbentuk: ('CGCCTT', 'GCCTTC', 'CCTTCG')
#
# 336. Himpunan Sirkular Trinukleotida: [('CGC', 'TTC')]
# Kata Sikel yang terbentuk: ('CGCTTC', 'GCTTCC', 'CTTCCG')
#
# 337. Himpunan Sirkular Trinukleotida: [('CGC', 'TCT')]
# Kata Sikel yang terbentuk: ('CGCTCT', 'GCTCTC', 'CTCTCG')
#
# 338. Himpunan Sirkular Trinukleotida: [('GCC', 'CTT')]
# Kata Sikel yang terbentuk: ('GCCCTT', 'CCCTTG', 'CCTTGC')
#
# 339. Himpunan Sirkular Trinukleotida: [('GCC', 'TTC')]
# Kata Sikel yang terbentuk: ('GCCTTC', 'CCTTCG', 'CTTCGC')
#
# 340. Himpunan Sirkular Trinukleotida: [('GCC', 'TCT')]
# Kata Sikel yang terbentuk: ('GCCTCT', 'CCTCTG', 'CTCTGC')
#
# 341. Himpunan Sirkular Trinukleotida: [('CCG', 'CTA')]
# Kata Sikel yang terbentuk: ('CCGCTA', 'CGCTAC', 'GCTACC')
#
# 342. Himpunan Sirkular Trinukleotida: [('CCG', 'TAC')]
# Kata Sikel yang terbentuk: ('CCGTAC', 'CGTACC', 'GTACCC')
#
# 343. Himpunan Sirkular Trinukleotida: [('CCG', 'ACT')]
# Kata Sikel yang terbentuk: ('CCGACT', 'CGACTC', 'GACTCC')
#
# 344. Himpunan Sirkular Trinukleotida: [('CGC', 'CTA')]
# Kata Sikel yang terbentuk: ('CGCCTA', 'GCCTAC', 'CCTACG')
#
# 345. Himpunan Sirkular Trinukleotida: [('CGC', 'TAC')]
# Kata Sikel yang terbentuk: ('CGCTAC', 'GCTACC', 'CTACCG')
#
# 346. Himpunan Sirkular Trinukleotida: [('CGC', 'ACT')]
# Kata Sikel yang terbentuk: ('CGCACT', 'GCACTC', 'CACTCG')
#
# 347. Himpunan Sirkular Trinukleotida: [('GCC', 'CTA')]
# Kata Sikel yang terbentuk: ('GCCCTA', 'CCCTAG', 'CCTAGC')
#
# 348. Himpunan Sirkular Trinukleotida: [('GCC', 'TAC')]
# Kata Sikel yang terbentuk: ('GCCTAC', 'CCTACG', 'CTACGC')
#
# 349. Himpunan Sirkular Trinukleotida: [('GCC', 'ACT')]
# Kata Sikel yang terbentuk: ('GCCACT', 'CCACTG', 'CACTGC')
#
# 350. Himpunan Sirkular Trinukleotida: [('CCG', 'CTG')]
# Kata Sikel yang terbentuk: ('CCGCTG', 'CGCTGC', 'GCTGCC')
#
# 351. Himpunan Sirkular Trinukleotida: [('CCG', 'TGC')]
# Kata Sikel yang terbentuk: ('CCGTGC', 'CGTGCC', 'GTGCCC')
#
# 352. Himpunan Sirkular Trinukleotida: [('CCG', 'GCT')]
# Kata Sikel yang terbentuk: ('CCGGCT', 'CGGCTC', 'GGCTCC')
#
# 353. Himpunan Sirkular Trinukleotida: [('CGC', 'CTG')]
# Kata Sikel yang terbentuk: ('CGCCTG', 'GCCTGC', 'CCTGCG')
#
# 354. Himpunan Sirkular Trinukleotida: [('CGC', 'TGC')]
# Kata Sikel yang terbentuk: ('CGCTGC', 'GCTGCC', 'CTGCCG')
#
# 355. Himpunan Sirkular Trinukleotida: [('CGC', 'GCT')]
# Kata Sikel yang terbentuk: ('CGCGCT', 'GCGCTC', 'CGCTCG')
#
# 356. Himpunan Sirkular Trinukleotida: [('GCC', 'CTG')]
# Kata Sikel yang terbentuk: ('GCCCTG', 'CCCTGG', 'CCTGGC')
#
# 357. Himpunan Sirkular Trinukleotida: [('GCC', 'TGC')]
# Kata Sikel yang terbentuk: ('GCCTGC', 'CCTGCG', 'CTGCGC')
#
# 358. Himpunan Sirkular Trinukleotida: [('GCC', 'GCT')]
# Kata Sikel yang terbentuk: ('GCCGCT', 'CCGCTG', 'CGCTGC')
#
# 359. Himpunan Sirkular Trinukleotida: [('CCG', 'CAT')]
# Kata Sikel yang terbentuk: ('CCGCAT', 'CGCATC', 'GCATCC')
#
# 360. Himpunan Sirkular Trinukleotida: [('CCG', 'ATC')]
# Kata Sikel yang terbentuk: ('CCGATC', 'CGATCC', 'GATCCC')
#
# 361. Himpunan Sirkular Trinukleotida: [('CCG', 'TCA')]
# Kata Sikel yang terbentuk: ('CCGTCA', 'CGTCAC', 'GTCACC')
#
# 362. Himpunan Sirkular Trinukleotida: [('CGC', 'CAT')]
# Kata Sikel yang terbentuk: ('CGCCAT', 'GCCATC', 'CCATCG')
#
# 363. Himpunan Sirkular Trinukleotida: [('CGC', 'ATC')]
# Kata Sikel yang terbentuk: ('CGCATC', 'GCATCC', 'CATCCG')
#
# 364. Himpunan Sirkular Trinukleotida: [('CGC', 'TCA')]
# Kata Sikel yang terbentuk: ('CGCTCA', 'GCTCAC', 'CTCACG')
#
# 365. Himpunan Sirkular Trinukleotida: [('GCC', 'CAT')]
# Kata Sikel yang terbentuk: ('GCCCAT', 'CCCATG', 'CCATGC')
#
# 366. Himpunan Sirkular Trinukleotida: [('GCC', 'ATC')]
# Kata Sikel yang terbentuk: ('GCCATC', 'CCATCG', 'CATCGC')
#
# 367. Himpunan Sirkular Trinukleotida: [('GCC', 'TCA')]
# Kata Sikel yang terbentuk: ('GCCTCA', 'CCTCAG', 'CTCAGC')
#
# 368. Himpunan Sirkular Trinukleotida: [('CCG', 'CAA')]
# Kata Sikel yang terbentuk: ('CCGCAA', 'CGCAAC', 'GCAACC')
#
# 369. Himpunan Sirkular Trinukleotida: [('CCG', 'AAC')]
# Kata Sikel yang terbentuk: ('CCGAAC', 'CGAACC', 'GAACCC')
#
# 370. Himpunan Sirkular Trinukleotida: [('CCG', 'ACA')]
# Kata Sikel yang terbentuk: ('CCGACA', 'CGACAC', 'GACACC')
#
# 371. Himpunan Sirkular Trinukleotida: [('CGC', 'CAA')]
# Kata Sikel yang terbentuk: ('CGCCAA', 'GCCAAC', 'CCAACG')
#
# 372. Himpunan Sirkular Trinukleotida: [('CGC', 'AAC')]
# Kata Sikel yang terbentuk: ('CGCAAC', 'GCAACC', 'CAACCG')
#
# 373. Himpunan Sirkular Trinukleotida: [('CGC', 'ACA')]
# Kata Sikel yang terbentuk: ('CGCACA', 'GCACAC', 'CACACG')
#
# 374. Himpunan Sirkular Trinukleotida: [('GCC', 'CAA')]
# Kata Sikel yang terbentuk: ('GCCCAA', 'CCCAAG', 'CCAAGC')
#
# 375. Himpunan Sirkular Trinukleotida: [('GCC', 'AAC')]
# Kata Sikel yang terbentuk: ('GCCAAC', 'CCAACG', 'CAACGC')
#
# 376. Himpunan Sirkular Trinukleotida: [('GCC', 'ACA')]
# Kata Sikel yang terbentuk: ('GCCACA', 'CCACAG', 'CACAGC')
#
# 377. Himpunan Sirkular Trinukleotida: [('CCG', 'CAG')]
# Kata Sikel yang terbentuk: ('CCGCAG', 'CGCAGC', 'GCAGCC')
#
# 378. Himpunan Sirkular Trinukleotida: [('CCG', 'AGC')]
# Kata Sikel yang terbentuk: ('CCGAGC', 'CGAGCC', 'GAGCCC')
#
# 379. Himpunan Sirkular Trinukleotida: [('CCG', 'GCA')]
# Kata Sikel yang terbentuk: ('CCGGCA', 'CGGCAC', 'GGCACC')
#
# 380. Himpunan Sirkular Trinukleotida: [('CGC', 'CAG')]
# Kata Sikel yang terbentuk: ('CGCCAG', 'GCCAGC', 'CCAGCG')
#
# 381. Himpunan Sirkular Trinukleotida: [('CGC', 'AGC')]
# Kata Sikel yang terbentuk: ('CGCAGC', 'GCAGCC', 'CAGCCG')
#
# 382. Himpunan Sirkular Trinukleotida: [('CGC', 'GCA')]
# Kata Sikel yang terbentuk: ('CGCGCA', 'GCGCAC', 'CGCACG')
#
# 383. Himpunan Sirkular Trinukleotida: [('GCC', 'CAG')]
# Kata Sikel yang terbentuk: ('GCCCAG', 'CCCAGG', 'CCAGGC')
#
# 384. Himpunan Sirkular Trinukleotida: [('GCC', 'AGC')]
# Kata Sikel yang terbentuk: ('GCCAGC', 'CCAGCG', 'CAGCGC')
#
# 385. Himpunan Sirkular Trinukleotida: [('GCC', 'GCA')]
# Kata Sikel yang terbentuk: ('GCCGCA', 'CCGCAG', 'CGCAGC')
#
# 386. Himpunan Sirkular Trinukleotida: [('CCG', 'CGT')]
# Kata Sikel yang terbentuk: ('CCGCGT', 'CGCGTC', 'GCGTCC')
#
# 387. Himpunan Sirkular Trinukleotida: [('CCG', 'GTC')]
# Kata Sikel yang terbentuk: ('CCGGTC', 'CGGTCC', 'GGTCCC')
#
# 388. Himpunan Sirkular Trinukleotida: [('CCG', 'TCG')]
# Kata Sikel yang terbentuk: ('CCGTCG', 'CGTCGC', 'GTCGCC')
#
# 389. Himpunan Sirkular Trinukleotida: [('CGC', 'CGT')]
# Kata Sikel yang terbentuk: ('CGCCGT', 'GCCGTC', 'CCGTCG')
#
# 390. Himpunan Sirkular Trinukleotida: [('CGC', 'GTC')]
# Kata Sikel yang terbentuk: ('CGCGTC', 'GCGTCC', 'CGTCCG')
#
# 391. Himpunan Sirkular Trinukleotida: [('CGC', 'TCG')]
# Kata Sikel yang terbentuk: ('CGCTCG', 'GCTCGC', 'CTCGCG')
#
# 392. Himpunan Sirkular Trinukleotida: [('GCC', 'CGT')]
# Kata Sikel yang terbentuk: ('GCCCGT', 'CCCGTG', 'CCGTGC')
#
# 393. Himpunan Sirkular Trinukleotida: [('GCC', 'GTC')]
# Kata Sikel yang terbentuk: ('GCCGTC', 'CCGTCG', 'CGTCGC')
#
# 394. Himpunan Sirkular Trinukleotida: [('GCC', 'TCG')]
# Kata Sikel yang terbentuk: ('GCCTCG', 'CCTCGG', 'CTCGGC')
#
# 395. Himpunan Sirkular Trinukleotida: [('CCG', 'CGA')]
# Kata Sikel yang terbentuk: ('CCGCGA', 'CGCGAC', 'GCGACC')
#
# 396. Himpunan Sirkular Trinukleotida: [('CCG', 'GAC')]
# Kata Sikel yang terbentuk: ('CCGGAC', 'CGGACC', 'GGACCC')
#
# 397. Himpunan Sirkular Trinukleotida: [('CCG', 'ACG')]
# Kata Sikel yang terbentuk: ('CCGACG', 'CGACGC', 'GACGCC')
#
# 398. Himpunan Sirkular Trinukleotida: [('CGC', 'CGA')]
# Kata Sikel yang terbentuk: ('CGCCGA', 'GCCGAC', 'CCGACG')
#
# 399. Himpunan Sirkular Trinukleotida: [('CGC', 'GAC')]
# Kata Sikel yang terbentuk: ('CGCGAC', 'GCGACC', 'CGACCG')
#
# 400. Himpunan Sirkular Trinukleotida: [('CGC', 'ACG')]
# Kata Sikel yang terbentuk: ('CGCACG', 'GCACGC', 'CACGCG')
#
# 401. Himpunan Sirkular Trinukleotida: [('GCC', 'CGA')]
# Kata Sikel yang terbentuk: ('GCCCGA', 'CCCGAG', 'CCGAGC')
#
# 402. Himpunan Sirkular Trinukleotida: [('GCC', 'GAC')]
# Kata Sikel yang terbentuk: ('GCCGAC', 'CCGACG', 'CGACGC')
#
# 403. Himpunan Sirkular Trinukleotida: [('GCC', 'ACG')]
# Kata Sikel yang terbentuk: ('GCCACG', 'CCACGG', 'CACGGC')
#
# 404. Himpunan Sirkular Trinukleotida: [('CCG', 'CGG')]
# Kata Sikel yang terbentuk: ('CCGCGG', 'CGCGGC', 'GCGGCC')
#
# 405. Himpunan Sirkular Trinukleotida: [('CCG', 'GGC')]
# Kata Sikel yang terbentuk: ('CCGGGC', 'CGGGCC', 'GGGCCC')
#
# 406. Himpunan Sirkular Trinukleotida: [('CCG', 'GCG')]
# Kata Sikel yang terbentuk: ('CCGGCG', 'CGGCGC', 'GGCGCC')
#
# 407. Himpunan Sirkular Trinukleotida: [('CGC', 'CGG')]
# Kata Sikel yang terbentuk: ('CGCCGG', 'GCCGGC', 'CCGGCG')
#
# 408. Himpunan Sirkular Trinukleotida: [('CGC', 'GGC')]
# Kata Sikel yang terbentuk: ('CGCGGC', 'GCGGCC', 'CGGCCG')
#
# 409. Himpunan Sirkular Trinukleotida: [('GCC', 'CGG')]
# Kata Sikel yang terbentuk: ('GCCCGG', 'CCCGGG', 'CCGGGC')
#
# 410. Himpunan Sirkular Trinukleotida: [('GCC', 'GGC')]
# Kata Sikel yang terbentuk: ('GCCGGC', 'CCGGCG', 'CGGCGC')
#
# 411. Himpunan Sirkular Trinukleotida: [('GCC', 'GCG')]
# Kata Sikel yang terbentuk: ('GCCGCG', 'CCGCGG', 'CGCGGC')
#
# 412. Himpunan Sirkular Trinukleotida: [('CCG', 'TTA')]
# Kata Sikel yang terbentuk: ('CCGTTA', 'CGTTAC', 'GTTACC')
#
# 413. Himpunan Sirkular Trinukleotida: [('CCG', 'TAT')]
# Kata Sikel yang terbentuk: ('CCGTAT', 'CGTATC', 'GTATCC')
#
# 414. Himpunan Sirkular Trinukleotida: [('CCG', 'ATT')]
# Kata Sikel yang terbentuk: ('CCGATT', 'CGATTC', 'GATTCC')
#
# 415. Himpunan Sirkular Trinukleotida: [('CGC', 'TTA')]
# Kata Sikel yang terbentuk: ('CGCTTA', 'GCTTAC', 'CTTACG')
#
# 416. Himpunan Sirkular Trinukleotida: [('CGC', 'TAT')]
# Kata Sikel yang terbentuk: ('CGCTAT', 'GCTATC', 'CTATCG')
#
# 417. Himpunan Sirkular Trinukleotida: [('CGC', 'ATT')]
# Kata Sikel yang terbentuk: ('CGCATT', 'GCATTC', 'CATTCG')
#
# 418. Himpunan Sirkular Trinukleotida: [('GCC', 'TTA')]
# Kata Sikel yang terbentuk: ('GCCTTA', 'CCTTAG', 'CTTAGC')
#
# 419. Himpunan Sirkular Trinukleotida: [('GCC', 'TAT')]
# Kata Sikel yang terbentuk: ('GCCTAT', 'CCTATG', 'CTATGC')
#
# 420. Himpunan Sirkular Trinukleotida: [('GCC', 'ATT')]
# Kata Sikel yang terbentuk: ('GCCATT', 'CCATTG', 'CATTGC')
#
# 421. Himpunan Sirkular Trinukleotida: [('CCG', 'TTG')]
# Kata Sikel yang terbentuk: ('CCGTTG', 'CGTTGC', 'GTTGCC')
#
# 422. Himpunan Sirkular Trinukleotida: [('CCG', 'TGT')]
# Kata Sikel yang terbentuk: ('CCGTGT', 'CGTGTC', 'GTGTCC')
#
# 423. Himpunan Sirkular Trinukleotida: [('CCG', 'GTT')]
# Kata Sikel yang terbentuk: ('CCGGTT', 'CGGTTC', 'GGTTCC')
#
# 424. Himpunan Sirkular Trinukleotida: [('CGC', 'TTG')]
# Kata Sikel yang terbentuk: ('CGCTTG', 'GCTTGC', 'CTTGCG')
#
# 425. Himpunan Sirkular Trinukleotida: [('CGC', 'TGT')]
# Kata Sikel yang terbentuk: ('CGCTGT', 'GCTGTC', 'CTGTCG')
#
# 426. Himpunan Sirkular Trinukleotida: [('CGC', 'GTT')]
# Kata Sikel yang terbentuk: ('CGCGTT', 'GCGTTC', 'CGTTCG')
#
# 427. Himpunan Sirkular Trinukleotida: [('GCC', 'TTG')]
# Kata Sikel yang terbentuk: ('GCCTTG', 'CCTTGG', 'CTTGGC')
#
# 428. Himpunan Sirkular Trinukleotida: [('GCC', 'TGT')]
# Kata Sikel yang terbentuk: ('GCCTGT', 'CCTGTG', 'CTGTGC')
#
# 429. Himpunan Sirkular Trinukleotida: [('GCC', 'GTT')]
# Kata Sikel yang terbentuk: ('GCCGTT', 'CCGTTG', 'CGTTGC')
#
# 430. Himpunan Sirkular Trinukleotida: [('CCG', 'TAA')]
# Kata Sikel yang terbentuk: ('CCGTAA', 'CGTAAC', 'GTAACC')
#
# 431. Himpunan Sirkular Trinukleotida: [('CCG', 'AAT')]
# Kata Sikel yang terbentuk: ('CCGAAT', 'CGAATC', 'GAATCC')
#
# 432. Himpunan Sirkular Trinukleotida: [('CCG', 'ATA')]
# Kata Sikel yang terbentuk: ('CCGATA', 'CGATAC', 'GATACC')
#
# 433. Himpunan Sirkular Trinukleotida: [('CGC', 'TAA')]
# Kata Sikel yang terbentuk: ('CGCTAA', 'GCTAAC', 'CTAACG')
#
# 434. Himpunan Sirkular Trinukleotida: [('CGC', 'AAT')]
# Kata Sikel yang terbentuk: ('CGCAAT', 'GCAATC', 'CAATCG')
#
# 435. Himpunan Sirkular Trinukleotida: [('CGC', 'ATA')]
# Kata Sikel yang terbentuk: ('CGCATA', 'GCATAC', 'CATACG')
#
# 436. Himpunan Sirkular Trinukleotida: [('GCC', 'TAA')]
# Kata Sikel yang terbentuk: ('GCCTAA', 'CCTAAG', 'CTAAGC')
#
# 437. Himpunan Sirkular Trinukleotida: [('GCC', 'AAT')]
# Kata Sikel yang terbentuk: ('GCCAAT', 'CCAATG', 'CAATGC')
#
# 438. Himpunan Sirkular Trinukleotida: [('GCC', 'ATA')]
# Kata Sikel yang terbentuk: ('GCCATA', 'CCATAG', 'CATAGC')
#
# 439. Himpunan Sirkular Trinukleotida: [('CCG', 'TAG')]
# Kata Sikel yang terbentuk: ('CCGTAG', 'CGTAGC', 'GTAGCC')
#
# 440. Himpunan Sirkular Trinukleotida: [('CCG', 'AGT')]
# Kata Sikel yang terbentuk: ('CCGAGT', 'CGAGTC', 'GAGTCC')
#
# 441. Himpunan Sirkular Trinukleotida: [('CCG', 'GTA')]
# Kata Sikel yang terbentuk: ('CCGGTA', 'CGGTAC', 'GGTACC')
#
# 442. Himpunan Sirkular Trinukleotida: [('CGC', 'TAG')]
# Kata Sikel yang terbentuk: ('CGCTAG', 'GCTAGC', 'CTAGCG')
#
# 443. Himpunan Sirkular Trinukleotida: [('CGC', 'AGT')]
# Kata Sikel yang terbentuk: ('CGCAGT', 'GCAGTC', 'CAGTCG')
#
# 444. Himpunan Sirkular Trinukleotida: [('CGC', 'GTA')]
# Kata Sikel yang terbentuk: ('CGCGTA', 'GCGTAC', 'CGTACG')
#
# 445. Himpunan Sirkular Trinukleotida: [('GCC', 'TAG')]
# Kata Sikel yang terbentuk: ('GCCTAG', 'CCTAGG', 'CTAGGC')
#
# 446. Himpunan Sirkular Trinukleotida: [('GCC', 'AGT')]
# Kata Sikel yang terbentuk: ('GCCAGT', 'CCAGTG', 'CAGTGC')
#
# 447. Himpunan Sirkular Trinukleotida: [('GCC', 'GTA')]
# Kata Sikel yang terbentuk: ('GCCGTA', 'CCGTAG', 'CGTAGC')
#
# 448. Himpunan Sirkular Trinukleotida: [('CCG', 'TGA')]
# Kata Sikel yang terbentuk: ('CCGTGA', 'CGTGAC', 'GTGACC')
#
# 449. Himpunan Sirkular Trinukleotida: [('CCG', 'GAT')]
# Kata Sikel yang terbentuk: ('CCGGAT', 'CGGATC', 'GGATCC')
#
# 450. Himpunan Sirkular Trinukleotida: [('CCG', 'ATG')]
# Kata Sikel yang terbentuk: ('CCGATG', 'CGATGC', 'GATGCC')
#
# 451. Himpunan Sirkular Trinukleotida: [('CGC', 'TGA')]
# Kata Sikel yang terbentuk: ('CGCTGA', 'GCTGAC', 'CTGACG')
#
# 452. Himpunan Sirkular Trinukleotida: [('CGC', 'GAT')]
# Kata Sikel yang terbentuk: ('CGCGAT', 'GCGATC', 'CGATCG')
#
# 453. Himpunan Sirkular Trinukleotida: [('CGC', 'ATG')]
# Kata Sikel yang terbentuk: ('CGCATG', 'GCATGC', 'CATGCG')
#
# 454. Himpunan Sirkular Trinukleotida: [('GCC', 'TGA')]
# Kata Sikel yang terbentuk: ('GCCTGA', 'CCTGAG', 'CTGAGC')
#
# 455. Himpunan Sirkular Trinukleotida: [('GCC', 'GAT')]
# Kata Sikel yang terbentuk: ('GCCGAT', 'CCGATG', 'CGATGC')
#
# 456. Himpunan Sirkular Trinukleotida: [('GCC', 'ATG')]
# Kata Sikel yang terbentuk: ('GCCATG', 'CCATGG', 'CATGGC')
#
# 457. Himpunan Sirkular Trinukleotida: [('CCG', 'TGG')]
# Kata Sikel yang terbentuk: ('CCGTGG', 'CGTGGC', 'GTGGCC')
#
# 458. Himpunan Sirkular Trinukleotida: [('CCG', 'GGT')]
# Kata Sikel yang terbentuk: ('CCGGGT', 'CGGGTC', 'GGGTCC')
#
# 459. Himpunan Sirkular Trinukleotida: [('CCG', 'GTG')]
# ...
#
# 1566. Himpunan Sirkular Trinukleotida: [('TGT', 'GGA')]
# Kata Sikel yang terbentuk: ('TGTGGA', 'GTGGAT', 'TGGATG')
#
# 1567. Himpunan Sirkular Trinukleotida: [('TGT', 'GAG')]
# Kata Sikel yang terbentuk: ('TGTGAG', 'GTGAGT', 'TGAGTG')
#
# 1568. Himpunan Sirkular Trinukleotida: [('GTT', 'AGG')]
# Kata Sikel yang terbentuk: ('GTTAGG', 'TTAGGG', 'TAGGGT')
#
# 1569. Himpunan Sirkular Trinukleotida: [('GTT', 'GGA')]
# Kata Sikel yang terbentuk: ('GTTGGA', 'TTGGAG', 'TGGAGT')
#
# 1570. Himpunan Sirkular Trinukleotida: [('GTT', 'GAG')]
# Kata Sikel yang terbentuk: ('GTTGAG', 'TTGAGG', 'TGAGGT')
#
# 1571. Himpunan Sirkular Trinukleotida: [('TAA', 'TAG')]
# Kata Sikel yang terbentuk: ('TAATAG', 'AATAGT', 'ATAGTA')
#
# 1572. Himpunan Sirkular Trinukleotida: [('TAA', 'AGT')]
# Kata Sikel yang terbentuk: ('TAAAGT', 'AAAGTT', 'AAGTTA')
#
# 1573. Himpunan Sirkular Trinukleotida: [('TAA', 'GTA')]
# Kata Sikel yang terbentuk: ('TAAGTA', 'AAGTAT', 'AGTATA')
#
# 1574. Himpunan Sirkular Trinukleotida: [('AAT', 'TAG')]
# Kata Sikel yang terbentuk: ('AATTAG', 'ATTAGA', 'TTAGAA')
#
# 1575. Himpunan Sirkular Trinukleotida: [('AAT', 'AGT')]
# Kata Sikel yang terbentuk: ('AATAGT', 'ATAGTA', 'TAGTAA')
#
# 1576. Himpunan Sirkular Trinukleotida: [('AAT', 'GTA')]
# Kata Sikel yang terbentuk: ('AATGTA', 'ATGTAA', 'TGTAAA')
#
# 1577. Himpunan Sirkular Trinukleotida: [('ATA', 'TAG')]
# Kata Sikel yang terbentuk: ('ATATAG', 'TATAGA', 'ATAGAT')
#
# 1578. Himpunan Sirkular Trinukleotida: [('ATA', 'AGT')]
# Kata Sikel yang terbentuk: ('ATAAGT', 'TAAGTA', 'AAGTAT')
#
# 1579. Himpunan Sirkular Trinukleotida: [('ATA', 'GTA')]
# Kata Sikel yang terbentuk: ('ATAGTA', 'TAGTAA', 'AGTAAT')
#
# 1580. Himpunan Sirkular Trinukleotida: [('TAA', 'TGA')]
# Kata Sikel yang terbentuk: ('TAATGA', 'AATGAT', 'ATGATA')
#
# 1581. Himpunan Sirkular Trinukleotida: [('TAA', 'GAT')]
# Kata Sikel yang terbentuk: ('TAAGAT', 'AAGATT', 'AGATTA')
#
# 1582. Himpunan Sirkular Trinukleotida: [('TAA', 'ATG')]
# Kata Sikel yang terbentuk: ('TAAATG', 'AAATGT', 'AATGTA')
#
# 1583. Himpunan Sirkular Trinukleotida: [('AAT', 'TGA')]
# Kata Sikel yang terbentuk: ('AATTGA', 'ATTGAA', 'TTGAAA')
#
# 1584. Himpunan Sirkular Trinukleotida: [('AAT', 'GAT')]
# Kata Sikel yang terbentuk: ('AATGAT', 'ATGATA', 'TGATAA')
#
# 1585. Himpunan Sirkular Trinukleotida: [('AAT', 'ATG')]
# Kata Sikel yang terbentuk: ('AATATG', 'ATATGA', 'TATGAA')
#
# 1586. Himpunan Sirkular Trinukleotida: [('ATA', 'TGA')]
# Kata Sikel yang terbentuk: ('ATATGA', 'TATGAA', 'ATGAAT')
#
# 1587. Himpunan Sirkular Trinukleotida: [('ATA', 'GAT')]
# Kata Sikel yang terbentuk: ('ATAGAT', 'TAGATA', 'AGATAT')
#
# 1588. Himpunan Sirkular Trinukleotida: [('ATA', 'ATG')]
# Kata Sikel yang terbentuk: ('ATAATG', 'TAATGA', 'AATGAT')
#
# 1589. Himpunan Sirkular Trinukleotida: [('TAA', 'TGG')]
# Kata Sikel yang terbentuk: ('TAATGG', 'AATGGT', 'ATGGTA')
#
# 1590. Himpunan Sirkular Trinukleotida: [('TAA', 'GGT')]
# Kata Sikel yang terbentuk: ('TAAGGT', 'AAGGTT', 'AGGTTA')
#
# 1591. Himpunan Sirkular Trinukleotida: [('TAA', 'GTG')]
# Kata Sikel yang terbentuk: ('TAAGTG', 'AAGTGT', 'AGTGTA')
#
# 1592. Himpunan Sirkular Trinukleotida: [('AAT', 'TGG')]
# Kata Sikel yang terbentuk: ('AATTGG', 'ATTGGA', 'TTGGAA')
#
# 1593. Himpunan Sirkular Trinukleotida: [('AAT', 'GGT')]
# Kata Sikel yang terbentuk: ('AATGGT', 'ATGGTA', 'TGGTAA')
#
# 1594. Himpunan Sirkular Trinukleotida: [('AAT', 'GTG')]
# Kata Sikel yang terbentuk: ('AATGTG', 'ATGTGA', 'TGTGAA')
#
# 1595. Himpunan Sirkular Trinukleotida: [('ATA', 'TGG')]
# Kata Sikel yang terbentuk: ('ATATGG', 'TATGGA', 'ATGGAT')
#
# 1596. Himpunan Sirkular Trinukleotida: [('ATA', 'GGT')]
# Kata Sikel yang terbentuk: ('ATAGGT', 'TAGGTA', 'AGGTAT')
#
# 1597. Himpunan Sirkular Trinukleotida: [('ATA', 'GTG')]
# Kata Sikel yang terbentuk: ('ATAGTG', 'TAGTGA', 'AGTGAT')
#
# 1598. Himpunan Sirkular Trinukleotida: [('TAA', 'AAG')]
# Kata Sikel yang terbentuk: ('TAAAAG', 'AAAAGT', 'AAAGTA')
#
# 1599. Himpunan Sirkular Trinukleotida: [('TAA', 'AGA')]
# Kata Sikel yang terbentuk: ('TAAAGA', 'AAAGAT', 'AAGATA')
#
# 1600. Himpunan Sirkular Trinukleotida: [('TAA', 'GAA')]
# Kata Sikel yang terbentuk: ('TAAGAA', 'AAGAAT', 'AGAATA')
#
# 1601. Himpunan Sirkular Trinukleotida: [('AAT', 'AAG')]
# Kata Sikel yang terbentuk: ('AATAAG', 'ATAAGA', 'TAAGAA')
#
# 1602. Himpunan Sirkular Trinukleotida: [('AAT', 'AGA')]
# Kata Sikel yang terbentuk: ('AATAGA', 'ATAGAA', 'TAGAAA')
#
# 1603. Himpunan Sirkular Trinukleotida: [('AAT', 'GAA')]
# Kata Sikel yang terbentuk: ('AATGAA', 'ATGAAA', 'TGAAAA')
#
# 1604. Himpunan Sirkular Trinukleotida: [('ATA', 'AAG')]
# Kata Sikel yang terbentuk: ('ATAAAG', 'TAAAGA', 'AAAGAT')
#
# 1605. Himpunan Sirkular Trinukleotida: [('ATA', 'AGA')]
# Kata Sikel yang terbentuk: ('ATAAGA', 'TAAGAA', 'AAGAAT')
#
# 1606. Himpunan Sirkular Trinukleotida: [('ATA', 'GAA')]
# Kata Sikel yang terbentuk: ('ATAGAA', 'TAGAAA', 'AGAAAT')
#
# 1607. Himpunan Sirkular Trinukleotida: [('TAA', 'AGG')]
# Kata Sikel yang terbentuk: ('TAAAGG', 'AAAGGT', 'AAGGTA')
#
# 1608. Himpunan Sirkular Trinukleotida: [('TAA', 'GGA')]
# Kata Sikel yang terbentuk: ('TAAGGA', 'AAGGAT', 'AGGATA')
#
# 1609. Himpunan Sirkular Trinukleotida: [('TAA', 'GAG')]
# Kata Sikel yang terbentuk: ('TAAGAG', 'AAGAGT', 'AGAGTA')
#
# 1610. Himpunan Sirkular Trinukleotida: [('AAT', 'AGG')]
# Kata Sikel yang terbentuk: ('AATAGG', 'ATAGGA', 'TAGGAA')
#
# 1611. Himpunan Sirkular Trinukleotida: [('AAT', 'GGA')]
# Kata Sikel yang terbentuk: ('AATGGA', 'ATGGAA', 'TGGAAA')
#
# 1612. Himpunan Sirkular Trinukleotida: [('AAT', 'GAG')]
# Kata Sikel yang terbentuk: ('AATGAG', 'ATGAGA', 'TGAGAA')
#
# 1613. Himpunan Sirkular Trinukleotida: [('ATA', 'AGG')]
# Kata Sikel yang terbentuk: ('ATAAGG', 'TAAGGA', 'AAGGAT')
#
# 1614. Himpunan Sirkular Trinukleotida: [('ATA', 'GGA')]
# Kata Sikel yang terbentuk: ('ATAGGA', 'TAGGAA', 'AGGAAT')
#
# 1615. Himpunan Sirkular Trinukleotida: [('ATA', 'GAG')]
# Kata Sikel yang terbentuk: ('ATAGAG', 'TAGAGA', 'AGAGAT')
#
# 1616. Himpunan Sirkular Trinukleotida: [('TAG', 'TGA')]
# Kata Sikel yang terbentuk: ('TAGTGA', 'AGTGAT', 'GTGATA')
#
# 1617. Himpunan Sirkular Trinukleotida: [('TAG', 'GAT')]
# Kata Sikel yang terbentuk: ('TAGGAT', 'AGGATT', 'GGATTA')
#
# 1618. Himpunan Sirkular Trinukleotida: [('TAG', 'ATG')]
# Kata Sikel yang terbentuk: ('TAGATG', 'AGATGT', 'GATGTA')
#
# 1619. Himpunan Sirkular Trinukleotida: [('AGT', 'TGA')]
# Kata Sikel yang terbentuk: ('AGTTGA', 'GTTGAA', 'TTGAAG')
#
# 1620. Himpunan Sirkular Trinukleotida: [('AGT', 'GAT')]
# Kata Sikel yang terbentuk: ('AGTGAT', 'GTGATA', 'TGATAG')
#
# 1621. Himpunan Sirkular Trinukleotida: [('AGT', 'ATG')]
# Kata Sikel yang terbentuk: ('AGTATG', 'GTATGA', 'TATGAG')
#
# 1622. Himpunan Sirkular Trinukleotida: [('GTA', 'TGA')]
# Kata Sikel yang terbentuk: ('GTATGA', 'TATGAG', 'ATGAGT')
#
# 1623. Himpunan Sirkular Trinukleotida: [('GTA', 'GAT')]
# Kata Sikel yang terbentuk: ('GTAGAT', 'TAGATG', 'AGATGT')
#
# 1624. Himpunan Sirkular Trinukleotida: [('GTA', 'ATG')]
# Kata Sikel yang terbentuk: ('GTAATG', 'TAATGG', 'AATGGT')
#
# 1625. Himpunan Sirkular Trinukleotida: [('TAG', 'TGG')]
# Kata Sikel yang terbentuk: ('TAGTGG', 'AGTGGT', 'GTGGTA')
#
# 1626. Himpunan Sirkular Trinukleotida: [('TAG', 'GGT')]
# Kata Sikel yang terbentuk: ('TAGGGT', 'AGGGTT', 'GGGTTA')
#
# 1627. Himpunan Sirkular Trinukleotida: [('TAG', 'GTG')]
# Kata Sikel yang terbentuk: ('TAGGTG', 'AGGTGT', 'GGTGTA')
#
# 1628. Himpunan Sirkular Trinukleotida: [('AGT', 'TGG')]
# Kata Sikel yang terbentuk: ('AGTTGG', 'GTTGGA', 'TTGGAG')
#
# 1629. Himpunan Sirkular Trinukleotida: [('AGT', 'GGT')]
# Kata Sikel yang terbentuk: ('AGTGGT', 'GTGGTA', 'TGGTAG')
#
# 1630. Himpunan Sirkular Trinukleotida: [('AGT', 'GTG')]
# Kata Sikel yang terbentuk: ('AGTGTG', 'GTGTGA', 'TGTGAG')
#
# 1631. Himpunan Sirkular Trinukleotida: [('GTA', 'TGG')]
# Kata Sikel yang terbentuk: ('GTATGG', 'TATGGG', 'ATGGGT')
#
# 1632. Himpunan Sirkular Trinukleotida: [('GTA', 'GGT')]
# Kata Sikel yang terbentuk: ('GTAGGT', 'TAGGTG', 'AGGTGT')
#
# 1633. Himpunan Sirkular Trinukleotida: [('GTA', 'GTG')]
# Kata Sikel yang terbentuk: ('GTAGTG', 'TAGTGG', 'AGTGGT')
#
# 1634. Himpunan Sirkular Trinukleotida: [('TAG', 'AAG')]
# Kata Sikel yang terbentuk: ('TAGAAG', 'AGAAGT', 'GAAGTA')
#
# 1635. Himpunan Sirkular Trinukleotida: [('TAG', 'AGA')]
# Kata Sikel yang terbentuk: ('TAGAGA', 'AGAGAT', 'GAGATA')
#
# 1636. Himpunan Sirkular Trinukleotida: [('TAG', 'GAA')]
# Kata Sikel yang terbentuk: ('TAGGAA', 'AGGAAT', 'GGAATA')
#
# 1637. Himpunan Sirkular Trinukleotida: [('AGT', 'AAG')]
# Kata Sikel yang terbentuk: ('AGTAAG', 'GTAAGA', 'TAAGAG')
#
# 1638. Himpunan Sirkular Trinukleotida: [('AGT', 'AGA')]
# Kata Sikel yang terbentuk: ('AGTAGA', 'GTAGAA', 'TAGAAG')
#
# 1639. Himpunan Sirkular Trinukleotida: [('AGT', 'GAA')]
# Kata Sikel yang terbentuk: ('AGTGAA', 'GTGAAA', 'TGAAAG')
#
# 1640. Himpunan Sirkular Trinukleotida: [('GTA', 'AAG')]
# Kata Sikel yang terbentuk: ('GTAAAG', 'TAAAGG', 'AAAGGT')
#
# 1641. Himpunan Sirkular Trinukleotida: [('GTA', 'AGA')]
# Kata Sikel yang terbentuk: ('GTAAGA', 'TAAGAG', 'AAGAGT')
#
# 1642. Himpunan Sirkular Trinukleotida: [('GTA', 'GAA')]
# Kata Sikel yang terbentuk: ('GTAGAA', 'TAGAAG', 'AGAAGT')
#
# 1643. Himpunan Sirkular Trinukleotida: [('TAG', 'AGG')]
# Kata Sikel yang terbentuk: ('TAGAGG', 'AGAGGT', 'GAGGTA')
#
# 1644. Himpunan Sirkular Trinukleotida: [('TAG', 'GGA')]
# Kata Sikel yang terbentuk: ('TAGGGA', 'AGGGAT', 'GGGATA')
#
# 1645. Himpunan Sirkular Trinukleotida: [('TAG', 'GAG')]
# Kata Sikel yang terbentuk: ('TAGGAG', 'AGGAGT', 'GGAGTA')
#
# 1646. Himpunan Sirkular Trinukleotida: [('AGT', 'AGG')]
# Kata Sikel yang terbentuk: ('AGTAGG', 'GTAGGA', 'TAGGAG')
#
# 1647. Himpunan Sirkular Trinukleotida: [('AGT', 'GGA')]
# Kata Sikel yang terbentuk: ('AGTGGA', 'GTGGAA', 'TGGAAG')
#
# 1648. Himpunan Sirkular Trinukleotida: [('AGT', 'GAG')]
# Kata Sikel yang terbentuk: ('AGTGAG', 'GTGAGA', 'TGAGAG')
#
# 1649. Himpunan Sirkular Trinukleotida: [('GTA', 'AGG')]
# Kata Sikel yang terbentuk: ('GTAAGG', 'TAAGGG', 'AAGGGT')
#
# 1650. Himpunan Sirkular Trinukleotida: [('GTA', 'GGA')]
# Kata Sikel yang terbentuk: ('GTAGGA', 'TAGGAG', 'AGGAGT')
#
# 1651. Himpunan Sirkular Trinukleotida: [('GTA', 'GAG')]
# Kata Sikel yang terbentuk: ('GTAGAG', 'TAGAGG', 'AGAGGT')
#
# 1652. Himpunan Sirkular Trinukleotida: [('TGA', 'TGG')]
# Kata Sikel yang terbentuk: ('TGATGG', 'GATGGT', 'ATGGTG')
#
# 1653. Himpunan Sirkular Trinukleotida: [('TGA', 'GGT')]
# Kata Sikel yang terbentuk: ('TGAGGT', 'GAGGTT', 'AGGTTG')
#
# 1654. Himpunan Sirkular Trinukleotida: [('TGA', 'GTG')]
# Kata Sikel yang terbentuk: ('TGAGTG', 'GAGTGT', 'AGTGTG')
#
# 1655. Himpunan Sirkular Trinukleotida: [('GAT', 'TGG')]
# Kata Sikel yang terbentuk: ('GATTGG', 'ATTGGG', 'TTGGGA')
#
# 1656. Himpunan Sirkular Trinukleotida: [('GAT', 'GGT')]
# Kata Sikel yang terbentuk: ('GATGGT', 'ATGGTG', 'TGGTGA')
#
# 1657. Himpunan Sirkular Trinukleotida: [('GAT', 'GTG')]
# Kata Sikel yang terbentuk: ('GATGTG', 'ATGTGG', 'TGTGGA')
#
# 1658. Himpunan Sirkular Trinukleotida: [('ATG', 'TGG')]
# Kata Sikel yang terbentuk: ('ATGTGG', 'TGTGGA', 'GTGGAT')
#
# 1659. Himpunan Sirkular Trinukleotida: [('ATG', 'GGT')]
# Kata Sikel yang terbentuk: ('ATGGGT', 'TGGGTA', 'GGGTAT')
#
# 1660. Himpunan Sirkular Trinukleotida: [('ATG', 'GTG')]
# Kata Sikel yang terbentuk: ('ATGGTG', 'TGGTGA', 'GGTGAT')
#
# 1661. Himpunan Sirkular Trinukleotida: [('TGA', 'AAG')]
# Kata Sikel yang terbentuk: ('TGAAAG', 'GAAAGT', 'AAAGTG')
#
# 1662. Himpunan Sirkular Trinukleotida: [('TGA', 'AGA')]
# Kata Sikel yang terbentuk: ('TGAAGA', 'GAAGAT', 'AAGATG')
#
# 1663. Himpunan Sirkular Trinukleotida: [('TGA', 'GAA')]
# Kata Sikel yang terbentuk: ('TGAGAA', 'GAGAAT', 'AGAATG')
#
# 1664. Himpunan Sirkular Trinukleotida: [('GAT', 'AAG')]
# Kata Sikel yang terbentuk: ('GATAAG', 'ATAAGG', 'TAAGGA')
#
# 1665. Himpunan Sirkular Trinukleotida: [('GAT', 'AGA')]
# Kata Sikel yang terbentuk: ('GATAGA', 'ATAGAG', 'TAGAGA')
#
# 1666. Himpunan Sirkular Trinukleotida: [('GAT', 'GAA')]
# Kata Sikel yang terbentuk: ('GATGAA', 'ATGAAG', 'TGAAGA')
#
# 1667. Himpunan Sirkular Trinukleotida: [('ATG', 'AAG')]
# Kata Sikel yang terbentuk: ('ATGAAG', 'TGAAGA', 'GAAGAT')
#
# 1668. Himpunan Sirkular Trinukleotida: [('ATG', 'AGA')]
# Kata Sikel yang terbentuk: ('ATGAGA', 'TGAGAA', 'GAGAAT')
#
# 1669. Himpunan Sirkular Trinukleotida: [('ATG', 'GAA')]
# Kata Sikel yang terbentuk: ('ATGGAA', 'TGGAAA', 'GGAAAT')
#
# 1670. Himpunan Sirkular Trinukleotida: [('TGA', 'AGG')]
# Kata Sikel yang terbentuk: ('TGAAGG', 'GAAGGT', 'AAGGTG')
#
# 1671. Himpunan Sirkular Trinukleotida: [('TGA', 'GGA')]
# Kata Sikel yang terbentuk: ('TGAGGA', 'GAGGAT', 'AGGATG')
#
# 1672. Himpunan Sirkular Trinukleotida: [('TGA', 'GAG')]
# Kata Sikel yang terbentuk: ('TGAGAG', 'GAGAGT', 'AGAGTG')
#
# 1673. Himpunan Sirkular Trinukleotida: [('GAT', 'AGG')]
# Kata Sikel yang terbentuk: ('GATAGG', 'ATAGGG', 'TAGGGA')
#
# 1674. Himpunan Sirkular Trinukleotida: [('GAT', 'GGA')]
# Kata Sikel yang terbentuk: ('GATGGA', 'ATGGAG', 'TGGAGA')
#
# 1675. Himpunan Sirkular Trinukleotida: [('GAT', 'GAG')]
# Kata Sikel yang terbentuk: ('GATGAG', 'ATGAGG', 'TGAGGA')
#
# 1676. Himpunan Sirkular Trinukleotida: [('ATG', 'AGG')]
# Kata Sikel yang terbentuk: ('ATGAGG', 'TGAGGA', 'GAGGAT')
#
# 1677. Himpunan Sirkular Trinukleotida: [('ATG', 'GGA')]
# Kata Sikel yang terbentuk: ('ATGGGA', 'TGGGAA', 'GGGAAT')
#
# 1678. Himpunan Sirkular Trinukleotida: [('ATG', 'GAG')]
# Kata Sikel yang terbentuk: ('ATGGAG', 'TGGAGA', 'GGAGAT')
#
# 1679. Himpunan Sirkular Trinukleotida: [('TGG', 'AAG')]
# Kata Sikel yang terbentuk: ('TGGAAG', 'GGAAGT', 'GAAGTG')
#
# 1680. Himpunan Sirkular Trinukleotida: [('TGG', 'AGA')]
# Kata Sikel yang terbentuk: ('TGGAGA', 'GGAGAT', 'GAGATG')
#
# 1681. Himpunan Sirkular Trinukleotida: [('TGG', 'GAA')]
# Kata Sikel yang terbentuk: ('TGGGAA', 'GGGAAT', 'GGAATG')
#
# 1682. Himpunan Sirkular Trinukleotida: [('GGT', 'AAG')]
# Kata Sikel yang terbentuk: ('GGTAAG', 'GTAAGG', 'TAAGGG')
#
# 1683. Himpunan Sirkular Trinukleotida: [('GGT', 'AGA')]
# Kata Sikel yang terbentuk: ('GGTAGA', 'GTAGAG', 'TAGAGG')
#
# 1684. Himpunan Sirkular Trinukleotida: [('GGT', 'GAA')]
# Kata Sikel yang terbentuk: ('GGTGAA', 'GTGAAG', 'TGAAGG')
#
# 1685. Himpunan Sirkular Trinukleotida: [('GTG', 'AAG')]
# Kata Sikel yang terbentuk: ('GTGAAG', 'TGAAGG', 'GAAGGT')
#
# 1686. Himpunan Sirkular Trinukleotida: [('GTG', 'AGA')]
# Kata Sikel yang terbentuk: ('GTGAGA', 'TGAGAG', 'GAGAGT')
#
# 1687. Himpunan Sirkular Trinukleotida: [('GTG', 'GAA')]
# Kata Sikel yang terbentuk: ('GTGGAA', 'TGGAAG', 'GGAAGT')
#
# 1688. Himpunan Sirkular Trinukleotida: [('TGG', 'AGG')]
# Kata Sikel yang terbentuk: ('TGGAGG', 'GGAGGT', 'GAGGTG')
#
# 1689. Himpunan Sirkular Trinukleotida: [('TGG', 'GGA')]
# Kata Sikel yang terbentuk: ('TGGGGA', 'GGGGAT', 'GGGATG')
#
# 1690. Himpunan Sirkular Trinukleotida: [('TGG', 'GAG')]
# Kata Sikel yang terbentuk: ('TGGGAG', 'GGGAGT', 'GGAGTG')
#
# 1691. Himpunan Sirkular Trinukleotida: [('GGT', 'AGG')]
# Kata Sikel yang terbentuk: ('GGTAGG', 'GTAGGG', 'TAGGGG')
#
# 1692. Himpunan Sirkular Trinukleotida: [('GGT', 'GGA')]
# Kata Sikel yang terbentuk: ('GGTGGA', 'GTGGAG', 'TGGAGG')
#
# 1693. Himpunan Sirkular Trinukleotida: [('GGT', 'GAG')]
# Kata Sikel yang terbentuk: ('GGTGAG', 'GTGAGG', 'TGAGGG')
#
# 1694. Himpunan Sirkular Trinukleotida: [('GTG', 'AGG')]
# Kata Sikel yang terbentuk: ('GTGAGG', 'TGAGGG', 'GAGGGT')
#
# 1695. Himpunan Sirkular Trinukleotida: [('GTG', 'GGA')]
# Kata Sikel yang terbentuk: ('GTGGGA', 'TGGGAG', 'GGGAGT')
#
# 1696. Himpunan Sirkular Trinukleotida: [('GTG', 'GAG')]
# Kata Sikel yang terbentuk: ('GTGGAG', 'TGGAGG', 'GGAGGT')
#
# 1697. Himpunan Sirkular Trinukleotida: [('AAG', 'AGG')]
# Kata Sikel yang terbentuk: ('AAGAGG', 'AGAGGA', 'GAGGAA')
#
# 1698. Himpunan Sirkular Trinukleotida: [('AAG', 'GGA')]
# Kata Sikel yang terbentuk: ('AAGGGA', 'AGGGAA', 'GGGAAA')
#
# 1699. Himpunan Sirkular Trinukleotida: [('AAG', 'GAG')]
# Kata Sikel yang terbentuk: ('AAGGAG', 'AGGAGA', 'GGAGAA')
#
# 1700. Himpunan Sirkular Trinukleotida: [('AGA', 'AGG')]
# Kata Sikel yang terbentuk: ('AGAAGG', 'GAAGGA', 'AAGGAG')
#
# 1701. Himpunan Sirkular Trinukleotida: [('AGA', 'GGA')]
# Kata Sikel yang terbentuk: ('AGAGGA', 'GAGGAA', 'AGGAAG')
#
# 1702. Himpunan Sirkular Trinukleotida: [('GAA', 'AGG')]
# Kata Sikel yang terbentuk: ('GAAAGG', 'AAAGGG', 'AAGGGA')
#
# 1703. Himpunan Sirkular Trinukleotida: [('GAA', 'GGA')]
# Kata Sikel yang terbentuk: ('GAAGGA', 'AAGGAG', 'AGGAGA')
#
# 1704. Himpunan Sirkular Trinukleotida: [('GAA', 'GAG')]
# Kata Sikel yang terbentuk: ('GAAGAG', 'AAGAGG', 'AGAGGA')

# %% [markdown]
# # Proposisi 4.5

# %% [markdown]
# ## Untuk |X| = 1

# %%
# Membentuk fungsi untuk mencari himpunan bersifat kode C3
def kode_C3(data):
    # Mencari permutasi dari kodon
    def permutasi_kodons(kodons):

        # Permutasi a_1 = (1 2 3)
        keys_1 = [2, 3, 1]
        # Permutasi a_2 = (1 3 2)
        keys_2 = [3, 1, 2]

        keys_11 = [key - 1 for key in keys_1]
        keys_22 = [key - 1 for key in keys_2]

        # Periksa apakah panjang keys sama dengan panjang kodons
        if len(keys_11) != len(kodons) and len(keys_22) != len(kodons):
            raise ValueError('Panjang keys tidak sama dengan panjang kodons')

        # Mengembalikan permutasi terhadap kodons_i
        kodons_1 = [kodons[key] for key in keys_11]
        kodons_2 = [kodons[key] for key in keys_22]
        return ''.join(kodons_1) if isinstance(kodons, str) else kodons_1, ''.join(kodons_2) if isinstance(kodons, str) else kodons_2

    # Membentuk himpunan X yang bersifat kode C3
    X = []
    # Nomor urutan
    i = 1
    invarians = ['CCC', 'TTT', 'AAA', 'GGG']

    # Melakukan perulangan untuk mencari himpunan kode C3
    for kodon in data:
        # Melakukan permutasi terhadap kodon x_i
        X1, X2 = permutasi_kodons(kodon)

        # Memeriksa apakah X1 dan X2 ada dalam data
        if X1 in data and X2 in data and kodon not in invarians and kodon not in X:
            X.append(kodon)
            print(f'Kode C3 X{i}: {kodon, X1, X2}\n')
            i += 1
        else:
            continue
    return X

# Memanggil fungsi kode_C3
kode_c3 = kode_C3(kodons)
# Out:
# Kode C3 X1: ('CCT', 'CTC', 'TCC')
#
# Kode C3 X2: ('CCA', 'CAC', 'ACC')
#
# Kode C3 X3: ('CCG', 'CGC', 'GCC')
#
# Kode C3 X4: ('CTC', 'TCC', 'CCT')
#
# Kode C3 X5: ('CTT', 'TTC', 'TCT')
#
# Kode C3 X6: ('CTA', 'TAC', 'ACT')
#
# Kode C3 X7: ('CTG', 'TGC', 'GCT')
#
# Kode C3 X8: ('CAC', 'ACC', 'CCA')
#
# Kode C3 X9: ('CAT', 'ATC', 'TCA')
#
# Kode C3 X10: ('CAA', 'AAC', 'ACA')
#
# Kode C3 X11: ('CAG', 'AGC', 'GCA')
#
# Kode C3 X12: ('CGC', 'GCC', 'CCG')
#
# Kode C3 X13: ('CGT', 'GTC', 'TCG')
#
# Kode C3 X14: ('CGA', 'GAC', 'ACG')
#
# Kode C3 X15: ('CGG', 'GGC', 'GCG')
#
# Kode C3 X16: ('TCC', 'CCT', 'CTC')
#
# Kode C3 X17: ('TCT', 'CTT', 'TTC')
#
# Kode C3 X18: ('TCA', 'CAT', 'ATC')
#
# Kode C3 X19: ('TCG', 'CGT', 'GTC')
#
# Kode C3 X20: ('TTC', 'TCT', 'CTT')
#
# Kode C3 X21: ('TTA', 'TAT', 'ATT')
#
# Kode C3 X22: ('TTG', 'TGT', 'GTT')
#
# Kode C3 X23: ('TAC', 'ACT', 'CTA')
#
# Kode C3 X24: ('TAT', 'ATT', 'TTA')
#
# Kode C3 X25: ('TAA', 'AAT', 'ATA')
#
# Kode C3 X26: ('TAG', 'AGT', 'GTA')
#
# Kode C3 X27: ('TGC', 'GCT', 'CTG')
#
# Kode C3 X28: ('TGT', 'GTT', 'TTG')
#
# Kode C3 X29: ('TGA', 'GAT', 'ATG')
#
# Kode C3 X30: ('TGG', 'GGT', 'GTG')
#
# Kode C3 X31: ('ACC', 'CCA', 'CAC')
#
# Kode C3 X32: ('ACT', 'CTA', 'TAC')
#
# Kode C3 X33: ('ACA', 'CAA', 'AAC')
#
# Kode C3 X34: ('ACG', 'CGA', 'GAC')
#
# Kode C3 X35: ('ATC', 'TCA', 'CAT')
#
# Kode C3 X36: ('ATT', 'TTA', 'TAT')
#
# Kode C3 X37: ('ATA', 'TAA', 'AAT')
#
# Kode C3 X38: ('ATG', 'TGA', 'GAT')
#
# Kode C3 X39: ('AAC', 'ACA', 'CAA')
#
# Kode C3 X40: ('AAT', 'ATA', 'TAA')
#
# Kode C3 X41: ('AAG', 'AGA', 'GAA')
#
# Kode C3 X42: ('AGC', 'GCA', 'CAG')
#
# Kode C3 X43: ('AGT', 'GTA', 'TAG')
#
# Kode C3 X44: ('AGA', 'GAA', 'AAG')
#
# Kode C3 X45: ('AGG', 'GGA', 'GAG')
#
# Kode C3 X46: ('GCC', 'CCG', 'CGC')
#
# Kode C3 X47: ('GCT', 'CTG', 'TGC')
#
# Kode C3 X48: ('GCA', 'CAG', 'AGC')
#
# Kode C3 X49: ('GCG', 'CGG', 'GGC')
#
# Kode C3 X50: ('GTC', 'TCG', 'CGT')
#
# Kode C3 X51: ('GTT', 'TTG', 'TGT')
#
# Kode C3 X52: ('GTA', 'TAG', 'AGT')
#
# Kode C3 X53: ('GTG', 'TGG', 'GGT')
#
# Kode C3 X54: ('GAC', 'ACG', 'CGA')
#
# Kode C3 X55: ('GAT', 'ATG', 'TGA')
#
# Kode C3 X56: ('GAA', 'AAG', 'AGA')
#
# Kode C3 X57: ('GAG', 'AGG', 'GGA')
#
# Kode C3 X58: ('GGC', 'GCG', 'CGG')
#
# Kode C3 X59: ('GGT', 'GTG', 'TGG')
#
# Kode C3 X60: ('GGA', 'GAG', 'AGG')

# %% [markdown]
# ## Untuk |X| = 2

# %%
# Membentuk fungsi untuk mencari himpunan bersifat kode C3
def kode_C3(data):
    # Mencari permutasi dari kodon
    def permutasi_kodons(kodons):

        # Permutasi a_1 = (1 2 3)
        keys_1 = [2, 3, 1]
        # Permutasi a_2 = (1 3 2)
        keys_2 = [3, 1, 2]

        keys_11 = [key - 1 for key in keys_1]
        keys_22 = [key - 1 for key in keys_2]

        # Periksa apakah panjang keys sama dengan panjang kodons
        if len(keys_11) != len(kodons) and len(keys_22) != len(kodons):
            raise ValueError('Panjang keys tidak sama dengan panjang kodons')

        # Mengembalikan permutasi terhadap kodons_i
        kodons_1 = [kodons[key] for key in keys_11]
        kodons_2 = [kodons[key] for key in keys_22]
        return ''.join(kodons_1) if isinstance(kodons, str) else kodons_1, ''.join(kodons_2) if isinstance(kodons, str) else kodons_2

    # Membentuk himpunan X yang bersifat kode C3
    X = []
    # Nomor urutan
    i = 1

    # Melakukan perulangan untuk mencari himpunan kode C3
    for kodon in data:
        # himpunan permutasi himpunan X terdapat a1 dan a2
        X1 = []
        X2 = []
        X3 = []
        X4 = []
        n = len(kodon)

        # Menentukan kodon x_i dari himpuna kode sirukular trinukleotida
        for j in range(0,n):

            # Melakukan permutasi terhadap kodon x_i
            kodon_1, kodon_2 = permutasi_kodons(kodon[j])
            kodon_3, kodon_4 = permutasi_kodons(kodon[n-1-j])

            # Menambahkan permutasi kodon x_i ke dalam himpunan X1 dan X2
            X1.append(kodon_1), X2.append(kodon_2), X3.append(kodon_3), X4.append(kodon_4)

            # Memeriksa apakah X1 dan X2 ada dalam data
            if (X1 in data and X2 in data) or (X3 in data and X4 in data):
                #print(kodon, X1, X2, X3, X4)
                if (X1 not in X and X2 not in X) or (X3 not in X and X4 not in X):
                    X.append(kodon)
                    print(f'{i}. Kode C3 X: {kodon}')
                    #print(f'X1: {X1}, X2: {X2}\n')
                    i += 1
            else:
                continue
    return X

# Memanggil fungsi kode_C3
kode_c3 = kode_C3(sirkular_trinukleotida)
# Out:
# 1. Kode C3 X: ['CCT', 'CCA']
# 2. Kode C3 X: ['CCT', 'CAC']
# 3. Kode C3 X: ['CCT', 'ACC']
# 4. Kode C3 X: ['CTC', 'CCA']
# 5. Kode C3 X: ['CTC', 'CAC']
# 6. Kode C3 X: ['CTC', 'ACC']
# 7. Kode C3 X: ['TCC', 'CCA']
# 8. Kode C3 X: ['TCC', 'CAC']
# 9. Kode C3 X: ['TCC', 'ACC']
# 10. Kode C3 X: ['CCT', 'CCG']
# 11. Kode C3 X: ['CCT', 'CGC']
# 12. Kode C3 X: ['CCT', 'GCC']
# 13. Kode C3 X: ['CTC', 'CCG']
# 14. Kode C3 X: ['CTC', 'CGC']
# 15. Kode C3 X: ['CTC', 'GCC']
# 16. Kode C3 X: ['TCC', 'CCG']
# 17. Kode C3 X: ['TCC', 'CGC']
# 18. Kode C3 X: ['TCC', 'GCC']
# 19. Kode C3 X: ['CCT', 'CTT']
# 20. Kode C3 X: ['CCT', 'TCT']
# 21. Kode C3 X: ['CTC', 'CTT']
# 22. Kode C3 X: ['CTC', 'TTC']
# 23. Kode C3 X: ['TCC', 'TTC']
# 24. Kode C3 X: ['TCC', 'TCT']
# 25. Kode C3 X: ['CCT', 'CTA']
# 26. Kode C3 X: ['CCT', 'TAC']
# 27. Kode C3 X: ['CCT', 'ACT']
# 28. Kode C3 X: ['CTC', 'CTA']
# 29. Kode C3 X: ['CTC', 'TAC']
# 30. Kode C3 X: ['CTC', 'ACT']
# 31. Kode C3 X: ['TCC', 'CTA']
# 32. Kode C3 X: ['TCC', 'TAC']
# 33. Kode C3 X: ['TCC', 'ACT']
# 34. Kode C3 X: ['CCT', 'CTG']
# 35. Kode C3 X: ['CCT', 'TGC']
# 36. Kode C3 X: ['CCT', 'GCT']
# 37. Kode C3 X: ['CTC', 'CTG']
# 38. Kode C3 X: ['CTC', 'TGC']
# 39. Kode C3 X: ['CTC', 'GCT']
# 40. Kode C3 X: ['TCC', 'CTG']
# 41. Kode C3 X: ['TCC', 'TGC']
# 42. Kode C3 X: ['TCC', 'GCT']
# 43. Kode C3 X: ['CCT', 'CAT']
# 44. Kode C3 X: ['CCT', 'ATC']
# 45. Kode C3 X: ['CCT', 'TCA']
# 46. Kode C3 X: ['CTC', 'CAT']
# 47. Kode C3 X: ['CTC', 'ATC']
# 48. Kode C3 X: ['CTC', 'TCA']
# 49. Kode C3 X: ['TCC', 'CAT']
# 50. Kode C3 X: ['TCC', 'ATC']
# 51. Kode C3 X: ['TCC', 'TCA']
# 52. Kode C3 X: ['CCT', 'CAA']
# 53. Kode C3 X: ['CCT', 'AAC']
# 54. Kode C3 X: ['CCT', 'ACA']
# 55. Kode C3 X: ['CTC', 'CAA']
# 56. Kode C3 X: ['CTC', 'AAC']
# 57. Kode C3 X: ['CTC', 'ACA']
# 58. Kode C3 X: ['TCC', 'CAA']
# 59. Kode C3 X: ['TCC', 'AAC']
# 60. Kode C3 X: ['TCC', 'ACA']
# 61. Kode C3 X: ['CCT', 'CAG']
# 62. Kode C3 X: ['CCT', 'AGC']
# 63. Kode C3 X: ['CCT', 'GCA']
# 64. Kode C3 X: ['CTC', 'CAG']
# 65. Kode C3 X: ['CTC', 'AGC']
# 66. Kode C3 X: ['CTC', 'GCA']
# 67. Kode C3 X: ['TCC', 'CAG']
# 68. Kode C3 X: ['TCC', 'AGC']
# 69. Kode C3 X: ['TCC', 'GCA']
# 70. Kode C3 X: ['CCT', 'CGT']
# 71. Kode C3 X: ['CCT', 'GTC']
# 72. Kode C3 X: ['CCT', 'TCG']
# 73. Kode C3 X: ['CTC', 'CGT']
# 74. Kode C3 X: ['CTC', 'GTC']
# 75. Kode C3 X: ['CTC', 'TCG']
# 76. Kode C3 X: ['TCC', 'CGT']
# 77. Kode C3 X: ['TCC', 'GTC']
# 78. Kode C3 X: ['TCC', 'TCG']
# 79. Kode C3 X: ['CCT', 'CGA']
# 80. Kode C3 X: ['CCT', 'GAC']
# 81. Kode C3 X: ['CCT', 'ACG']
# 82. Kode C3 X: ['CTC', 'CGA']
# 83. Kode C3 X: ['CTC', 'GAC']
# 84. Kode C3 X: ['CTC', 'ACG']
# 85. Kode C3 X: ['TCC', 'CGA']
# 86. Kode C3 X: ['TCC', 'GAC']
# 87. Kode C3 X: ['TCC', 'ACG']
# 88. Kode C3 X: ['CCT', 'CGG']
# 89. Kode C3 X: ['CCT', 'GGC']
# 90. Kode C3 X: ['CCT', 'GCG']
# 91. Kode C3 X: ['CTC', 'CGG']
# 92. Kode C3 X: ['CTC', 'GGC']
# 93. Kode C3 X: ['CTC', 'GCG']
# 94. Kode C3 X: ['TCC', 'CGG']
# 95. Kode C3 X: ['TCC', 'GGC']
# 96. Kode C3 X: ['TCC', 'GCG']
# 97. Kode C3 X: ['CCT', 'TTA']
# 98. Kode C3 X: ['CCT', 'TAT']
# 99. Kode C3 X: ['CCT', 'ATT']
# 100. Kode C3 X: ['CTC', 'TTA']
# 101. Kode C3 X: ['CTC', 'TAT']
# 102. Kode C3 X: ['CTC', 'ATT']
# 103. Kode C3 X: ['TCC', 'TTA']
# 104. Kode C3 X: ['TCC', 'TAT']
# 105. Kode C3 X: ['TCC', 'ATT']
# 106. Kode C3 X: ['CCT', 'TTG']
# 107. Kode C3 X: ['CCT', 'TGT']
# 108. Kode C3 X: ['CCT', 'GTT']
# 109. Kode C3 X: ['CTC', 'TTG']
# 110. Kode C3 X: ['CTC', 'TGT']
# 111. Kode C3 X: ['CTC', 'GTT']
# 112. Kode C3 X: ['TCC', 'TTG']
# 113. Kode C3 X: ['TCC', 'TGT']
# 114. Kode C3 X: ['TCC', 'GTT']
# 115. Kode C3 X: ['CCT', 'TAA']
# 116. Kode C3 X: ['CCT', 'AAT']
# 117. Kode C3 X: ['CCT', 'ATA']
# 118. Kode C3 X: ['CTC', 'TAA']
# 119. Kode C3 X: ['CTC', 'AAT']
# 120. Kode C3 X: ['CTC', 'ATA']
# 121. Kode C3 X: ['TCC', 'TAA']
# 122. Kode C3 X: ['TCC', 'AAT']
# 123. Kode C3 X: ['TCC', 'ATA']
# 124. Kode C3 X: ['CCT', 'TAG']
# 125. Kode C3 X: ['CCT', 'AGT']
# 126. Kode C3 X: ['CCT', 'GTA']
# 127. Kode C3 X: ['CTC', 'TAG']
# 128. Kode C3 X: ['CTC', 'AGT']
# 129. Kode C3 X: ['CTC', 'GTA']
# 130. Kode C3 X: ['TCC', 'TAG']
# 131. Kode C3 X: ['TCC', 'AGT']
# 132. Kode C3 X: ['TCC', 'GTA']
# 133. Kode C3 X: ['CCT', 'TGA']
# 134. Kode C3 X: ['CCT', 'GAT']
# 135. Kode C3 X: ['CCT', 'ATG']
# 136. Kode C3 X: ['CTC', 'TGA']
# 137. Kode C3 X: ['CTC', 'GAT']
# 138. Kode C3 X: ['CTC', 'ATG']
# 139. Kode C3 X: ['TCC', 'TGA']
# 140. Kode C3 X: ['TCC', 'GAT']
# 141. Kode C3 X: ['TCC', 'ATG']
# 142. Kode C3 X: ['CCT', 'TGG']
# 143. Kode C3 X: ['CCT', 'GGT']
# 144. Kode C3 X: ['CCT', 'GTG']
# 145. Kode C3 X: ['CTC', 'TGG']
# 146. Kode C3 X: ['CTC', 'GGT']
# 147. Kode C3 X: ['CTC', 'GTG']
# 148. Kode C3 X: ['TCC', 'TGG']
# 149. Kode C3 X: ['TCC', 'GGT']
# 150. Kode C3 X: ['TCC', 'GTG']
# 151. Kode C3 X: ['CCT', 'AAG']
# 152. Kode C3 X: ['CCT', 'AGA']
# 153. Kode C3 X: ['CCT', 'GAA']
# 154. Kode C3 X: ['CTC', 'AAG']
# 155. Kode C3 X: ['CTC', 'AGA']
# 156. Kode C3 X: ['CTC', 'GAA']
# 157. Kode C3 X: ['TCC', 'AAG']
# 158. Kode C3 X: ['TCC', 'AGA']
# 159. Kode C3 X: ['TCC', 'GAA']
# 160. Kode C3 X: ['CCT', 'AGG']
# 161. Kode C3 X: ['CCT', 'GGA']
# 162. Kode C3 X: ['CCT', 'GAG']
# 163. Kode C3 X: ['CTC', 'AGG']
# 164. Kode C3 X: ['CTC', 'GGA']
# 165. Kode C3 X: ['CTC', 'GAG']
# 166. Kode C3 X: ['TCC', 'AGG']
# 167. Kode C3 X: ['TCC', 'GGA']
# 168. Kode C3 X: ['TCC', 'GAG']
# 169. Kode C3 X: ['CCA', 'CCG']
# 170. Kode C3 X: ['CCA', 'CGC']
# 171. Kode C3 X: ['CCA', 'GCC']
# 172. Kode C3 X: ['CAC', 'CCG']
# 173. Kode C3 X: ['CAC', 'CGC']
# 174. Kode C3 X: ['CAC', 'GCC']
# 175. Kode C3 X: ['ACC', 'CCG']
# 176. Kode C3 X: ['ACC', 'CGC']
# 177. Kode C3 X: ['ACC', 'GCC']
# 178. Kode C3 X: ['CCA', 'CTT']
# 179. Kode C3 X: ['CCA', 'TTC']
# 180. Kode C3 X: ['CCA', 'TCT']
# 181. Kode C3 X: ['CAC', 'CTT']
# 182. Kode C3 X: ['CAC', 'TTC']
# 183. Kode C3 X: ['CAC', 'TCT']
# 184. Kode C3 X: ['ACC', 'CTT']
# 185. Kode C3 X: ['ACC', 'TTC']
# 186. Kode C3 X: ['ACC', 'TCT']
# 187. Kode C3 X: ['CCA', 'CTA']
# 188. Kode C3 X: ['CCA', 'TAC']
# 189. Kode C3 X: ['CCA', 'ACT']
# 190. Kode C3 X: ['CAC', 'CTA']
# 191. Kode C3 X: ['CAC', 'TAC']
# 192. Kode C3 X: ['CAC', 'ACT']
# 193. Kode C3 X: ['ACC', 'CTA']
# 194. Kode C3 X: ['ACC', 'TAC']
# 195. Kode C3 X: ['ACC', 'ACT']
# 196. Kode C3 X: ['CCA', 'CTG']
# 197. Kode C3 X: ['CCA', 'TGC']
# 198. Kode C3 X: ['CCA', 'GCT']
# 199. Kode C3 X: ['CAC', 'CTG']
# 200. Kode C3 X: ['CAC', 'TGC']
# 201. Kode C3 X: ['CAC', 'GCT']
# 202. Kode C3 X: ['ACC', 'CTG']
# 203. Kode C3 X: ['ACC', 'TGC']
# 204. Kode C3 X: ['ACC', 'GCT']
# 205. Kode C3 X: ['CCA', 'CAT']
# 206. Kode C3 X: ['CCA', 'ATC']
# 207. Kode C3 X: ['CCA', 'TCA']
# 208. Kode C3 X: ['CAC', 'CAT']
# 209. Kode C3 X: ['CAC', 'ATC']
# 210. Kode C3 X: ['CAC', 'TCA']
# 211. Kode C3 X: ['ACC', 'CAT']
# 212. Kode C3 X: ['ACC', 'ATC']
# 213. Kode C3 X: ['ACC', 'TCA']
# 214. Kode C3 X: ['CCA', 'CAA']
# 215. Kode C3 X: ['CCA', 'ACA']
# 216. Kode C3 X: ['CAC', 'CAA']
# 217. Kode C3 X: ['CAC', 'AAC']
# 218. Kode C3 X: ['ACC', 'AAC']
# 219. Kode C3 X: ['ACC', 'ACA']
# 220. Kode C3 X: ['CCA', 'CAG']
# 221. Kode C3 X: ['CCA', 'AGC']
# 222. Kode C3 X: ['CCA', 'GCA']
# 223. Kode C3 X: ['CAC', 'CAG']
# 224. Kode C3 X: ['CAC', 'AGC']
# 225. Kode C3 X: ['CAC', 'GCA']
# 226. Kode C3 X: ['ACC', 'CAG']
# 227. Kode C3 X: ['ACC', 'AGC']
# 228. Kode C3 X: ['ACC', 'GCA']
# 229. Kode C3 X: ['CCA', 'CGT']
# 230. Kode C3 X: ['CCA', 'GTC']
# 231. Kode C3 X: ['CCA', 'TCG']
# 232. Kode C3 X: ['CAC', 'CGT']
# 233. Kode C3 X: ['CAC', 'GTC']
# 234. Kode C3 X: ['CAC', 'TCG']
# 235. Kode C3 X: ['ACC', 'CGT']
# 236. Kode C3 X: ['ACC', 'GTC']
# 237. Kode C3 X: ['ACC', 'TCG']
# 238. Kode C3 X: ['CCA', 'CGA']
# 239. Kode C3 X: ['CCA', 'GAC']
# 240. Kode C3 X: ['CCA', 'ACG']
# 241. Kode C3 X: ['CAC', 'CGA']
# 242. Kode C3 X: ['CAC', 'GAC']
# 243. Kode C3 X: ['CAC', 'ACG']
# 244. Kode C3 X: ['ACC', 'CGA']
# 245. Kode C3 X: ['ACC', 'GAC']
# 246. Kode C3 X: ['ACC', 'ACG']
# 247. Kode C3 X: ['CCA', 'CGG']
# 248. Kode C3 X: ['CCA', 'GGC']
# 249. Kode C3 X: ['CCA', 'GCG']
# 250. Kode C3 X: ['CAC', 'CGG']
# 251. Kode C3 X: ['CAC', 'GGC']
# 252. Kode C3 X: ['CAC', 'GCG']
# 253. Kode C3 X: ['ACC', 'CGG']
# 254. Kode C3 X: ['ACC', 'GGC']
# 255. Kode C3 X: ['ACC', 'GCG']
# 256. Kode C3 X: ['CCA', 'TTA']
# 257. Kode C3 X: ['CCA', 'TAT']
# 258. Kode C3 X: ['CCA', 'ATT']
# 259. Kode C3 X: ['CAC', 'TTA']
# 260. Kode C3 X: ['CAC', 'TAT']
# 261. Kode C3 X: ['CAC', 'ATT']
# 262. Kode C3 X: ['ACC', 'TTA']
# 263. Kode C3 X: ['ACC', 'TAT']
# 264. Kode C3 X: ['ACC', 'ATT']
# 265. Kode C3 X: ['CCA', 'TTG']
# 266. Kode C3 X: ['CCA', 'TGT']
# 267. Kode C3 X: ['CCA', 'GTT']
# 268. Kode C3 X: ['CAC', 'TTG']
# 269. Kode C3 X: ['CAC', 'TGT']
# 270. Kode C3 X: ['CAC', 'GTT']
# 271. Kode C3 X: ['ACC', 'TTG']
# 272. Kode C3 X: ['ACC', 'TGT']
# 273. Kode C3 X: ['ACC', 'GTT']
# 274. Kode C3 X: ['CCA', 'TAA']
# 275. Kode C3 X: ['CCA', 'AAT']
# 276. Kode C3 X: ['CCA', 'ATA']
# 277. Kode C3 X: ['CAC', 'TAA']
# 278. Kode C3 X: ['CAC', 'AAT']
# 279. Kode C3 X: ['CAC', 'ATA']
# 280. Kode C3 X: ['ACC', 'TAA']
# 281. Kode C3 X: ['ACC', 'AAT']
# 282. Kode C3 X: ['ACC', 'ATA']
# 283. Kode C3 X: ['CCA', 'TAG']
# 284. Kode C3 X: ['CCA', 'AGT']
# 285. Kode C3 X: ['CCA', 'GTA']
# 286. Kode C3 X: ['CAC', 'TAG']
# 287. Kode C3 X: ['CAC', 'AGT']
# 288. Kode C3 X: ['CAC', 'GTA']
# 289. Kode C3 X: ['ACC', 'TAG']
# 290. Kode C3 X: ['ACC', 'AGT']
# 291. Kode C3 X: ['ACC', 'GTA']
# 292. Kode C3 X: ['CCA', 'TGA']
# 293. Kode C3 X: ['CCA', 'GAT']
# 294. Kode C3 X: ['CCA', 'ATG']
# 295. Kode C3 X: ['CAC', 'TGA']
# 296. Kode C3 X: ['CAC', 'GAT']
# 297. Kode C3 X: ['CAC', 'ATG']
# 298. Kode C3 X: ['ACC', 'TGA']
# 299. Kode C3 X: ['ACC', 'GAT']
# 300. Kode C3 X: ['ACC', 'ATG']
# 301. Kode C3 X: ['CCA', 'TGG']
# 302. Kode C3 X: ['CCA', 'GGT']
# 303. Kode C3 X: ['CCA', 'GTG']
# 304. Kode C3 X: ['CAC', 'TGG']
# 305. Kode C3 X: ['CAC', 'GGT']
# 306. Kode C3 X: ['CAC', 'GTG']
# 307. Kode C3 X: ['ACC', 'TGG']
# 308. Kode C3 X: ['ACC', 'GGT']
# 309. Kode C3 X: ['ACC', 'GTG']
# 310. Kode C3 X: ['CCA', 'AAG']
# 311. Kode C3 X: ['CCA', 'AGA']
# 312. Kode C3 X: ['CCA', 'GAA']
# 313. Kode C3 X: ['CAC', 'AAG']
# 314. Kode C3 X: ['CAC', 'AGA']
# 315. Kode C3 X: ['CAC', 'GAA']
# 316. Kode C3 X: ['ACC', 'AAG']
# 317. Kode C3 X: ['ACC', 'AGA']
# 318. Kode C3 X: ['ACC', 'GAA']
# 319. Kode C3 X: ['CCA', 'AGG']
# 320. Kode C3 X: ['CCA', 'GGA']
# 321. Kode C3 X: ['CCA', 'GAG']
# 322. Kode C3 X: ['CAC', 'AGG']
# 323. Kode C3 X: ['CAC', 'GGA']
# 324. Kode C3 X: ['CAC', 'GAG']
# 325. Kode C3 X: ['ACC', 'AGG']
# 326. Kode C3 X: ['ACC', 'GGA']
# 327. Kode C3 X: ['ACC', 'GAG']
# 328. Kode C3 X: ['CCG', 'CTT']
# 329. Kode C3 X: ['CCG', 'TTC']
# 330. Kode C3 X: ['CCG', 'TCT']
# 331. Kode C3 X: ['CGC', 'CTT']
# 332. Kode C3 X: ['CGC', 'TTC']
# 333. Kode C3 X: ['CGC', 'TCT']
# 334. Kode C3 X: ['GCC', 'CTT']
# 335. Kode C3 X: ['GCC', 'TTC']
# 336. Kode C3 X: ['GCC', 'TCT']
# 337. Kode C3 X: ['CCG', 'CTA']
# 338. Kode C3 X: ['CCG', 'TAC']
# 339. Kode C3 X: ['CCG', 'ACT']
# 340. Kode C3 X: ['CGC', 'CTA']
# 341. Kode C3 X: ['CGC', 'TAC']
# 342. Kode C3 X: ['CGC', 'ACT']
# 343. Kode C3 X: ['GCC', 'CTA']
# 344. Kode C3 X: ['GCC', 'TAC']
# 345. Kode C3 X: ['GCC', 'ACT']
# 346. Kode C3 X: ['CCG', 'CTG']
# 347. Kode C3 X: ['CCG', 'TGC']
# 348. Kode C3 X: ['CCG', 'GCT']
# 349. Kode C3 X: ['CGC', 'CTG']
# 350. Kode C3 X: ['CGC', 'TGC']
# 351. Kode C3 X: ['CGC', 'GCT']
# 352. Kode C3 X: ['GCC', 'CTG']
# 353. Kode C3 X: ['GCC', 'TGC']
# 354. Kode C3 X: ['GCC', 'GCT']
# 355. Kode C3 X: ['CCG', 'CAT']
# 356. Kode C3 X: ['CCG', 'ATC']
# 357. Kode C3 X: ['CCG', 'TCA']
# 358. Kode C3 X: ['CGC', 'CAT']
# 359. Kode C3 X: ['CGC', 'ATC']
# 360. Kode C3 X: ['CGC', 'TCA']
# 361. Kode C3 X: ['GCC', 'CAT']
# 362. Kode C3 X: ['GCC', 'ATC']
# 363. Kode C3 X: ['GCC', 'TCA']
# 364. Kode C3 X: ['CCG', 'CAA']
# 365. Kode C3 X: ['CCG', 'AAC']
# 366. Kode C3 X: ['CCG', 'ACA']
# 367. Kode C3 X: ['CGC', 'CAA']
# 368. Kode C3 X: ['CGC', 'AAC']
# 369. Kode C3 X: ['CGC', 'ACA']
# 370. Kode C3 X: ['GCC', 'CAA']
# 371. Kode C3 X: ['GCC', 'AAC']
# 372. Kode C3 X: ['GCC', 'ACA']
# 373. Kode C3 X: ['CCG', 'CAG']
# 374. Kode C3 X: ['CCG', 'AGC']
# 375. Kode C3 X: ['CCG', 'GCA']
# 376. Kode C3 X: ['CGC', 'CAG']
# 377. Kode C3 X: ['CGC', 'AGC']
# 378. Kode C3 X: ['CGC', 'GCA']
# 379. Kode C3 X: ['GCC', 'CAG']
# 380. Kode C3 X: ['GCC', 'AGC']
# 381. Kode C3 X: ['GCC', 'GCA']
# 382. Kode C3 X: ['CCG', 'CGT']
# 383. Kode C3 X: ['CCG', 'GTC']
# 384. Kode C3 X: ['CCG', 'TCG']
# 385. Kode C3 X: ['CGC', 'CGT']
# 386. Kode C3 X: ['CGC', 'GTC']
# 387. Kode C3 X: ['CGC', 'TCG']
# 388. Kode C3 X: ['GCC', 'CGT']
# 389. Kode C3 X: ['GCC', 'GTC']
# 390. Kode C3 X: ['GCC', 'TCG']
# 391. Kode C3 X: ['CCG', 'CGA']
# 392. Kode C3 X: ['CCG', 'GAC']
# 393. Kode C3 X: ['CCG', 'ACG']
# 394. Kode C3 X: ['CGC', 'CGA']
# 395. Kode C3 X: ['CGC', 'GAC']
# 396. Kode C3 X: ['CGC', 'ACG']
# 397. Kode C3 X: ['GCC', 'CGA']
# 398. Kode C3 X: ['GCC', 'GAC']
# 399. Kode C3 X: ['GCC', 'ACG']
# 400. Kode C3 X: ['CCG', 'CGG']
# 401. Kode C3 X: ['CCG', 'GCG']
# 402. Kode C3 X: ['CGC', 'CGG']
# 403. Kode C3 X: ['CGC', 'GGC']
# 404. Kode C3 X: ['GCC', 'GGC']
# 405. Kode C3 X: ['GCC', 'GCG']
# 406. Kode C3 X: ['CCG', 'TTA']
# 407. Kode C3 X: ['CCG', 'TAT']
# 408. Kode C3 X: ['CCG', 'ATT']
# 409. Kode C3 X: ['CGC', 'TTA']
# 410. Kode C3 X: ['CGC', 'TAT']
# 411. Kode C3 X: ['CGC', 'ATT']
# 412. Kode C3 X: ['GCC', 'TTA']
# 413. Kode C3 X: ['GCC', 'TAT']
# 414. Kode C3 X: ['GCC', 'ATT']
# 415. Kode C3 X: ['CCG', 'TTG']
# 416. Kode C3 X: ['CCG', 'TGT']
# 417. Kode C3 X: ['CCG', 'GTT']
# 418. Kode C3 X: ['CGC', 'TTG']
# 419. Kode C3 X: ['CGC', 'TGT']
# 420. Kode C3 X: ['CGC', 'GTT']
# 421. Kode C3 X: ['GCC', 'TTG']
# 422. Kode C3 X: ['GCC', 'TGT']
# 423. Kode C3 X: ['GCC', 'GTT']
# 424. Kode C3 X: ['CCG', 'TAA']
# 425. Kode C3 X: ['CCG', 'AAT']
# 426. Kode C3 X: ['CCG', 'ATA']
# 427. Kode C3 X: ['CGC', 'TAA']
# 428. Kode C3 X: ['CGC', 'AAT']
# 429. Kode C3 X: ['CGC', 'ATA']
# 430. Kode C3 X: ['GCC', 'TAA']
# 431. Kode C3 X: ['GCC', 'AAT']
# 432. Kode C3 X: ['GCC', 'ATA']
# 433. Kode C3 X: ['CCG', 'TAG']
# 434. Kode C3 X: ['CCG', 'AGT']
# 435. Kode C3 X: ['CCG', 'GTA']
# 436. Kode C3 X: ['CGC', 'TAG']
# 437. Kode C3 X: ['CGC', 'AGT']
# 438. Kode C3 X: ['CGC', 'GTA']
# 439. Kode C3 X: ['GCC', 'TAG']
# 440. Kode C3 X: ['GCC', 'AGT']
# 441. Kode C3 X: ['GCC', 'GTA']
# 442. Kode C3 X: ['CCG', 'TGA']
# 443. Kode C3 X: ['CCG', 'GAT']
# 444. Kode C3 X: ['CCG', 'ATG']
# 445. Kode C3 X: ['CGC', 'TGA']
# 446. Kode C3 X: ['CGC', 'GAT']
# 447. Kode C3 X: ['CGC', 'ATG']
# 448. Kode C3 X: ['GCC', 'TGA']
# 449. Kode C3 X: ['GCC', 'GAT']
# 450. Kode C3 X: ['GCC', 'ATG']
# 451. Kode C3 X: ['CCG', 'TGG']
# 452. Kode C3 X: ['CCG', 'GGT']
# 453. Kode C3 X: ['CCG', 'GTG']
# 454. Kode C3 X: ['CGC', 'TGG']
# 455. Kode C3 X: ['CGC', 'GGT']
# 456. Kode C3 X: ['CGC', 'GTG']
# 457. Kode C3 X: ['GCC', 'TGG']
# 458. Kode C3 X: ['GCC', 'GGT']
# 459. Kode C3 X: ['GCC', 'GTG']
# 460. Kode C3 X: ['CCG', 'AAG']
# 461. Kode C3 X: ['CCG', 'AGA']
# 462. Kode C3 X: ['CCG', 'GAA']
# 463. Kode C3 X: ['CGC', 'AAG']
# 464. Kode C3 X: ['CGC', 'AGA']
# 465. Kode C3 X: ['CGC', 'GAA']
# 466. Kode C3 X: ['GCC', 'AAG']
# 467. Kode C3 X: ['GCC', 'AGA']
# 468. Kode C3 X: ['GCC', 'GAA']
# 469. Kode C3 X: ['CCG', 'AGG']
# 470. Kode C3 X: ['CCG', 'GGA']
# 471. Kode C3 X: ['CCG', 'GAG']
# 472. Kode C3 X: ['CGC', 'AGG']
# 473. Kode C3 X: ['CGC', 'GGA']
# 474. Kode C3 X: ['CGC', 'GAG']
# 475. Kode C3 X: ['GCC', 'AGG']
# 476. Kode C3 X: ['GCC', 'GGA']
# 477. Kode C3 X: ['GCC', 'GAG']
# 478. Kode C3 X: ['CTT', 'CTA']
# 479. Kode C3 X: ['CTT', 'TAC']
# 480. Kode C3 X: ['CTT', 'ACT']
# 481. Kode C3 X: ['TTC', 'CTA']
# 482. Kode C3 X: ['TTC', 'TAC']
# 483. Kode C3 X: ['TTC', 'ACT']
# 484. Kode C3 X: ['TCT', 'CTA']
# 485. Kode C3 X: ['TCT', 'TAC']
# 486. Kode C3 X: ['TCT', 'ACT']
# 487. Kode C3 X: ['CTT', 'CTG']
# 488. Kode C3 X: ['CTT', 'TGC']
# 489. Kode C3 X: ['CTT', 'GCT']
# 490. Kode C3 X: ['TTC', 'CTG']
# 491. Kode C3 X: ['TTC', 'TGC']
# 492. Kode C3 X: ['TTC', 'GCT']
# 493. Kode C3 X: ['TCT', 'CTG']
# 494. Kode C3 X: ['TCT', 'TGC']
# 495. Kode C3 X: ['TCT', 'GCT']
# 496. Kode C3 X: ['CTT', 'CAT']
# 497. Kode C3 X: ['CTT', 'ATC']
# 498. Kode C3 X: ['CTT', 'TCA']
# 499. Kode C3 X: ['TTC', 'CAT']
# 500. Kode C3 X: ['TTC', 'ATC']
# 501. Kode C3 X: ['TTC', 'TCA']
# 502. Kode C3 X: ['TCT', 'CAT']
# 503. Kode C3 X: ['TCT', 'ATC']
# 504. Kode C3 X: ['TCT', 'TCA']
# 505. Kode C3 X: ['CTT', 'CAA']
# 506. Kode C3 X: ['CTT', 'AAC']
# 507. Kode C3 X: ['CTT', 'ACA']
# 508. Kode C3 X: ['TTC', 'CAA']
# 509. Kode C3 X: ['TTC', 'AAC']
# 510. Kode C3 X: ['TTC', 'ACA']
# 511. Kode C3 X: ['TCT', 'CAA']
# 512. Kode C3 X: ['TCT', 'AAC']
# 513. Kode C3 X: ['TCT', 'ACA']
# 514. Kode C3 X: ['CTT', 'CAG']
# 515. Kode C3 X: ['CTT', 'AGC']
# 516. Kode C3 X: ['CTT', 'GCA']
# 517. Kode C3 X: ['TTC', 'CAG']
# 518. Kode C3 X: ['TTC', 'AGC']
# 519. Kode C3 X: ['TTC', 'GCA']
# 520. Kode C3 X: ['TCT', 'CAG']
# 521. Kode C3 X: ['TCT', 'AGC']
# 522. Kode C3 X: ['TCT', 'GCA']
# 523. Kode C3 X: ['CTT', 'CGT']
# 524. Kode C3 X: ['CTT', 'GTC']
# 525. Kode C3 X: ['CTT', 'TCG']
# 526. Kode C3 X: ['TTC', 'CGT']
# 527. Kode C3 X: ['TTC', 'GTC']
# 528. Kode C3 X: ['TTC', 'TCG']
# 529. Kode C3 X: ['TCT', 'CGT']
# 530. Kode C3 X: ['TCT', 'GTC']
# 531. Kode C3 X: ['TCT', 'TCG']
# 532. Kode C3 X: ['CTT', 'CGA']
# 533. Kode C3 X: ['CTT', 'GAC']
# 534. Kode C3 X: ['CTT', 'ACG']
# 535. Kode C3 X: ['TTC', 'CGA']
# 536. Kode C3 X: ['TTC', 'GAC']
# 537. Kode C3 X: ['TTC', 'ACG']
# 538. Kode C3 X: ['TCT', 'CGA']
# 539. Kode C3 X: ['TCT', 'GAC']
# 540. Kode C3 X: ['TCT', 'ACG']
# 541. Kode C3 X: ['CTT', 'CGG']
# 542. Kode C3 X: ['CTT', 'GGC']
# 543. Kode C3 X: ['CTT', 'GCG']
# 544. Kode C3 X: ['TTC', 'CGG']
# 545. Kode C3 X: ['TTC', 'GGC']
# 546. Kode C3 X: ['TTC', 'GCG']
# 547. Kode C3 X: ['TCT', 'CGG']
# 548. Kode C3 X: ['TCT', 'GGC']
# 549. Kode C3 X: ['TCT', 'GCG']
# 550. Kode C3 X: ['CTT', 'TTA']
# 551. Kode C3 X: ['CTT', 'TAT']
# 552. Kode C3 X: ['CTT', 'ATT']
# 553. Kode C3 X: ['TTC', 'TTA']
# 554. Kode C3 X: ['TTC', 'TAT']
# 555. Kode C3 X: ['TTC', 'ATT']
# 556. Kode C3 X: ['TCT', 'TTA']
# 557. Kode C3 X: ['TCT', 'TAT']
# 558. Kode C3 X: ['TCT', 'ATT']
# 559. Kode C3 X: ['CTT', 'TTG']
# 560. Kode C3 X: ['CTT', 'TGT']
# 561. Kode C3 X: ['CTT', 'GTT']
# 562. Kode C3 X: ['TTC', 'TTG']
# 563. Kode C3 X: ['TTC', 'TGT']
# 564. Kode C3 X: ['TTC', 'GTT']
# 565. Kode C3 X: ['TCT', 'TTG']
# 566. Kode C3 X: ['TCT', 'TGT']
# 567. Kode C3 X: ['TCT', 'GTT']
# 568. Kode C3 X: ['CTT', 'TAA']
# 569. Kode C3 X: ['CTT', 'AAT']
# 570. Kode C3 X: ['CTT', 'ATA']
# 571. Kode C3 X: ['TTC', 'TAA']
# 572. Kode C3 X: ['TTC', 'AAT']
# 573. Kode C3 X: ['TTC', 'ATA']
# 574. Kode C3 X: ['TCT', 'TAA']
# 575. Kode C3 X: ['TCT', 'AAT']
# 576. Kode C3 X: ['TCT', 'ATA']
# 577. Kode C3 X: ['CTT', 'TAG']
# 578. Kode C3 X: ['CTT', 'AGT']
# 579. Kode C3 X: ['CTT', 'GTA']
# 580. Kode C3 X: ['TTC', 'TAG']
# 581. Kode C3 X: ['TTC', 'AGT']
# 582. Kode C3 X: ['TTC', 'GTA']
# 583. Kode C3 X: ['TCT', 'TAG']
# 584. Kode C3 X: ['TCT', 'AGT']
# 585. Kode C3 X: ['TCT', 'GTA']
# 586. Kode C3 X: ['CTT', 'TGA']
# 587. Kode C3 X: ['CTT', 'GAT']
# 588. Kode C3 X: ['CTT', 'ATG']
# 589. Kode C3 X: ['TTC', 'TGA']
# 590. Kode C3 X: ['TTC', 'GAT']
# 591. Kode C3 X: ['TTC', 'ATG']
# 592. Kode C3 X: ['TCT', 'TGA']
# 593. Kode C3 X: ['TCT', 'GAT']
# 594. Kode C3 X: ['TCT', 'ATG']
# 595. Kode C3 X: ['CTT', 'TGG']
# 596. Kode C3 X: ['CTT', 'GGT']
# 597. Kode C3 X: ['CTT', 'GTG']
# 598. Kode C3 X: ['TTC', 'TGG']
# 599. Kode C3 X: ['TTC', 'GGT']
# 600. Kode C3 X: ['TTC', 'GTG']
# 601. Kode C3 X: ['TCT', 'TGG']
# 602. Kode C3 X: ['TCT', 'GGT']
# 603. Kode C3 X: ['TCT', 'GTG']
# 604. Kode C3 X: ['CTT', 'AAG']
# 605. Kode C3 X: ['CTT', 'AGA']
# 606. Kode C3 X: ['CTT', 'GAA']
# 607. Kode C3 X: ['TTC', 'AAG']
# 608. Kode C3 X: ['TTC', 'AGA']
# 609. Kode C3 X: ['TTC', 'GAA']
# 610. Kode C3 X: ['TCT', 'AAG']
# 611. Kode C3 X: ['TCT', 'AGA']
# 612. Kode C3 X: ['TCT', 'GAA']
# 613. Kode C3 X: ['CTT', 'AGG']
# 614. Kode C3 X: ['CTT', 'GGA']
# 615. Kode C3 X: ['CTT', 'GAG']
# 616. Kode C3 X: ['TTC', 'AGG']
# 617. Kode C3 X: ['TTC', 'GGA']
# 618. Kode C3 X: ['TTC', 'GAG']
# 619. Kode C3 X: ['TCT', 'AGG']
# 620. Kode C3 X: ['TCT', 'GGA']
# 621. Kode C3 X: ['TCT', 'GAG']
# 622. Kode C3 X: ['CTA', 'CTG']
# 623. Kode C3 X: ['CTA', 'TGC']
# 624. Kode C3 X: ['CTA', 'GCT']
# 625. Kode C3 X: ['TAC', 'CTG']
# 626. Kode C3 X: ['TAC', 'TGC']
# 627. Kode C3 X: ['TAC', 'GCT']
# 628. Kode C3 X: ['ACT', 'CTG']
# 629. Kode C3 X: ['ACT', 'TGC']
# 630. Kode C3 X: ['ACT', 'GCT']
# 631. Kode C3 X: ['CTA', 'CAT']
# 632. Kode C3 X: ['CTA', 'ATC']
# 633. Kode C3 X: ['CTA', 'TCA']
# 634. Kode C3 X: ['TAC', 'CAT']
# 635. Kode C3 X: ['TAC', 'ATC']
# 636. Kode C3 X: ['TAC', 'TCA']
# 637. Kode C3 X: ['ACT', 'CAT']
# 638. Kode C3 X: ['ACT', 'ATC']
# 639. Kode C3 X: ['ACT', 'TCA']
# 640. Kode C3 X: ['CTA', 'CAA']
# 641. Kode C3 X: ['CTA', 'AAC']
# 642. Kode C3 X: ['CTA', 'ACA']
# 643. Kode C3 X: ['TAC', 'CAA']
# 644. Kode C3 X: ['TAC', 'AAC']
# 645. Kode C3 X: ['TAC', 'ACA']
# 646. Kode C3 X: ['ACT', 'CAA']
# 647. Kode C3 X: ['ACT', 'AAC']
# 648. Kode C3 X: ['ACT', 'ACA']
# 649. Kode C3 X: ['CTA', 'CAG']
# 650. Kode C3 X: ['CTA', 'AGC']
# 651. Kode C3 X: ['CTA', 'GCA']
# 652. Kode C3 X: ['TAC', 'CAG']
# 653. Kode C3 X: ['TAC', 'AGC']
# 654. Kode C3 X: ['TAC', 'GCA']
# 655. Kode C3 X: ['ACT', 'CAG']
# 656. Kode C3 X: ['ACT', 'AGC']
# 657. Kode C3 X: ['ACT', 'GCA']
# 658. Kode C3 X: ['CTA', 'CGT']
# 659. Kode C3 X: ['CTA', 'GTC']
# 660. Kode C3 X: ['CTA', 'TCG']
# 661. Kode C3 X: ['TAC', 'CGT']
# 662. Kode C3 X: ['TAC', 'GTC']
# 663. Kode C3 X: ['TAC', 'TCG']
# 664. Kode C3 X: ['ACT', 'CGT']
# 665. Kode C3 X: ['ACT', 'GTC']
# 666. Kode C3 X: ['ACT', 'TCG']
# 667. Kode C3 X: ['CTA', 'CGA']
# 668. Kode C3 X: ['CTA', 'GAC']
# 669. Kode C3 X: ['CTA', 'ACG']
# 670. Kode C3 X: ['TAC', 'CGA']
# 671. Kode C3 X: ['TAC', 'GAC']
# 672. Kode C3 X: ['TAC', 'ACG']
# 673. Kode C3 X: ['ACT', 'CGA']
# 674. Kode C3 X: ['ACT', 'GAC']
# 675. Kode C3 X: ['ACT', 'ACG']
# 676. Kode C3 X: ['CTA', 'CGG']
# 677. Kode C3 X: ['CTA', 'GGC']
# 678. Kode C3 X: ['CTA', 'GCG']
# 679. Kode C3 X: ['TAC', 'CGG']
# 680. Kode C3 X: ['TAC', 'GGC']
# 681. Kode C3 X: ['TAC', 'GCG']
# 682. Kode C3 X: ['ACT', 'CGG']
# 683. Kode C3 X: ['ACT', 'GGC']
# 684. Kode C3 X: ['ACT', 'GCG']
# 685. Kode C3 X: ['CTA', 'TTA']
# 686. Kode C3 X: ['CTA', 'TAT']
# 687. Kode C3 X: ['CTA', 'ATT']
# 688. Kode C3 X: ['TAC', 'TTA']
# 689. Kode C3 X: ['TAC', 'TAT']
# 690. Kode C3 X: ['TAC', 'ATT']
# 691. Kode C3 X: ['ACT', 'TTA']
# 692. Kode C3 X: ['ACT', 'TAT']
# 693. Kode C3 X: ['ACT', 'ATT']
# 694. Kode C3 X: ['CTA', 'TTG']
# 695. Kode C3 X: ['CTA', 'TGT']
# 696. Kode C3 X: ['CTA', 'GTT']
# 697. Kode C3 X: ['TAC', 'TTG']
# 698. Kode C3 X: ['TAC', 'TGT']
# 699. Kode C3 X: ['TAC', 'GTT']
# 700. Kode C3 X: ['ACT', 'TTG']
# 701. Kode C3 X: ['ACT', 'TGT']
# 702. Kode C3 X: ['ACT', 'GTT']
# 703. Kode C3 X: ['CTA', 'TAA']
# 704. Kode C3 X: ['CTA', 'AAT']
# 705. Kode C3 X: ['CTA', 'ATA']
# 706. Kode C3 X: ['TAC', 'TAA']
# 707. Kode C3 X: ['TAC', 'AAT']
# 708. Kode C3 X: ['TAC', 'ATA']
# 709. Kode C3 X: ['ACT', 'TAA']
# 710. Kode C3 X: ['ACT', 'AAT']
# 711. Kode C3 X: ['ACT', 'ATA']
# 712. Kode C3 X: ['CTA', 'TAG']
# 713. Kode C3 X: ['CTA', 'AGT']
# 714. Kode C3 X: ['CTA', 'GTA']
# 715. Kode C3 X: ['TAC', 'TAG']
# 716. Kode C3 X: ['TAC', 'AGT']
# 717. Kode C3 X: ['TAC', 'GTA']
# 718. Kode C3 X: ['ACT', 'TAG']
# 719. Kode C3 X: ['ACT', 'AGT']
# 720. Kode C3 X: ['ACT', 'GTA']
# 721. Kode C3 X: ['CTA', 'TGA']
# 722. Kode C3 X: ['CTA', 'GAT']
# 723. Kode C3 X: ['CTA', 'ATG']
# 724. Kode C3 X: ['TAC', 'TGA']
# 725. Kode C3 X: ['TAC', 'GAT']
# 726. Kode C3 X: ['TAC', 'ATG']
# 727. Kode C3 X: ['ACT', 'TGA']
# 728. Kode C3 X: ['ACT', 'GAT']
# 729. Kode C3 X: ['ACT', 'ATG']
# 730. Kode C3 X: ['CTA', 'TGG']
# 731. Kode C3 X: ['CTA', 'GGT']
# 732. Kode C3 X: ['CTA', 'GTG']
# 733. Kode C3 X: ['TAC', 'TGG']
# 734. Kode C3 X: ['TAC', 'GGT']
# 735. Kode C3 X: ['TAC', 'GTG']
# 736. Kode C3 X: ['ACT', 'TGG']
# 737. Kode C3 X: ['ACT', 'GGT']
# 738. Kode C3 X: ['ACT', 'GTG']
# 739. Kode C3 X: ['CTA', 'AAG']
# 740. Kode C3 X: ['CTA', 'AGA']
# 741. Kode C3 X: ['CTA', 'GAA']
# 742. Kode C3 X: ['TAC', 'AAG']
# 743. Kode C3 X: ['TAC', 'AGA']
# 744. Kode C3 X: ['TAC', 'GAA']
# 745. Kode C3 X: ['ACT', 'AAG']
# 746. Kode C3 X: ['ACT', 'AGA']
# 747. Kode C3 X: ['ACT', 'GAA']
# 748. Kode C3 X: ['CTA', 'AGG']
# 749. Kode C3 X: ['CTA', 'GGA']
# 750. Kode C3 X: ['CTA', 'GAG']
# 751. Kode C3 X: ['TAC', 'AGG']
# 752. Kode C3 X: ['TAC', 'GGA']
# 753. Kode C3 X: ['TAC', 'GAG']
# 754. Kode C3 X: ['ACT', 'AGG']
# 755. Kode C3 X: ['ACT', 'GGA']
# 756. Kode C3 X: ['ACT', 'GAG']
# 757. Kode C3 X: ['CTG', 'CAT']
# 758. Kode C3 X: ['CTG', 'ATC']
# 759. Kode C3 X: ['CTG', 'TCA']
# 760. Kode C3 X: ['TGC', 'CAT']
# 761. Kode C3 X: ['TGC', 'ATC']
# 762. Kode C3 X: ['TGC', 'TCA']
# 763. Kode C3 X: ['GCT', 'CAT']
# 764. Kode C3 X: ['GCT', 'ATC']
# 765. Kode C3 X: ['GCT', 'TCA']
# 766. Kode C3 X: ['CTG', 'CAA']
# 767. Kode C3 X: ['CTG', 'AAC']
# 768. Kode C3 X: ['CTG', 'ACA']
# 769. Kode C3 X: ['TGC', 'CAA']
# 770. Kode C3 X: ['TGC', 'AAC']
# 771. Kode C3 X: ['TGC', 'ACA']
# 772. Kode C3 X: ['GCT', 'CAA']
# 773. Kode C3 X: ['GCT', 'AAC']
# 774. Kode C3 X: ['GCT', 'ACA']
# 775. Kode C3 X: ['CTG', 'CAG']
# 776. Kode C3 X: ['CTG', 'AGC']
# 777. Kode C3 X: ['CTG', 'GCA']
# 778. Kode C3 X: ['TGC', 'CAG']
# 779. Kode C3 X: ['TGC', 'AGC']
# 780. Kode C3 X: ['TGC', 'GCA']
# 781. Kode C3 X: ['GCT', 'CAG']
# 782. Kode C3 X: ['GCT', 'AGC']
# 783. Kode C3 X: ['GCT', 'GCA']
# 784. Kode C3 X: ['CTG', 'CGT']
# 785. Kode C3 X: ['CTG', 'GTC']
# 786. Kode C3 X: ['CTG', 'TCG']
# 787. Kode C3 X: ['TGC', 'CGT']
# 788. Kode C3 X: ['TGC', 'GTC']
# 789. Kode C3 X: ['TGC', 'TCG']
# 790. Kode C3 X: ['GCT', 'CGT']
# 791. Kode C3 X: ['GCT', 'GTC']
# 792. Kode C3 X: ['GCT', 'TCG']
# 793. Kode C3 X: ['CTG', 'CGA']
# 794. Kode C3 X: ['CTG', 'GAC']
# 795. Kode C3 X: ['CTG', 'ACG']
# 796. Kode C3 X: ['TGC', 'CGA']
# 797. Kode C3 X: ['TGC', 'GAC']
# 798. Kode C3 X: ['TGC', 'ACG']
# 799. Kode C3 X: ['GCT', 'CGA']
# 800. Kode C3 X: ['GCT', 'GAC']
# 801. Kode C3 X: ['GCT', 'ACG']
# 802. Kode C3 X: ['CTG', 'CGG']
# 803. Kode C3 X: ['CTG', 'GGC']
# 804. Kode C3 X: ['CTG', 'GCG']
# 805. Kode C3 X: ['TGC', 'CGG']
# 806. Kode C3 X: ['TGC', 'GGC']
# 807. Kode C3 X: ['TGC', 'GCG']
# 808. Kode C3 X: ['GCT', 'CGG']
# 809. Kode C3 X: ['GCT', 'GGC']
# 810. Kode C3 X: ['GCT', 'GCG']
# 811. Kode C3 X: ['CTG', 'TTA']
# 812. Kode C3 X: ['CTG', 'TAT']
# 813. Kode C3 X: ['CTG', 'ATT']
# 814. Kode C3 X: ['TGC', 'TTA']
# 815. Kode C3 X: ['TGC', 'TAT']
# 816. Kode C3 X: ['TGC', 'ATT']
# 817. Kode C3 X: ['GCT', 'TTA']
# 818. Kode C3 X: ['GCT', 'TAT']
# 819. Kode C3 X: ['GCT', 'ATT']
# 820. Kode C3 X: ['CTG', 'TTG']
# 821. Kode C3 X: ['CTG', 'TGT']
# 822. Kode C3 X: ['CTG', 'GTT']
# 823. Kode C3 X: ['TGC', 'TTG']
# 824. Kode C3 X: ['TGC', 'TGT']
# 825. Kode C3 X: ['TGC', 'GTT']
# 826. Kode C3 X: ['GCT', 'TTG']
# 827. Kode C3 X: ['GCT', 'TGT']
# 828. Kode C3 X: ['GCT', 'GTT']
# 829. Kode C3 X: ['CTG', 'TAA']
# 830. Kode C3 X: ['CTG', 'AAT']
# 831. Kode C3 X: ['CTG', 'ATA']
# 832. Kode C3 X: ['TGC', 'TAA']
# 833. Kode C3 X: ['TGC', 'AAT']
# 834. Kode C3 X: ['TGC', 'ATA']
# 835. Kode C3 X: ['GCT', 'TAA']
# 836. Kode C3 X: ['GCT', 'AAT']
# 837. Kode C3 X: ['GCT', 'ATA']
# 838. Kode C3 X: ['CTG', 'TAG']
# 839. Kode C3 X: ['CTG', 'AGT']
# 840. Kode C3 X: ['CTG', 'GTA']
# 841. Kode C3 X: ['TGC', 'TAG']
# 842. Kode C3 X: ['TGC', 'AGT']
# 843. Kode C3 X: ['TGC', 'GTA']
# 844. Kode C3 X: ['GCT', 'TAG']
# 845. Kode C3 X: ['GCT', 'AGT']
# 846. Kode C3 X: ['GCT', 'GTA']
# 847. Kode C3 X: ['CTG', 'TGA']
# 848. Kode C3 X: ['CTG', 'GAT']
# 849. Kode C3 X: ['CTG', 'ATG']
# 850. Kode C3 X: ['TGC', 'TGA']
# 851. Kode C3 X: ['TGC', 'GAT']
# 852. Kode C3 X: ['TGC', 'ATG']
# 853. Kode C3 X: ['GCT', 'TGA']
# 854. Kode C3 X: ['GCT', 'GAT']
# 855. Kode C3 X: ['GCT', 'ATG']
# 856. Kode C3 X: ['CTG', 'TGG']
# 857. Kode C3 X: ['CTG', 'GGT']
# 858. Kode C3 X: ['CTG', 'GTG']
# 859. Kode C3 X: ['TGC', 'TGG']
# 860. Kode C3 X: ['TGC', 'GGT']
# 861. Kode C3 X: ['TGC', 'GTG']
# 862. Kode C3 X: ['GCT', 'TGG']
# 863. Kode C3 X: ['GCT', 'GGT']
# 864. Kode C3 X: ['GCT', 'GTG']
# 865. Kode C3 X: ['CTG', 'AAG']
# 866. Kode C3 X: ['CTG', 'AGA']
# 867. Kode C3 X: ['CTG', 'GAA']
# 868. Kode C3 X: ['TGC', 'AAG']
# 869. Kode C3 X: ['TGC', 'AGA']
# 870. Kode C3 X: ['TGC', 'GAA']
# 871. Kode C3 X: ['GCT', 'AAG']
# 872. Kode C3 X: ['GCT', 'AGA']
# 873. Kode C3 X: ['GCT', 'GAA']
# 874. Kode C3 X: ['CTG', 'AGG']
# 875. Kode C3 X: ['CTG', 'GGA']
# 876. Kode C3 X: ['CTG', 'GAG']
# 877. Kode C3 X: ['TGC', 'AGG']
# 878. Kode C3 X: ['TGC', 'GGA']
# 879. Kode C3 X: ['TGC', 'GAG']
# 880. Kode C3 X: ['GCT', 'AGG']
# 881. Kode C3 X: ['GCT', 'GGA']
# 882. Kode C3 X: ['GCT', 'GAG']
# 883. Kode C3 X: ['CAT', 'CAA']
# 884. Kode C3 X: ['CAT', 'AAC']
# 885. Kode C3 X: ['CAT', 'ACA']
# 886. Kode C3 X: ['ATC', 'CAA']
# 887. Kode C3 X: ['ATC', 'AAC']
# 888. Kode C3 X: ['ATC', 'ACA']
# 889. Kode C3 X: ['TCA', 'CAA']
# 890. Kode C3 X: ['TCA', 'AAC']
# 891. Kode C3 X: ['TCA', 'ACA']
# 892. Kode C3 X: ['CAT', 'CAG']
# 893. Kode C3 X: ['CAT', 'AGC']
# 894. Kode C3 X: ['CAT', 'GCA']
# 895. Kode C3 X: ['ATC', 'CAG']
# 896. Kode C3 X: ['ATC', 'AGC']
# 897. Kode C3 X: ['ATC', 'GCA']
# 898. Kode C3 X: ['TCA', 'CAG']
# 899. Kode C3 X: ['TCA', 'AGC']
# 900. Kode C3 X: ['TCA', 'GCA']
# 901. Kode C3 X: ['CAT', 'CGT']
# 902. Kode C3 X: ['CAT', 'GTC']
# 903. Kode C3 X: ['CAT', 'TCG']
# 904. Kode C3 X: ['ATC', 'CGT']
# 905. Kode C3 X: ['ATC', 'GTC']
# 906. Kode C3 X: ['ATC', 'TCG']
# 907. Kode C3 X: ['TCA', 'CGT']
# 908. Kode C3 X: ['TCA', 'GTC']
# 909. Kode C3 X: ['TCA', 'TCG']
# 910. Kode C3 X: ['CAT', 'CGA']
# 911. Kode C3 X: ['CAT', 'GAC']
# 912. Kode C3 X: ['CAT', 'ACG']
# 913. Kode C3 X: ['ATC', 'CGA']
# 914. Kode C3 X: ['ATC', 'GAC']
# 915. Kode C3 X: ['ATC', 'ACG']
# 916. Kode C3 X: ['TCA', 'CGA']
# 917. Kode C3 X: ['TCA', 'GAC']
# 918. Kode C3 X: ['TCA', 'ACG']
# 919. Kode C3 X: ['CAT', 'CGG']
# 920. Kode C3 X: ['CAT', 'GGC']
# 921. Kode C3 X: ['CAT', 'GCG']
# 922. Kode C3 X: ['ATC', 'CGG']
# 923. Kode C3 X: ['ATC', 'GGC']
# 924. Kode C3 X: ['ATC', 'GCG']
# 925. Kode C3 X: ['TCA', 'CGG']
# 926. Kode C3 X: ['TCA', 'GGC']
# 927. Kode C3 X: ['TCA', 'GCG']
# 928. Kode C3 X: ['CAT', 'TTA']
# 929. Kode C3 X: ['CAT', 'TAT']
# 930. Kode C3 X: ['CAT', 'ATT']
# 931. Kode C3 X: ['ATC', 'TTA']
# 932. Kode C3 X: ['ATC', 'TAT']
# 933. Kode C3 X: ['ATC', 'ATT']
# 934. Kode C3 X: ['TCA', 'TTA']
# 935. Kode C3 X: ['TCA', 'TAT']
# 936. Kode C3 X: ['TCA', 'ATT']
# 937. Kode C3 X: ['CAT', 'TTG']
# 938. Kode C3 X: ['CAT', 'TGT']
# 939. Kode C3 X: ['CAT', 'GTT']
# 940. Kode C3 X: ['ATC', 'TTG']
# 941. Kode C3 X: ['ATC', 'TGT']
# 942. Kode C3 X: ['ATC', 'GTT']
# 943. Kode C3 X: ['TCA', 'TTG']
# 944. Kode C3 X: ['TCA', 'TGT']
# 945. Kode C3 X: ['TCA', 'GTT']
# 946. Kode C3 X: ['CAT', 'TAA']
# 947. Kode C3 X: ['CAT', 'AAT']
# 948. Kode C3 X: ['CAT', 'ATA']
# 949. Kode C3 X: ['ATC', 'TAA']
# 950. Kode C3 X: ['ATC', 'AAT']
# 951. Kode C3 X: ['ATC', 'ATA']
# 952. Kode C3 X: ['TCA', 'TAA']
# 953. Kode C3 X: ['TCA', 'AAT']
# 954. Kode C3 X: ['TCA', 'ATA']
# 955. Kode C3 X: ['CAT', 'TAG']
# 956. Kode C3 X: ['CAT', 'AGT']
# 957. Kode C3 X: ['CAT', 'GTA']
# 958. Kode C3 X: ['ATC', 'TAG']
# 959. Kode C3 X: ['ATC', 'AGT']
# 960. Kode C3 X: ['ATC', 'GTA']
# 961. Kode C3 X: ['TCA', 'TAG']
# 962. Kode C3 X: ['TCA', 'AGT']
# 963. Kode C3 X: ['TCA', 'GTA']
# 964. Kode C3 X: ['CAT', 'TGA']
# 965. Kode C3 X: ['CAT', 'GAT']
# 966. Kode C3 X: ['CAT', 'ATG']
# 967. Kode C3 X: ['ATC', 'TGA']
# 968. Kode C3 X: ['ATC', 'GAT']
# 969. Kode C3 X: ['ATC', 'ATG']
# 970. Kode C3 X: ['TCA', 'TGA']
# 971. Kode C3 X: ['TCA', 'GAT']
# 972. Kode C3 X: ['TCA', 'ATG']
# 973. Kode C3 X: ['CAT', 'TGG']
# 974. Kode C3 X: ['CAT', 'GGT']
# 975. Kode C3 X: ['CAT', 'GTG']
# 976. Kode C3 X: ['ATC', 'TGG']
# 977. Kode C3 X: ['ATC', 'GGT']
# 978. Kode C3 X: ['ATC', 'GTG']
# 979. Kode C3 X: ['TCA', 'TGG']
# 980. Kode C3 X: ['TCA', 'GGT']
# 981. Kode C3 X: ['TCA', 'GTG']
# 982. Kode C3 X: ['CAT', 'AAG']
# 983. Kode C3 X: ['CAT', 'AGA']
# 984. Kode C3 X: ['CAT', 'GAA']
# 985. Kode C3 X: ['ATC', 'AAG']
# 986. Kode C3 X: ['ATC', 'AGA']
# 987. Kode C3 X: ['ATC', 'GAA']
# 988. Kode C3 X: ['TCA', 'AAG']
# 989. Kode C3 X: ['TCA', 'AGA']
# 990. Kode C3 X: ['TCA', 'GAA']
# 991. Kode C3 X: ['CAT', 'AGG']
# 992. Kode C3 X: ['CAT', 'GGA']
# 993. Kode C3 X: ['CAT', 'GAG']
# 994. Kode C3 X: ['ATC', 'AGG']
# 995. Kode C3 X: ['ATC', 'GGA']
# 996. Kode C3 X: ['ATC', 'GAG']
# 997. Kode C3 X: ['TCA', 'AGG']
# 998. Kode C3 X: ['TCA', 'GGA']
# 999. Kode C3 X: ['TCA', 'GAG']
# 1000. Kode C3 X: ['CAA', 'CAG']
# 1001. Kode C3 X: ['CAA', 'AGC']
# 1002. Kode C3 X: ['CAA', 'GCA']
# 1003. Kode C3 X: ['AAC', 'CAG']
# 1004. Kode C3 X: ['AAC', 'AGC']
# 1005. Kode C3 X: ['AAC', 'GCA']
# 1006. Kode C3 X: ['ACA', 'CAG']
# 1007. Kode C3 X: ['ACA', 'AGC']
# 1008. Kode C3 X: ['ACA', 'GCA']
# 1009. Kode C3 X: ['CAA', 'CGT']
# 1010. Kode C3 X: ['CAA', 'GTC']
# 1011. Kode C3 X: ['CAA', 'TCG']
# 1012. Kode C3 X: ['AAC', 'CGT']
# 1013. Kode C3 X: ['AAC', 'GTC']
# 1014. Kode C3 X: ['AAC', 'TCG']
# 1015. Kode C3 X: ['ACA', 'CGT']
# 1016. Kode C3 X: ['ACA', 'GTC']
# 1017. Kode C3 X: ['ACA', 'TCG']
# 1018. Kode C3 X: ['CAA', 'CGA']
# 1019. Kode C3 X: ['CAA', 'GAC']
# 1020. Kode C3 X: ['CAA', 'ACG']
# 1021. Kode C3 X: ['AAC', 'CGA']
# 1022. Kode C3 X: ['AAC', 'GAC']
# 1023. Kode C3 X: ['AAC', 'ACG']
# 1024. Kode C3 X: ['ACA', 'CGA']
# 1025. Kode C3 X: ['ACA', 'GAC']
# 1026. Kode C3 X: ['ACA', 'ACG']
# 1027. Kode C3 X: ['CAA', 'CGG']
# 1028. Kode C3 X: ['CAA', 'GGC']
# 1029. Kode C3 X: ['CAA', 'GCG']
# 1030. Kode C3 X: ['AAC', 'CGG']
# 1031. Kode C3 X: ['AAC', 'GGC']
# 1032. Kode C3 X: ['AAC', 'GCG']
# 1033. Kode C3 X: ['ACA', 'CGG']
# 1034. Kode C3 X: ['ACA', 'GGC']
# 1035. Kode C3 X: ['ACA', 'GCG']
# 1036. Kode C3 X: ['CAA', 'TTA']
# 1037. Kode C3 X: ['CAA', 'TAT']
# 1038. Kode C3 X: ['CAA', 'ATT']
# 1039. Kode C3 X: ['AAC', 'TTA']
# 1040. Kode C3 X: ['AAC', 'TAT']
# 1041. Kode C3 X: ['AAC', 'ATT']
# 1042. Kode C3 X: ['ACA', 'TTA']
# 1043. Kode C3 X: ['ACA', 'TAT']
# 1044. Kode C3 X: ['ACA', 'ATT']
# 1045. Kode C3 X: ['CAA', 'TTG']
# 1046. Kode C3 X: ['CAA', 'TGT']
# 1047. Kode C3 X: ['CAA', 'GTT']
# 1048. Kode C3 X: ['AAC', 'TTG']
# 1049. Kode C3 X: ['AAC', 'TGT']
# 1050. Kode C3 X: ['AAC', 'GTT']
# 1051. Kode C3 X: ['ACA', 'TTG']
# 1052. Kode C3 X: ['ACA', 'TGT']
# 1053. Kode C3 X: ['ACA', 'GTT']
# 1054. Kode C3 X: ['CAA', 'TAA']
# 1055. Kode C3 X: ['CAA', 'AAT']
# 1056. Kode C3 X: ['CAA', 'ATA']
# 1057. Kode C3 X: ['AAC', 'TAA']
# 1058. Kode C3 X: ['AAC', 'AAT']
# 1059. Kode C3 X: ['AAC', 'ATA']
# 1060. Kode C3 X: ['ACA', 'TAA']
# 1061. Kode C3 X: ['ACA', 'AAT']
# 1062. Kode C3 X: ['ACA', 'ATA']
# 1063. Kode C3 X: ['CAA', 'TAG']
# 1064. Kode C3 X: ['CAA', 'AGT']
# 1065. Kode C3 X: ['CAA', 'GTA']
# 1066. Kode C3 X: ['AAC', 'TAG']
# 1067. Kode C3 X: ['AAC', 'AGT']
# 1068. Kode C3 X: ['AAC', 'GTA']
# 1069. Kode C3 X: ['ACA', 'TAG']
# 1070. Kode C3 X: ['ACA', 'AGT']
# 1071. Kode C3 X: ['ACA', 'GTA']
# 1072. Kode C3 X: ['CAA', 'TGA']
# 1073. Kode C3 X: ['CAA', 'GAT']
# 1074. Kode C3 X: ['CAA', 'ATG']
# 1075. Kode C3 X: ['AAC', 'TGA']
# 1076. Kode C3 X: ['AAC', 'GAT']
# 1077. Kode C3 X: ['AAC', 'ATG']
# 1078. Kode C3 X: ['ACA', 'TGA']
# 1079. Kode C3 X: ['ACA', 'GAT']
# 1080. Kode C3 X: ['ACA', 'ATG']
# 1081. Kode C3 X: ['CAA', 'TGG']
# 1082. Kode C3 X: ['CAA', 'GGT']
# 1083. Kode C3 X: ['CAA', 'GTG']
# 1084. Kode C3 X: ['AAC', 'TGG']
# 1085. Kode C3 X: ['AAC', 'GGT']
# 1086. Kode C3 X: ['AAC', 'GTG']
# 1087. Kode C3 X: ['ACA', 'TGG']
# 1088. Kode C3 X: ['ACA', 'GGT']
# 1089. Kode C3 X: ['ACA', 'GTG']
# 1090. Kode C3 X: ['CAA', 'AAG']
# 1091. Kode C3 X: ['CAA', 'AGA']
# 1092. Kode C3 X: ['CAA', 'GAA']
# 1093. Kode C3 X: ['AAC', 'AAG']
# 1094. Kode C3 X: ['AAC', 'AGA']
# 1095. Kode C3 X: ['AAC', 'GAA']
# 1096. Kode C3 X: ['ACA', 'AAG']
# 1097. Kode C3 X: ['ACA', 'AGA']
# 1098. Kode C3 X: ['ACA', 'GAA']
# 1099. Kode C3 X: ['CAA', 'AGG']
# 1100. Kode C3 X: ['CAA', 'GGA']
# 1101. Kode C3 X: ['CAA', 'GAG']
# 1102. Kode C3 X: ['AAC', 'AGG']
# 1103. Kode C3 X: ['AAC', 'GGA']
# 1104. Kode C3 X: ['AAC', 'GAG']
# 1105. Kode C3 X: ['ACA', 'AGG']
# 1106. Kode C3 X: ['ACA', 'GGA']
# 1107. Kode C3 X: ['ACA', 'GAG']
# 1108. Kode C3 X: ['CAG', 'CGT']
# 1109. Kode C3 X: ['CAG', 'GTC']
# 1110. Kode C3 X: ['CAG', 'TCG']
# 1111. Kode C3 X: ['AGC', 'CGT']
# 1112. Kode C3 X: ['AGC', 'GTC']
# 1113. Kode C3 X: ['AGC', 'TCG']
# 1114. Kode C3 X: ['GCA', 'CGT']
# 1115. Kode C3 X: ['GCA', 'GTC']
# 1116. Kode C3 X: ['GCA', 'TCG']
# 1117. Kode C3 X: ['CAG', 'CGA']
# 1118. Kode C3 X: ['CAG', 'GAC']
# 1119. Kode C3 X: ['CAG', 'ACG']
# 1120. Kode C3 X: ['AGC', 'CGA']
# 1121. Kode C3 X: ['AGC', 'GAC']
# 1122. Kode C3 X: ['AGC', 'ACG']
# 1123. Kode C3 X: ['GCA', 'CGA']
# 1124. Kode C3 X: ['GCA', 'GAC']
# 1125. Kode C3 X: ['GCA', 'ACG']
# 1126. Kode C3 X: ['CAG', 'CGG']
# 1127. Kode C3 X: ['CAG', 'GGC']
# 1128. Kode C3 X: ['CAG', 'GCG']
# 1129. Kode C3 X: ['AGC', 'CGG']
# 1130. Kode C3 X: ['AGC', 'GGC']
# 1131. Kode C3 X: ['AGC', 'GCG']
# 1132. Kode C3 X: ['GCA', 'CGG']
# 1133. Kode C3 X: ['GCA', 'GGC']
# 1134. Kode C3 X: ['GCA', 'GCG']
# 1135. Kode C3 X: ['CAG', 'TTA']
# 1136. Kode C3 X: ['CAG', 'TAT']
# 1137. Kode C3 X: ['CAG', 'ATT']
# 1138. Kode C3 X: ['AGC', 'TTA']
# 1139. Kode C3 X: ['AGC', 'TAT']
# 1140. Kode C3 X: ['AGC', 'ATT']
# 1141. Kode C3 X: ['GCA', 'TTA']
# 1142. Kode C3 X: ['GCA', 'TAT']
# 1143. Kode C3 X: ['GCA', 'ATT']
# 1144. Kode C3 X: ['CAG', 'TTG']
# 1145. Kode C3 X: ['CAG', 'TGT']
# 1146. Kode C3 X: ['CAG', 'GTT']
# 1147. Kode C3 X: ['AGC', 'TTG']
# 1148. Kode C3 X: ['AGC', 'TGT']
# 1149. Kode C3 X: ['AGC', 'GTT']
# 1150. Kode C3 X: ['GCA', 'TTG']
# 1151. Kode C3 X: ['GCA', 'TGT']
# 1152. Kode C3 X: ['GCA', 'GTT']
# 1153. Kode C3 X: ['CAG', 'TAA']
# 1154. Kode C3 X: ['CAG', 'AAT']
# 1155. Kode C3 X: ['CAG', 'ATA']
# 1156. Kode C3 X: ['AGC', 'TAA']
# 1157. Kode C3 X: ['AGC', 'AAT']
# 1158. Kode C3 X: ['AGC', 'ATA']
# 1159. Kode C3 X: ['GCA', 'TAA']
# 1160. Kode C3 X: ['GCA', 'AAT']
# 1161. Kode C3 X: ['GCA', 'ATA']
# 1162. Kode C3 X: ['CAG', 'TAG']
# 1163. Kode C3 X: ['CAG', 'AGT']
# 1164. Kode C3 X: ['CAG', 'GTA']
# 1165. Kode C3 X: ['AGC', 'TAG']
# 1166. Kode C3 X: ['AGC', 'AGT']
# 1167. Kode C3 X: ['AGC', 'GTA']
# 1168. Kode C3 X: ['GCA', 'TAG']
# 1169. Kode C3 X: ['GCA', 'AGT']
# 1170. Kode C3 X: ['GCA', 'GTA']
# 1171. Kode C3 X: ['CAG', 'TGA']
# 1172. Kode C3 X: ['CAG', 'GAT']
# 1173. Kode C3 X: ['CAG', 'ATG']
# 1174. Kode C3 X: ['AGC', 'TGA']
# 1175. Kode C3 X: ['AGC', 'GAT']
# 1176. Kode C3 X: ['AGC', 'ATG']
# 1177. Kode C3 X: ['GCA', 'TGA']
# 1178. Kode C3 X: ['GCA', 'GAT']
# 1179. Kode C3 X: ['GCA', 'ATG']
# 1180. Kode C3 X: ['CAG', 'TGG']
# 1181. Kode C3 X: ['CAG', 'GGT']
# 1182. Kode C3 X: ['CAG', 'GTG']
# 1183. Kode C3 X: ['AGC', 'TGG']
# 1184. Kode C3 X: ['AGC', 'GGT']
# 1185. Kode C3 X: ['AGC', 'GTG']
# 1186. Kode C3 X: ['GCA', 'TGG']
# 1187. Kode C3 X: ['GCA', 'GGT']
# 1188. Kode C3 X: ['GCA', 'GTG']
# 1189. Kode C3 X: ['CAG', 'AAG']
# 1190. Kode C3 X: ['CAG', 'AGA']
# 1191. Kode C3 X: ['CAG', 'GAA']
# 1192. Kode C3 X: ['AGC', 'AAG']
# 1193. Kode C3 X: ['AGC', 'AGA']
# 1194. Kode C3 X: ['AGC', 'GAA']
# 1195. Kode C3 X: ['GCA', 'AAG']
# 1196. Kode C3 X: ['GCA', 'AGA']
# 1197. Kode C3 X: ['GCA', 'GAA']
# 1198. Kode C3 X: ['CAG', 'AGG']
# 1199. Kode C3 X: ['CAG', 'GGA']
# 1200. Kode C3 X: ['CAG', 'GAG']
# 1201. Kode C3 X: ['AGC', 'AGG']
# 1202. Kode C3 X: ['AGC', 'GGA']
# 1203. Kode C3 X: ['AGC', 'GAG']
# 1204. Kode C3 X: ['GCA', 'AGG']
# 1205. Kode C3 X: ['GCA', 'GGA']
# 1206. Kode C3 X: ['GCA', 'GAG']
# 1207. Kode C3 X: ['CGT', 'CGA']
# 1208. Kode C3 X: ['CGT', 'GAC']
# 1209. Kode C3 X: ['CGT', 'ACG']
# 1210. Kode C3 X: ['GTC', 'CGA']
# 1211. Kode C3 X: ['GTC', 'GAC']
# 1212. Kode C3 X: ['GTC', 'ACG']
# 1213. Kode C3 X: ['TCG', 'CGA']
# 1214. Kode C3 X: ['TCG', 'GAC']
# 1215. Kode C3 X: ['TCG', 'ACG']
# 1216. Kode C3 X: ['CGT', 'CGG']
# 1217. Kode C3 X: ['CGT', 'GGC']
# 1218. Kode C3 X: ['CGT', 'GCG']
# 1219. Kode C3 X: ['GTC', 'CGG']
# 1220. Kode C3 X: ['GTC', 'GGC']
# 1221. Kode C3 X: ['GTC', 'GCG']
# 1222. Kode C3 X: ['TCG', 'CGG']
# 1223. Kode C3 X: ['TCG', 'GGC']
# 1224. Kode C3 X: ['TCG', 'GCG']
# 1225. Kode C3 X: ['CGT', 'TTA']
# 1226. Kode C3 X: ['CGT', 'TAT']
# 1227. Kode C3 X: ['CGT', 'ATT']
# 1228. Kode C3 X: ['GTC', 'TTA']
# 1229. Kode C3 X: ['GTC', 'TAT']
# 1230. Kode C3 X: ['GTC', 'ATT']
# 1231. Kode C3 X: ['TCG', 'TTA']
# 1232. Kode C3 X: ['TCG', 'TAT']
# 1233. Kode C3 X: ['TCG', 'ATT']
# 1234. Kode C3 X: ['CGT', 'TTG']
# 1235. Kode C3 X: ['CGT', 'TGT']
# 1236. Kode C3 X: ['CGT', 'GTT']
# 1237. Kode C3 X: ['GTC', 'TTG']
# 1238. Kode C3 X: ['GTC', 'TGT']
# 1239. Kode C3 X: ['GTC', 'GTT']
# 1240. Kode C3 X: ['TCG', 'TTG']
# 1241. Kode C3 X: ['TCG', 'TGT']
# 1242. Kode C3 X: ['TCG', 'GTT']
# 1243. Kode C3 X: ['CGT', 'TAA']
# 1244. Kode C3 X: ['CGT', 'AAT']
# 1245. Kode C3 X: ['CGT', 'ATA']
# 1246. Kode C3 X: ['GTC', 'TAA']
# 1247. Kode C3 X: ['GTC', 'AAT']
# 1248. Kode C3 X: ['GTC', 'ATA']
# 1249. Kode C3 X: ['TCG', 'TAA']
# 1250. Kode C3 X: ['TCG', 'AAT']
# 1251. Kode C3 X: ['TCG', 'ATA']
# 1252. Kode C3 X: ['CGT', 'TAG']
# 1253. Kode C3 X: ['CGT', 'AGT']
# 1254. Kode C3 X: ['CGT', 'GTA']
# 1255. Kode C3 X: ['GTC', 'TAG']
# 1256. Kode C3 X: ['GTC', 'AGT']
# 1257. Kode C3 X: ['GTC', 'GTA']
# 1258. Kode C3 X: ['TCG', 'TAG']
# 1259. Kode C3 X: ['TCG', 'AGT']
# 1260. Kode C3 X: ['TCG', 'GTA']
# 1261. Kode C3 X: ['CGT', 'TGA']
# 1262. Kode C3 X: ['CGT', 'GAT']
# 1263. Kode C3 X: ['CGT', 'ATG']
# 1264. Kode C3 X: ['GTC', 'TGA']
# 1265. Kode C3 X: ['GTC', 'GAT']
# 1266. Kode C3 X: ['GTC', 'ATG']
# 1267. Kode C3 X: ['TCG', 'TGA']
# 1268. Kode C3 X: ['TCG', 'GAT']
# 1269. Kode C3 X: ['TCG', 'ATG']
# 1270. Kode C3 X: ['CGT', 'TGG']
# 1271. Kode C3 X: ['CGT', 'GGT']
# 1272. Kode C3 X: ['CGT', 'GTG']
# 1273. Kode C3 X: ['GTC', 'TGG']
# 1274. Kode C3 X: ['GTC', 'GGT']
# 1275. Kode C3 X: ['GTC', 'GTG']
# 1276. Kode C3 X: ['TCG', 'TGG']
# 1277. Kode C3 X: ['TCG', 'GGT']
# 1278. Kode C3 X: ['TCG', 'GTG']
# 1279. Kode C3 X: ['CGT', 'AAG']
# 1280. Kode C3 X: ['CGT', 'AGA']
# 1281. Kode C3 X: ['CGT', 'GAA']
# 1282. Kode C3 X: ['GTC', 'AAG']
# 1283. Kode C3 X: ['GTC', 'AGA']
# 1284. Kode C3 X: ['GTC', 'GAA']
# 1285. Kode C3 X: ['TCG', 'AAG']
# 1286. Kode C3 X: ['TCG', 'AGA']
# 1287. Kode C3 X: ['TCG', 'GAA']
# 1288. Kode C3 X: ['CGT', 'AGG']
# 1289. Kode C3 X: ['CGT', 'GGA']
# 1290. Kode C3 X: ['CGT', 'GAG']
# 1291. Kode C3 X: ['GTC', 'AGG']
# 1292. Kode C3 X: ['GTC', 'GGA']
# 1293. Kode C3 X: ['GTC', 'GAG']
# 1294. Kode C3 X: ['TCG', 'AGG']
# 1295. Kode C3 X: ['TCG', 'GGA']
# 1296. Kode C3 X: ['TCG', 'GAG']
# 1297. Kode C3 X: ['CGA', 'CGG']
# 1298. Kode C3 X: ['CGA', 'GGC']
# 1299. Kode C3 X: ['CGA', 'GCG']
# 1300. Kode C3 X: ['GAC', 'CGG']
# 1301. Kode C3 X: ['GAC', 'GGC']
# 1302. Kode C3 X: ['GAC', 'GCG']
# 1303. Kode C3 X: ['ACG', 'CGG']
# 1304. Kode C3 X: ['ACG', 'GGC']
# 1305. Kode C3 X: ['ACG', 'GCG']
# 1306. Kode C3 X: ['CGA', 'TTA']
# 1307. Kode C3 X: ['CGA', 'TAT']
# 1308. Kode C3 X: ['CGA', 'ATT']
# 1309. Kode C3 X: ['GAC', 'TTA']
# 1310. Kode C3 X: ['GAC', 'TAT']
# 1311. Kode C3 X: ['GAC', 'ATT']
# 1312. Kode C3 X: ['ACG', 'TTA']
# 1313. Kode C3 X: ['ACG', 'TAT']
# 1314. Kode C3 X: ['ACG', 'ATT']
# 1315. Kode C3 X: ['CGA', 'TTG']
# 1316. Kode C3 X: ['CGA', 'TGT']
# 1317. Kode C3 X: ['CGA', 'GTT']
# 1318. Kode C3 X: ['GAC', 'TTG']
# 1319. Kode C3 X: ['GAC', 'TGT']
# 1320. Kode C3 X: ['GAC', 'GTT']
# 1321. Kode C3 X: ['ACG', 'TTG']
# 1322. Kode C3 X: ['ACG', 'TGT']
# 1323. Kode C3 X: ['ACG', 'GTT']
# 1324. Kode C3 X: ['CGA', 'TAA']
# 1325. Kode C3 X: ['CGA', 'AAT']
# 1326. Kode C3 X: ['CGA', 'ATA']
# 1327. Kode C3 X: ['GAC', 'TAA']
# 1328. Kode C3 X: ['GAC', 'AAT']
# 1329. Kode C3 X: ['GAC', 'ATA']
# 1330. Kode C3 X: ['ACG', 'TAA']
# 1331. Kode C3 X: ['ACG', 'AAT']
# 1332. Kode C3 X: ['ACG', 'ATA']
# 1333. Kode C3 X: ['CGA', 'TAG']
# 1334. Kode C3 X: ['CGA', 'AGT']
# 1335. Kode C3 X: ['CGA', 'GTA']
# 1336. Kode C3 X: ['GAC', 'TAG']
# 1337. Kode C3 X: ['GAC', 'AGT']
# 1338. Kode C3 X: ['GAC', 'GTA']
# 1339. Kode C3 X: ['ACG', 'TAG']
# 1340. Kode C3 X: ['ACG', 'AGT']
# 1341. Kode C3 X: ['ACG', 'GTA']
# 1342. Kode C3 X: ['CGA', 'TGA']
# 1343. Kode C3 X: ['CGA', 'GAT']
# 1344. Kode C3 X: ['CGA', 'ATG']
# 1345. Kode C3 X: ['GAC', 'TGA']
# 1346. Kode C3 X: ['GAC', 'GAT']
# 1347. Kode C3 X: ['GAC', 'ATG']
# 1348. Kode C3 X: ['ACG', 'TGA']
# 1349. Kode C3 X: ['ACG', 'GAT']
# 1350. Kode C3 X: ['ACG', 'ATG']
# 1351. Kode C3 X: ['CGA', 'TGG']
# 1352. Kode C3 X: ['CGA', 'GGT']
# 1353. Kode C3 X: ['CGA', 'GTG']
# 1354. Kode C3 X: ['GAC', 'TGG']
# 1355. Kode C3 X: ['GAC', 'GGT']
# 1356. Kode C3 X: ['GAC', 'GTG']
# 1357. Kode C3 X: ['ACG', 'TGG']
# 1358. Kode C3 X: ['ACG', 'GGT']
# 1359. Kode C3 X: ['ACG', 'GTG']
# 1360. Kode C3 X: ['CGA', 'AAG']
# 1361. Kode C3 X: ['CGA', 'AGA']
# 1362. Kode C3 X: ['CGA', 'GAA']
# 1363. Kode C3 X: ['GAC', 'AAG']
# 1364. Kode C3 X: ['GAC', 'AGA']
# 1365. Kode C3 X: ['GAC', 'GAA']
# 1366. Kode C3 X: ['ACG', 'AAG']
# 1367. Kode C3 X: ['ACG', 'AGA']
# 1368. Kode C3 X: ['ACG', 'GAA']
# 1369. Kode C3 X: ['CGA', 'AGG']
# 1370. Kode C3 X: ['CGA', 'GGA']
# 1371. Kode C3 X: ['CGA', 'GAG']
# 1372. Kode C3 X: ['GAC', 'AGG']
# 1373. Kode C3 X: ['GAC', 'GGA']
# 1374. Kode C3 X: ['GAC', 'GAG']
# 1375. Kode C3 X: ['ACG', 'AGG']
# 1376. Kode C3 X: ['ACG', 'GGA']
# 1377. Kode C3 X: ['ACG', 'GAG']
# 1378. Kode C3 X: ['CGG', 'TTA']
# 1379. Kode C3 X: ['CGG', 'TAT']
# 1380. Kode C3 X: ['CGG', 'ATT']
# 1381. Kode C3 X: ['GGC', 'TTA']
# 1382. Kode C3 X: ['GGC', 'TAT']
# 1383. Kode C3 X: ['GGC', 'ATT']
# 1384. Kode C3 X: ['GCG', 'TTA']
# 1385. Kode C3 X: ['GCG', 'TAT']
# 1386. Kode C3 X: ['GCG', 'ATT']
# 1387. Kode C3 X: ['CGG', 'TTG']
# 1388. Kode C3 X: ['CGG', 'TGT']
# 1389. Kode C3 X: ['CGG', 'GTT']
# 1390. Kode C3 X: ['GGC', 'TTG']
# 1391. Kode C3 X: ['GGC', 'TGT']
# 1392. Kode C3 X: ['GGC', 'GTT']
# 1393. Kode C3 X: ['GCG', 'TTG']
# 1394. Kode C3 X: ['GCG', 'TGT']
# 1395. Kode C3 X: ['GCG', 'GTT']
# 1396. Kode C3 X: ['CGG', 'TAA']
# 1397. Kode C3 X: ['CGG', 'AAT']
# 1398. Kode C3 X: ['CGG', 'ATA']
# 1399. Kode C3 X: ['GGC', 'TAA']
# 1400. Kode C3 X: ['GGC', 'AAT']
# 1401. Kode C3 X: ['GGC', 'ATA']
# 1402. Kode C3 X: ['GCG', 'TAA']
# 1403. Kode C3 X: ['GCG', 'AAT']
# 1404. Kode C3 X: ['GCG', 'ATA']
# 1405. Kode C3 X: ['CGG', 'TAG']
# 1406. Kode C3 X: ['CGG', 'AGT']
# 1407. Kode C3 X: ['CGG', 'GTA']
# 1408. Kode C3 X: ['GGC', 'TAG']
# 1409. Kode C3 X: ['GGC', 'AGT']
# 1410. Kode C3 X: ['GGC', 'GTA']
# 1411. Kode C3 X: ['GCG', 'TAG']
# 1412. Kode C3 X: ['GCG', 'AGT']
# 1413. Kode C3 X: ['GCG', 'GTA']
# 1414. Kode C3 X: ['CGG', 'TGA']
# 1415. Kode C3 X: ['CGG', 'GAT']
# 1416. Kode C3 X: ['CGG', 'ATG']
# 1417. Kode C3 X: ['GGC', 'TGA']
# 1418. Kode C3 X: ['GGC', 'GAT']
# 1419. Kode C3 X: ['GGC', 'ATG']
# 1420. Kode C3 X: ['GCG', 'TGA']
# 1421. Kode C3 X: ['GCG', 'GAT']
# 1422. Kode C3 X: ['GCG', 'ATG']
# 1423. Kode C3 X: ['CGG', 'TGG']
# 1424. Kode C3 X: ['CGG', 'GGT']
# 1425. Kode C3 X: ['CGG', 'GTG']
# 1426. Kode C3 X: ['GGC', 'TGG']
# 1427. Kode C3 X: ['GGC', 'GGT']
# 1428. Kode C3 X: ['GGC', 'GTG']
# 1429. Kode C3 X: ['GCG', 'TGG']
# 1430. Kode C3 X: ['GCG', 'GGT']
# 1431. Kode C3 X: ['GCG', 'GTG']
# 1432. Kode C3 X: ['CGG', 'AAG']
# 1433. Kode C3 X: ['CGG', 'AGA']
# 1434. Kode C3 X: ['CGG', 'GAA']
# 1435. Kode C3 X: ['GGC', 'AAG']
# 1436. Kode C3 X: ['GGC', 'AGA']
# 1437. Kode C3 X: ['GGC', 'GAA']
# 1438. Kode C3 X: ['GCG', 'AAG']
# 1439. Kode C3 X: ['GCG', 'AGA']
# 1440. Kode C3 X: ['GCG', 'GAA']
# 1441. Kode C3 X: ['CGG', 'AGG']
# 1442. Kode C3 X: ['CGG', 'GGA']
# 1443. Kode C3 X: ['CGG', 'GAG']
# 1444. Kode C3 X: ['GGC', 'AGG']
# 1445. Kode C3 X: ['GGC', 'GGA']
# 1446. Kode C3 X: ['GGC', 'GAG']
# 1447. Kode C3 X: ['GCG', 'AGG']
# 1448. Kode C3 X: ['GCG', 'GGA']
# 1449. Kode C3 X: ['GCG', 'GAG']
# 1450. Kode C3 X: ['TTA', 'TTG']
# 1451. Kode C3 X: ['TTA', 'TGT']
# 1452. Kode C3 X: ['TTA', 'GTT']
# 1453. Kode C3 X: ['TAT', 'TTG']
# 1454. Kode C3 X: ['TAT', 'TGT']
# 1455. Kode C3 X: ['TAT', 'GTT']
# 1456. Kode C3 X: ['ATT', 'TTG']
# 1457. Kode C3 X: ['ATT', 'TGT']
# 1458. Kode C3 X: ['ATT', 'GTT']
# 1459. Kode C3 X: ['TTA', 'TAA']
# 1460. Kode C3 X: ['TTA', 'ATA']
# 1461. Kode C3 X: ['TAT', 'TAA']
# 1462. Kode C3 X: ['TAT', 'AAT']
# 1463. Kode C3 X: ['ATT', 'AAT']
# 1464. Kode C3 X: ['ATT', 'ATA']
# 1465. Kode C3 X: ['TTA', 'TAG']
# 1466. Kode C3 X: ['TTA', 'AGT']
# 1467. Kode C3 X: ['TTA', 'GTA']
# 1468. Kode C3 X: ['TAT', 'TAG']
# 1469. Kode C3 X: ['TAT', 'AGT']
# 1470. Kode C3 X: ['TAT', 'GTA']
# 1471. Kode C3 X: ['ATT', 'TAG']
# 1472. Kode C3 X: ['ATT', 'AGT']
# 1473. Kode C3 X: ['ATT', 'GTA']
# 1474. Kode C3 X: ['TTA', 'TGA']
# 1475. Kode C3 X: ['TTA', 'GAT']
# 1476. Kode C3 X: ['TTA', 'ATG']
# 1477. Kode C3 X: ['TAT', 'TGA']
# 1478. Kode C3 X: ['TAT', 'GAT']
# 1479. Kode C3 X: ['TAT', 'ATG']
# 1480. Kode C3 X: ['ATT', 'TGA']
# 1481. Kode C3 X: ['ATT', 'GAT']
# 1482. Kode C3 X: ['ATT', 'ATG']
# 1483. Kode C3 X: ['TTA', 'TGG']
# 1484. Kode C3 X: ['TTA', 'GGT']
# 1485. Kode C3 X: ['TTA', 'GTG']
# 1486. Kode C3 X: ['TAT', 'TGG']
# 1487. Kode C3 X: ['TAT', 'GGT']
# 1488. Kode C3 X: ['TAT', 'GTG']
# 1489. Kode C3 X: ['ATT', 'TGG']
# 1490. Kode C3 X: ['ATT', 'GGT']
# 1491. Kode C3 X: ['ATT', 'GTG']
# 1492. Kode C3 X: ['TTA', 'AAG']
# 1493. Kode C3 X: ['TTA', 'AGA']
# 1494. Kode C3 X: ['TTA', 'GAA']
# 1495. Kode C3 X: ['TAT', 'AAG']
# 1496. Kode C3 X: ['TAT', 'AGA']
# 1497. Kode C3 X: ['TAT', 'GAA']
# 1498. Kode C3 X: ['ATT', 'AAG']
# 1499. Kode C3 X: ['ATT', 'AGA']
# 1500. Kode C3 X: ['ATT', 'GAA']
# 1501. Kode C3 X: ['TTA', 'AGG']
# 1502. Kode C3 X: ['TTA', 'GGA']
# 1503. Kode C3 X: ['TTA', 'GAG']
# 1504. Kode C3 X: ['TAT', 'AGG']
# 1505. Kode C3 X: ['TAT', 'GGA']
# 1506. Kode C3 X: ['TAT', 'GAG']
# 1507. Kode C3 X: ['ATT', 'AGG']
# 1508. Kode C3 X: ['ATT', 'GGA']
# 1509. Kode C3 X: ['ATT', 'GAG']
# 1510. Kode C3 X: ['TTG', 'TAA']
# 1511. Kode C3 X: ['TTG', 'AAT']
# 1512. Kode C3 X: ['TTG', 'ATA']
# 1513. Kode C3 X: ['TGT', 'TAA']
# 1514. Kode C3 X: ['TGT', 'AAT']
# 1515. Kode C3 X: ['TGT', 'ATA']
# 1516. Kode C3 X: ['GTT', 'TAA']
# 1517. Kode C3 X: ['GTT', 'AAT']
# 1518. Kode C3 X: ['GTT', 'ATA']
# 1519. Kode C3 X: ['TTG', 'TAG']
# 1520. Kode C3 X: ['TTG', 'AGT']
# 1521. Kode C3 X: ['TTG', 'GTA']
# 1522. Kode C3 X: ['TGT', 'TAG']
# 1523. Kode C3 X: ['TGT', 'AGT']
# 1524. Kode C3 X: ['TGT', 'GTA']
# 1525. Kode C3 X: ['GTT', 'TAG']
# 1526. Kode C3 X: ['GTT', 'AGT']
# 1527. Kode C3 X: ['GTT', 'GTA']
# 1528. Kode C3 X: ['TTG', 'TGA']
# 1529. Kode C3 X: ['TTG', 'GAT']
# 1530. Kode C3 X: ['TTG', 'ATG']
# 1531. Kode C3 X: ['TGT', 'TGA']
# 1532. Kode C3 X: ['TGT', 'GAT']
# 1533. Kode C3 X: ['TGT', 'ATG']
# 1534. Kode C3 X: ['GTT', 'TGA']
# 1535. Kode C3 X: ['GTT', 'GAT']
# 1536. Kode C3 X: ['GTT', 'ATG']
# 1537. Kode C3 X: ['TTG', 'TGG']
# 1538. Kode C3 X: ['TTG', 'GTG']
# 1539. Kode C3 X: ['TGT', 'TGG']
# 1540. Kode C3 X: ['TGT', 'GGT']
# 1541. Kode C3 X: ['GTT', 'GGT']
# 1542. Kode C3 X: ['GTT', 'GTG']
# 1543. Kode C3 X: ['TTG', 'AAG']
# 1544. Kode C3 X: ['TTG', 'AGA']
# 1545. Kode C3 X: ['TTG', 'GAA']
# 1546. Kode C3 X: ['TGT', 'AAG']
# 1547. Kode C3 X: ['TGT', 'AGA']
# 1548. Kode C3 X: ['TGT', 'GAA']
# 1549. Kode C3 X: ['GTT', 'AAG']
# 1550. Kode C3 X: ['GTT', 'AGA']
# 1551. Kode C3 X: ['GTT', 'GAA']
# 1552. Kode C3 X: ['TTG', 'AGG']
# 1553. Kode C3 X: ['TTG', 'GGA']
# 1554. Kode C3 X: ['TTG', 'GAG']
# 1555. Kode C3 X: ['TGT', 'AGG']
# 1556. Kode C3 X: ['TGT', 'GGA']
# 1557. Kode C3 X: ['TGT', 'GAG']
# 1558. Kode C3 X: ['GTT', 'AGG']
# 1559. Kode C3 X: ['GTT', 'GGA']
# 1560. Kode C3 X: ['GTT', 'GAG']
# 1561. Kode C3 X: ['TAA', 'TAG']
# 1562. Kode C3 X: ['TAA', 'AGT']
# 1563. Kode C3 X: ['TAA', 'GTA']
# 1564. Kode C3 X: ['AAT', 'TAG']
# 1565. Kode C3 X: ['AAT', 'AGT']
# 1566. Kode C3 X: ['AAT', 'GTA']
# 1567. Kode C3 X: ['ATA', 'TAG']
# 1568. Kode C3 X: ['ATA', 'AGT']
# 1569. Kode C3 X: ['ATA', 'GTA']
# 1570. Kode C3 X: ['TAA', 'TGA']
# 1571. Kode C3 X: ['TAA', 'GAT']
# 1572. Kode C3 X: ['TAA', 'ATG']
# 1573. Kode C3 X: ['AAT', 'TGA']
# 1574. Kode C3 X: ['AAT', 'GAT']
# 1575. Kode C3 X: ['AAT', 'ATG']
# 1576. Kode C3 X: ['ATA', 'TGA']
# 1577. Kode C3 X: ['ATA', 'GAT']
# 1578. Kode C3 X: ['ATA', 'ATG']
# 1579. Kode C3 X: ['TAA', 'TGG']
# 1580. Kode C3 X: ['TAA', 'GGT']
# 1581. Kode C3 X: ['TAA', 'GTG']
# 1582. Kode C3 X: ['AAT', 'TGG']
# 1583. Kode C3 X: ['AAT', 'GGT']
# 1584. Kode C3 X: ['AAT', 'GTG']
# 1585. Kode C3 X: ['ATA', 'TGG']
# 1586. Kode C3 X: ['ATA', 'GGT']
# 1587. Kode C3 X: ['ATA', 'GTG']
# 1588. Kode C3 X: ['TAA', 'AAG']
# 1589. Kode C3 X: ['TAA', 'AGA']
# 1590. Kode C3 X: ['TAA', 'GAA']
# 1591. Kode C3 X: ['AAT', 'AAG']
# 1592. Kode C3 X: ['AAT', 'AGA']
# 1593. Kode C3 X: ['AAT', 'GAA']
# 1594. Kode C3 X: ['ATA', 'AAG']
# 1595. Kode C3 X: ['ATA', 'AGA']
# 1596. Kode C3 X: ['ATA', 'GAA']
# 1597. Kode C3 X: ['TAA', 'AGG']
# 1598. Kode C3 X: ['TAA', 'GGA']
# 1599. Kode C3 X: ['TAA', 'GAG']
# 1600. Kode C3 X: ['AAT', 'AGG']
# 1601. Kode C3 X: ['AAT', 'GGA']
# 1602. Kode C3 X: ['AAT', 'GAG']
# 1603. Kode C3 X: ['ATA', 'AGG']
# 1604. Kode C3 X: ['ATA', 'GGA']
# 1605. Kode C3 X: ['ATA', 'GAG']
# 1606. Kode C3 X: ['TAG', 'TGA']
# 1607. Kode C3 X: ['TAG', 'GAT']
# 1608. Kode C3 X: ['TAG', 'ATG']
# 1609. Kode C3 X: ['AGT', 'TGA']
# 1610. Kode C3 X: ['AGT', 'GAT']
# 1611. Kode C3 X: ['AGT', 'ATG']
# 1612. Kode C3 X: ['GTA', 'TGA']
# 1613. Kode C3 X: ['GTA', 'GAT']
# 1614. Kode C3 X: ['GTA', 'ATG']
# 1615. Kode C3 X: ['TAG', 'TGG']
# 1616. Kode C3 X: ['TAG', 'GGT']
# 1617. Kode C3 X: ['TAG', 'GTG']
# 1618. Kode C3 X: ['AGT', 'TGG']
# 1619. Kode C3 X: ['AGT', 'GGT']
# 1620. Kode C3 X: ['AGT', 'GTG']
# 1621. Kode C3 X: ['GTA', 'TGG']
# 1622. Kode C3 X: ['GTA', 'GGT']
# 1623. Kode C3 X: ['GTA', 'GTG']
# 1624. Kode C3 X: ['TAG', 'AAG']
# 1625. Kode C3 X: ['TAG', 'AGA']
# 1626. Kode C3 X: ['TAG', 'GAA']
# 1627. Kode C3 X: ['AGT', 'AAG']
# 1628. Kode C3 X: ['AGT', 'AGA']
# 1629. Kode C3 X: ['AGT', 'GAA']
# 1630. Kode C3 X: ['GTA', 'AAG']
# 1631. Kode C3 X: ['GTA', 'AGA']
# 1632. Kode C3 X: ['GTA', 'GAA']
# 1633. Kode C3 X: ['TAG', 'AGG']
# 1634. Kode C3 X: ['TAG', 'GGA']
# 1635. Kode C3 X: ['TAG', 'GAG']
# 1636. Kode C3 X: ['AGT', 'AGG']
# 1637. Kode C3 X: ['AGT', 'GGA']
# 1638. Kode C3 X: ['AGT', 'GAG']
# 1639. Kode C3 X: ['GTA', 'AGG']
# 1640. Kode C3 X: ['GTA', 'GGA']
# 1641. Kode C3 X: ['GTA', 'GAG']
# 1642. Kode C3 X: ['TGA', 'TGG']
# 1643. Kode C3 X: ['TGA', 'GGT']
# 1644. Kode C3 X: ['TGA', 'GTG']
# 1645. Kode C3 X: ['GAT', 'TGG']
# 1646. Kode C3 X: ['GAT', 'GGT']
# 1647. Kode C3 X: ['GAT', 'GTG']
# 1648. Kode C3 X: ['ATG', 'TGG']
# 1649. Kode C3 X: ['ATG', 'GGT']
# 1650. Kode C3 X: ['ATG', 'GTG']
# 1651. Kode C3 X: ['TGA', 'AAG']
# 1652. Kode C3 X: ['TGA', 'AGA']
# 1653. Kode C3 X: ['TGA', 'GAA']
# 1654. Kode C3 X: ['GAT', 'AAG']
# 1655. Kode C3 X: ['GAT', 'AGA']
# 1656. Kode C3 X: ['GAT', 'GAA']
# 1657. Kode C3 X: ['ATG', 'AAG']
# 1658. Kode C3 X: ['ATG', 'AGA']
# 1659. Kode C3 X: ['ATG', 'GAA']
# 1660. Kode C3 X: ['TGA', 'AGG']
# 1661. Kode C3 X: ['TGA', 'GGA']
# 1662. Kode C3 X: ['TGA', 'GAG']
# 1663. Kode C3 X: ['GAT', 'AGG']
# 1664. Kode C3 X: ['GAT', 'GGA']
# 1665. Kode C3 X: ['GAT', 'GAG']
# 1666. Kode C3 X: ['ATG', 'AGG']
# 1667. Kode C3 X: ['ATG', 'GGA']
# 1668. Kode C3 X: ['ATG', 'GAG']
# 1669. Kode C3 X: ['TGG', 'AAG']
# 1670. Kode C3 X: ['TGG', 'AGA']
# 1671. Kode C3 X: ['TGG', 'GAA']
# 1672. Kode C3 X: ['GGT', 'AAG']
# 1673. Kode C3 X: ['GGT', 'AGA']
# 1674. Kode C3 X: ['GGT', 'GAA']
# 1675. Kode C3 X: ['GTG', 'AAG']
# 1676. Kode C3 X: ['GTG', 'AGA']
# 1677. Kode C3 X: ['GTG', 'GAA']
# 1678. Kode C3 X: ['TGG', 'AGG']
# 1679. Kode C3 X: ['TGG', 'GGA']
# 1680. Kode C3 X: ['TGG', 'GAG']
# 1681. Kode C3 X: ['GGT', 'AGG']
# 1682. Kode C3 X: ['GGT', 'GGA']
# 1683. Kode C3 X: ['GGT', 'GAG']
# 1684. Kode C3 X: ['GTG', 'AGG']
# 1685. Kode C3 X: ['GTG', 'GGA']
# 1686. Kode C3 X: ['GTG', 'GAG']
# 1687. Kode C3 X: ['AAG', 'AGG']
# 1688. Kode C3 X: ['AAG', 'GAG']
# 1689. Kode C3 X: ['AGA', 'AGG']
# 1690. Kode C3 X: ['AGA', 'GGA']
# 1691. Kode C3 X: ['GAA', 'GGA']
# 1692. Kode C3 X: ['GAA', 'GAG']

# %% [markdown]
# # Proposisi 4.6

# %% [markdown]
# ## Untuk |X| = 2

# %%
# Mencari himpunan bersifat self-complementary
def Self_Complementary(data):

    # Mencari antikodon dari kodon yang dicari
    def Kodon_Complementary(kodons):
        # Compelmenter dari basa nitrogen
        Complementer = 'GATC'
        # Urutan basa nitrogen
        Basa_Nitrogren = 'CTAG'

        # Membuat dictionary untuk menyimpan complementer
        Kodon_Complement = dict(zip(Basa_Nitrogren, Complementer))
        # Melakukan penukaran Basa Nitrogen
        Penukaran_basa_nitrogen = ''.join(Kodon_Complement.get(kodon, kodon) for kodon in kodons)

        return Penukaran_basa_nitrogen

    def permutasi_kodons(kodons):
        # Permutasi a_1 = (1 3)
        keys_1 = [3, 2, 1]

        keys_11 = [key - 1 for key in keys_1]

        # Periksa apakah panjang keys sama dengan panjang kodons
        if len(keys_11) != len(kodons):
            raise ValueError('Panjang keys tidak sama dengan panjang kodons')

        # Mengembalikan permutasi terhadap kodons_i
        kodons_1 = [kodons[key] for key in keys_11]
        return ''.join(kodons_1) if isinstance(kodons, str) else kodons_1

    # Membuat himpunan X yang bersifat self-complementary
    X = []
    # Nomor urutan
    i = 1

    # Melakukan perulangan untuk mencari himpunan self-complementary
    for j in range(len(data)):
        # Menentukan kodon x_i dari Kelas Ekuivalen
        for kodon in data[j]:
            # mencari antikodon terhadap kodon
            hasil = Kodon_Complementary(kodon)
            hasil = permutasi_kodons(hasil)
            x1 = [kodon, hasil]
            x2 = [hasil, kodon]

            # Memeriksa apakah x1 dan x2 tidak ada dalam X dan x1 tidak ada dalam data
            if x1 not in X and x2 not in X and x1 in data:
                X.append([kodon, hasil])
                print(f'Himpunan Self-Compelmentary X{i}: {kodon, hasil}')
                i += 1
            else:
                continue


    return X

# Memanggil fungsi Self_Complementary
self_complementary = Self_Complementary(kode_c3)
# Out:
# Himpunan Self-Compelmentary X1: ('CCT', 'AGG')
# Himpunan Self-Compelmentary X2: ('CCA', 'TGG')
# Himpunan Self-Compelmentary X3: ('CAC', 'GTG')
# Himpunan Self-Compelmentary X4: ('ACC', 'GGT')
# Himpunan Self-Compelmentary X5: ('CTC', 'GAG')
# Himpunan Self-Compelmentary X6: ('TCC', 'GGA')
# Himpunan Self-Compelmentary X7: ('CCG', 'CGG')
# Himpunan Self-Compelmentary X8: ('GCC', 'GGC')
# Himpunan Self-Compelmentary X9: ('CTT', 'AAG')
# Himpunan Self-Compelmentary X10: ('TCT', 'AGA')
# Himpunan Self-Compelmentary X11: ('TTC', 'GAA')
# Himpunan Self-Compelmentary X12: ('CTA', 'TAG')
# Himpunan Self-Compelmentary X13: ('TAC', 'GTA')
# Himpunan Self-Compelmentary X14: ('ACT', 'AGT')
# Himpunan Self-Compelmentary X15: ('CTG', 'CAG')
# Himpunan Self-Compelmentary X16: ('TGC', 'GCA')
# Himpunan Self-Compelmentary X17: ('GCT', 'AGC')
# Himpunan Self-Compelmentary X18: ('CAT', 'ATG')
# Himpunan Self-Compelmentary X19: ('ATC', 'GAT')
# Himpunan Self-Compelmentary X20: ('TCA', 'TGA')
# Himpunan Self-Compelmentary X21: ('CAA', 'TTG')
# Himpunan Self-Compelmentary X22: ('AAC', 'GTT')
# Himpunan Self-Compelmentary X23: ('ACA', 'TGT')
# Himpunan Self-Compelmentary X24: ('CGT', 'ACG')
# Himpunan Self-Compelmentary X25: ('GTC', 'GAC')
# Himpunan Self-Compelmentary X26: ('TCG', 'CGA')
# Himpunan Self-Compelmentary X27: ('TTA', 'TAA')
# Himpunan Self-Compelmentary X28: ('ATT', 'AAT')
